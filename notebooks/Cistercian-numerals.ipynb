# %% [markdown]
# # Cistercian numerals
#
# A [numeral system](https://en.wikipedia.org/wiki/Cistercian_numerals) created by XIII century Cistercian monks that can represent any integer from 1 to 9,999 with a single glyph.
#
# Examples:
#
# <img src="Cistercian_numerals.png" width="40%" />

# %% [markdown]
# Combining digits:
#
# <img src="Cistercian_digits_vertical.png" width="30%" />

# %%
from jupyturtle import *

# %%
# %%turtle fast 1000 100
#
# h = 56  # glyph height
#
# #initial position
# with no_pen():
#     bk(450)
#     lt(90)
#     bk(h/2)
#
# def space(height):
#     with no_pen():
#         rt(90)
#         fd(height)
#         lt(90)
#
# def d1(height):
#     h = height
#     w = width = 2 * height / 7
#     fd(h, -90)
#     fd(w, 180)
#     fd(w, 90)
#     fd(h, 180)
#
# def d2(h):
#     w = 2 * h / 7
#     fd(h, 180)
#     fd(w, 90)
#     fd(w, 180)
#     with no_pen():
#         fd(w, -90)
#         bk(5 * h / 7)
#
# def d3(h):
#     w = 2 * h / 7
#     fd(h, -135)
#     fd(w * 2**.5, 180)
#     with no_pen():
#         fd(w * 2**.5, -45)
#         bk(h)
#
# def d4(h):
#     w = 2 * h / 7
#     fd(h, 180)
#     fd(w, 135)
#     fd(w * 2**.5, 135)
#     with no_pen():
#         fd(w, 90)
#         fd(h, 180)
#
# def d5(h):
#     w = 2 * h / 7
#     fd(h, 180)
#     fd(w, 135)
#     fd(w * 2**.5, 135)
#     fd(w, 90)
#     with no_pen():
#         fd(h, 180)
#
# def d6(h):
#     w = 2 * h / 7
#     fd(h, -90)
#     with no_pen():
#         fd(w, -90)
#     fd(w, -90)
#     with no_pen():
#         fd(w, 90)
#         fd(h-w, 180)
#
# def d7(h):
#     w = 2 * h / 7
#     fd(h, -90)
#     fd(w, -90)
#     fd(w, -90)
#     with no_pen():
#         fd(w, 90)
#         fd(h-w, 180)
#
# def d8(h):
#     w = 2 * h / 7
#     fd(h, -90)
#     with no_pen():
#         fd(w, -90)
#     fd(w, -90)
#     fd(w, 90)
#     with no_pen():
#         fd(h-w, 180)
#
# def d9(h):
#     w = 2 * h / 7
#     fd(h, -90)
#     fd(w, -90)
#     fd(w, -90)
#     fd(w, 90)
#     with no_pen():
#         fd(h-w, 180)
#
# h = 56
# d1(h)
# space(h)
# d2(h)
# space(h)
# d3(h)
# space(h)
# d4(h)
# space(h)
# d5(h)
# space(h)
# d6(h)
# space(h)
# d7(h)
# space(h)
# d8(h)
# space(h)
# d9(h)
# space(h)
# Out:
# <svg width="1000" height="100" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 500,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 50,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 50,78 50,22 66,22 50,22 50,78" />'
#
# <path stroke="#663399" stroke-width="2" d="M 106,78 106,22 106,38 122,38" />'
#
# <path stroke="#663399" stroke-width="2" d="M 106,38" />'
#
# <path stroke="#663399" stroke-width="2" d="M 106,78" />'
#
# <path stroke="#663399" stroke-width="2" d="M 162,78 162,22 178,38" />'
#
# <path stroke="#663399" stroke-width="2" d="M 162,22" />'
#
# <path stroke="#663399" stroke-width="2" d="M 162,78" />'
#
# <path stroke="#663399" stroke-width="2" d="M 218,78 218,22 218,38 234,22" />'
#
# <path stroke="#663399" stroke-width="2" d="M 218,22" />'
#
# <path stroke="#663399" stroke-width="2" d="M 218,78" />'
#
# <path stroke="#663399" stroke-width="2" d="M 274,78 274,22 274,38 290,22 274,22" />'
#
# <path stroke="#663399" stroke-width="2" d="M 274,78" />'
#
# <path stroke="#663399" stroke-width="2" d="M 330,78 330,22" />'
#
# <path stroke="#663399" stroke-width="2" d="M 346,22 346,38" />'
#
# <path stroke="#663399" stroke-width="2" d="M 330,38" />'
#
# <path stroke="#663399" stroke-width="2" d="M 330,78" />'
#
# <path stroke="#663399" stroke-width="2" d="M 386,78 386,22 402,22 402,38" />'
#
# <path stroke="#663399" stroke-width="2" d="M 386,38" />'
#
# <path stroke="#663399" stroke-width="2" d="M 386,78" />'
#
# <path stroke="#663399" stroke-width="2" d="M 442,78 442,22" />'
#
# <path stroke="#663399" stroke-width="2" d="M 458,22 458,38 442,38" />'
#
# <path stroke="#663399" stroke-width="2" d="M 442,78" />'
#
# <path stroke="#663399" stroke-width="2" d="M 498,78 498,22 514,22 514,38 498,38" />'
#
# <path stroke="#663399" stroke-width="2" d="M 498,78" />'
#
# <path stroke="#663399" stroke-width="2" d="M 554,78" />'
#
# <g transform="rotate(180.0,554.0,78.0) translate(554.0, 78.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>
