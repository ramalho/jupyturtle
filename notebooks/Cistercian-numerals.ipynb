# %% [markdown]
# # Cistercian numerals
#
# A [numeral system](https://en.wikipedia.org/wiki/Cistercian_numerals) created by XIII century Cistercian monks that can represent any integer from 1 to 9,999 with a single glyph.
#
# Examples in vertical form:
#
# <img src="Cistercian_numerals.png" width="40%" />

# %% [markdown]
# Combining digits in horizontal form:
#
# <img src="Cistercian_digits_horizontal_labels.png" width="30%" />

# %%
from jupyturtle import *

# %%
# %%turtle 1000 100 fast
#
# h = 56  # glyph height
#
# #initial position
# with no_pen():
#     bk(450)
#
# def space(height):
#     with no_pen():
#         fd(height * 1.2)
#
# def d1(a, flip=1):
#     b = 2 * a / 7
#     with magnet():
#         with magnet():
#             lt(90*flip)
#             fd(b)
#         fd(h)
#
# def d2(a, flip=1):
#     b = 2 * a / 7
#     with magnet():
#         fd(a)
#         bk(a - b)
#         lt(90*flip, b)
#
# def d3(a, flip=1):
#     b = 2 * a / 7
#     c = 2**.5 * b
#     with magnet():
#         with magnet():
#             lt(45*flip, c)
#         fd(a)
#
# def d4(a, flip=1):
#     b = 2 * a / 7
#     c = 2**.5 * b
#     with magnet():
#         fd(a, 180)
#         fd(a-b, -45*flip)
#         fd(c)
#
# def d5(a, flip=1):
#     b = 2 * a / 7
#     with magnet():
#         d4(a,flip)
#         lt(90*flip, b)
#
# def d6(a, flip=1):
#     b = 2 * a / 7
#     with magnet():
#         fd(a)
#     with magnet():
#         lt(90*flip)
#         leap(b, -90*flip)
#         fd(b)
#
# def d7(a, flip=1):
#     b = 2 * a / 7
#     d6(a, flip)
#     with magnet():
#         lt(90*flip, b)
#
# def d8(a, flip=1):
#     b = 2 * a / 7
#     d6(a, flip)
#     with magnet():
#         leap(b, 90*flip)
#         fd(b)
#
# def d9(a, flip=1):
#     b = 2 * a / 7
#     d8(a, flip)
#     with magnet():
#         lt(90*flip, b)
#
# for digit in [d1, d2, d3, d4, d5, d6, d7, d8, d9]:
#     digit(h)
#     space(h)
# Out:
# <svg width="1000" height="100" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 500,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 50,50 50,34" />'
#
# <path stroke="#663399" stroke-width="2" d="M 50,50 106,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 50,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 117.2,50 173.2,50 133.2,50 133.2,34" />'
#
# <path stroke="#663399" stroke-width="2" d="M 117.2,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 184.4,50 200.4,34" />'
#
# <path stroke="#663399" stroke-width="2" d="M 184.4,50 240.4,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 184.4,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 251.6,50 307.6,50 267.6,50 251.6,34" />'
#
# <path stroke="#663399" stroke-width="2" d="M 251.6,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 318.8,50 374.8,50 334.8,50 318.8,34" />'
#
# ...

# %% [markdown]
# <img src="Cistercian_digits_horizontal_labels.png" width="30%" />

# %%
# %%turtle 1000 100 fast
#
# #initial position
# with no_pen():
#     bk(450)
#
# FLIP = -1
#
# def d10(a):
#     d1(a, FLIP)
#
# def d20(a):
#     d2(a, FLIP)
#
# def d30(a):
#     d3(a, FLIP)
#
# def d40(a):
#     d4(a, FLIP)
#
# def d50(a):
#     d5(a, FLIP)
#
# def d60(a):
#     d6(a, FLIP)
#
# def d70(a):
#     d7(a, FLIP)
#
# def d80(a):
#     d8(a, FLIP)
#
# def d90(a):
#     d9(a, FLIP)
#
# for digit in [d10, d20, d30, d40, d50, d60, d70, d80, d90]:
#     digit(h)
#     space(h)
# Out:
# <svg width="1000" height="100" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 500,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 50,50 50,66" />'
#
# <path stroke="#663399" stroke-width="2" d="M 50,50 106,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 50,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 117.2,50 173.2,50 133.2,50 133.2,66" />'
#
# <path stroke="#663399" stroke-width="2" d="M 117.2,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 184.4,50 200.4,66" />'
#
# <path stroke="#663399" stroke-width="2" d="M 184.4,50 240.4,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 184.4,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 251.6,50 307.6,50 267.6,50 251.6,66" />'
#
# <path stroke="#663399" stroke-width="2" d="M 251.6,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 318.8,50 374.8,50 334.8,50 318.8,66" />'
#
# ...

# %% [markdown]
# <img src="Cistercian_digits_horizontal_labels.png" width="30%" />
