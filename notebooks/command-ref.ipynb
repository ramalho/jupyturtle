# %% [markdown]
# # Turtle command reference
#
# #### [`back`](#forward(n);-back(n)-—-aliases-fd;-bk) [`bk`](#forward(n);-back(n)-—-aliases-fd;-bk) [`forward`](#forward(n);-back(n)-—-aliases-fd;-bk) [`fd`](#forward(n);-back(n)-—-aliases-fd;-bk) [`get_turtle`](#get_turtle()) [`hide`](#hide()) [`jumpto`](#jumpto()) [`left`](#left(n);-right(n)-—-aliases-lt;-rt) [`lt`](#left(n);-right(n)-—-aliases-lt;-rt) [`make_turtle`](#get_turtle())
# #### [`moveto`](#moveto()) [`no_pen`](#no_pen()) [`pendown`](#pendown()) [`penup`](#penup()) [`render`](#draw()) [`right`](#left(n);-right(n)-—-aliases-lt;-rt) [`rt`](#left(n);-right(n)-—-aliases-lt;-rt) [`set_color`](#set_color(color)) [`set_width`](#set_width(n))  [`show`](#show()) [`toggle_pen`](#toggle_pen())

# %% [markdown]
# ## Introduction to the turtle and canvas

# %% [markdown]
# Import all names exported by the `jupyturtle` module, then move the turtle.

# %%
from jupyturtle import *
fd(50)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 200,75" />'
#
# <g transform="rotate(-90.0,200.0,75.0) translate(200.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Most commands will automatically create a turtle and blank canvas,
# if there isn't one already.
#
# To start a new drawing, call `make_turtle()`

# %%
make_turtle()
fd(60)
lt(120)
fd(60)  # see more turtle commands below drawing
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 210,75 180,23 150,75" />'
#
# <g transform="rotate(30.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Further commands apply to the latest turtle.

# %%
lt(120)
fd(60)

# %% [markdown]
# ## Essential commands
#
# Learn these first.

# %% [markdown]
# ### `forward(n)`; `back(n)` — aliases `fd`; `bk`
#
# Move turtle forward or backward `n` units, leaving a trail if the pen is down.

# %%
make_turtle()
fd(50)
bk(75)
fd(25)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 200,75 125,75 150,75" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### `left(n)`; `right(n)` — aliases `lt`; `rt`
#
# Turn turtle left or right `n` degrees, remaining in place.

# %%
make_turtle()
lt(45)
rt(90)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <g transform="rotate(-45.0,150,75) translate(150, 75)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### `penup()`; `pendown()`
#
# Raise or lower the turtle's pen. The turtle leaves a trail only when the pen is down (the default).

# %%
make_turtle()

for _ in range(4):
    fd(10)
    penup()
    fd(20)
    pendown()
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 160,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 180,75 190,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 210,75 220,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 240,75 250,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 270,75" />'
#
# <g transform="rotate(-90.0,270.0,75.0) translate(270.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### `no_pen()`

# %% [markdown]
# Returs a context manager that calls `penup()` at the top of the `with` block
# and resets the pen to its previous state at the end of the block.
#
# This is useful to move the turtle without drawing for a few steps.

# %%
make_turtle(delay=0.1)

rt(60)

for _ in range(3):
    lt(60)
    fd(30)
    with no_pen():
        lt(60)
        fd(30)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 180,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 195,49 180,23" />'
#
# <path stroke="#663399" stroke-width="2" d="M 150,23 135,49" />'
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <g transform="rotate(-30.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### toggle_pen()
#
# Lower the pen if it's up; raises it if it's down.

# %%
make_turtle(delay=.01)

for _ in range(20):
    fd(5)
    toggle_pen()
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 155,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 160,75 165,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 170,75 175,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 180,75 185,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 190,75 195,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 200,75 205,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 210,75 215,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 220,75 225,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 230,75 235,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 240,75 245,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 250,75" />'
#
# <g transform="rotate(-90.0,250.0,75.0) translate(250.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### `hide()`; `show()`

# %% [markdown]
# Make the turtle invisible or visible. The turtle is visible by default. Making it invisible speeds up drawing.

# %%
make_turtle()
hide()
forward(100)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 250,75" />'
#
# </svg>

# %% [markdown]
# ### `make_turtle(animate=True, delay=0.2, width=300, height=150)`
#
# Create a new turtle and canvas. Assign new turtle to `_main_turtle`. Further commands are sent to `_main_turtle`.
#
# Optional arguments:
#
# `animate=True` updates the drawing with each turtle command. This is slow for complex drawings with many lines. Set to `False` for much faster processing, then use `draw()` to render the drawing.
#
# `delay=?` sets a delay in seconds after each turtle command. Default is `0`.
# For debugging, setting `delay=.5` makes the turtle pause for ½ second so it's easy to watch each step as it happens.
#
# `width=?` / `height=?` define the size of the drawing area.
#
# Use `animate=False` and `draw()` to draw  circles and arcs almost instantly.
#
# The `delay` is ignored when `animate` is `False`,
# because the drawing will only be updated once, after a call to `draw()`.

# %%
make_turtle(delay=5, animate=False, height=240, width=240)

def circle():
    for _ in range(180):
        fd(2)
        lt(2)

for _ in range(24):
    circle()
    lt(15)

draw()
# Out:
# Warning: delay is ignored when animate=False
# <svg width="240" height="240" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 120,120 122,120 124,119.9 126,119.8 128,119.6 130,119.3 131.9,119 133.9,118.5 135.8,118.1 137.8,117.5 139.7,116.9 141.5,116.2 143.4,115.5 145.2,114.6 147,113.8 148.8,112.8 150.5,111.8 152.2,110.8 153.9,109.6 155.5,108.5 157.1,107.2 158.6,106 160.1,104.6 161.5,103.2 162.9,101.8 164.2,100.3 165.5,98.8 166.8,97.2 167.9,95.6 169.1,93.9 170.1,92.2 171.1,90.5 172.1,88.7 172.9,86.9 173.7,85.1 174.5,83.2 175.2,81.4 175.8,79.5 176.3,77.5 176.8,75.6 177.2,73.6 177.6,71.7 177.9,69.7 178.1,67.7 178.2,65.7 178.3,63.7 178.3,61.7 178.2,59.7 178.1,57.7 177.9,55.7 177.6,53.7 177.2,51.8 176.8,49.8 176.3,47.9 175.8,46 175.2,44.1 174.5,42.2 173.7,40.3 172.9,38.5 172.1,36.7 171.1,34.9 170.1,33.2 169.1,31.5 167.9,29.8 166.8,28.2 165.5,26.7 164.2,25.1 162.9,23.6 161.5,22.2 160.1,20.8 158.6,19.5 157.1,18.2 155.5,16.9 153.9,15.8 152.2,14.7 150.5,13.6 148.8,12.6 147,11.7 145.2,10.8 143.4,10 141.5,9.2 139.7,8.5 137.8,7.9 135.8,7.4 133.9,6.9 131.9,6.5 130,6.1 128,5.8 126,5.6 124,5.5 122,5.4 120,5.4 118,5.5 116,5.6 114,5.8 112,6.1 110.1,6.5 108.1,6.9 106.2,7.4 104.2,7.9 102.3,8.5 100.5,9.2 98.6,10 96.8,10.8 95,11.7 93.2,12.6 91.5,13.6 89.8,14.7 88.1,15.8 86.5,16.9 84.9,18.2 83.4,19.5 81.9,20.8 80.5,22.2 79.1,23.6 77.8,25.1 76.5,26.7 75.2,28.2 74.1,29.8 72.9,31.5 71.9,33.2 70.9,34.9 69.9,36.7 69.1,38.5 68.3,40.3 67.5,42.2 66.8,44.1 66.2,46 65.7,47.9 65.2,49.8 64.8,51.8 64.4,53.7 64.1,55.7 63.9,57.7 63.8,59.7 63.7,61.7 63.
 96.2,120.8 98.2,121.1 100.1,121.4 102.1,121.6 104.1,121.7 106.1,121.7 108.1,121.7 110.1,121.6 112.1,121.4 114.1,121.1 116.1,120.8 118.1,120.4 120,120 121.7,119 123.4,117.9 125.1,116.8 126.7,115.6 128.3,114.4 129.8,113.1 131.3,111.8 132.7,110.4 134.1,109 135.5,107.5 136.8,105.9 138,104.4 139.2,102.8 140.3,101.1 141.3,99.4 142.3,97.7 143.3,95.9 144.2,94.1 145,92.3 145 ...

# %% [markdown]
# With `animate=True` (the default value), we can see the drawing as it happens.
# The drawing below will be updated at 361 times: 180 updates per circle, plus the update of `lt(15)`.
#
# > **Note**: The `jupyturtle` Python code generates the drawing as SVG code, which is then rendered by the browser's graphic engine. For each update, automatic or not, a complete new drawing is generated and rendered.

# %%
make_turtle(delay=0, height=240, width=240)

def circle():
    for _ in range(180):
        fd(2)
        lt(2)
        
circle()
lt(15)
circle()
# Out:
# <svg width="240" height="240" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 120,120 122,120 124,119.9 126,119.8 128,119.6 130,119.3 131.9,119 133.9,118.5 135.8,118.1 137.8,117.5 139.7,116.9 141.5,116.2 143.4,115.5 145.2,114.6 147,113.8 148.8,112.8 150.5,111.8 152.2,110.8 153.9,109.6 155.5,108.5 157.1,107.2 158.6,106 160.1,104.6 161.5,103.2 162.9,101.8 164.2,100.3 165.5,98.8 166.8,97.2 167.9,95.6 169.1,93.9 170.1,92.2 171.1,90.5 172.1,88.7 172.9,86.9 173.7,85.1 174.5,83.2 175.2,81.4 175.8,79.5 176.3,77.5 176.8,75.6 177.2,73.6 177.6,71.7 177.9,69.7 178.1,67.7 178.2,65.7 178.3,63.7 178.3,61.7 178.2,59.7 178.1,57.7 177.9,55.7 177.6,53.7 177.2,51.8 176.8,49.8 176.3,47.9 175.8,46 175.2,44.1 174.5,42.2 173.7,40.3 172.9,38.5 172.1,36.7 171.1,34.9 170.1,33.2 169.1,31.5 167.9,29.8 166.8,28.2 165.5,26.7 164.2,25.1 162.9,23.6 161.5,22.2 160.1,20.8 158.6,19.5 157.1,18.2 155.5,16.9 153.9,15.8 152.2,14.7 150.5,13.6 148.8,12.6 147,11.7 145.2,10.8 143.4,10 141.5,9.2 139.7,8.5 137.8,7.9 135.8,7.4 133.9,6.9 131.9,6.5 130,6.1 128,5.8 126,5.6 124,5.5 122,5.4 120,5.4 118,5.5 116,5.6 114,5.8 112,6.1 110.1,6.5 108.1,6.9 106.2,7.4 104.2,7.9 102.3,8.5 100.5,9.2 98.6,10 96.8,10.8 95,11.7 93.2,12.6 91.5,13.6 89.8,14.7 88.1,15.8 86.5,16.9 84.9,18.2 83.4,19.5 81.9,20.8 80.5,22.2 79.1,23.6 77.8,25.1 76.5,26.7 75.2,28.2 74.1,29.8 72.9,31.5 71.9,33.2 70.9,34.9 69.9,36.7 69.1,38.5 68.3,40.3 67.5,42.2 66.8,44.1 66.2,46 65.7,47.9 65.2,49.8 64.8,51.8 64.4,53.7 64.1,55.7 63.9,57.7 63.8,59.7 63.7,61.7 63.7,63.7 63.8,65.7 63.9,67.7 64.1,69.7 64.4,71.7 64.8,73.6 65.2,75.6 65.7,77.5 66.2,79.5 66.8,81.4 67.5,83
0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### `get_turtle()`
#
# Returns existing `_main_turtle`, or creates and sets it if it was `None`.
# Useful when you need to change some turtle attribute, like `animate` or `delay` after `make_turtle()`.
# See example in `draw()`.

# %% [markdown]
# ### `draw()`
#
# Update the drawing.
# Use `draw()` to render the drawing after setting `animate=False` and
# issuing turtle commands like `fd()`, `lt()` etc.
#
# When `animate=True`, `draw()` is automatically called after each turtle command.
#
# The next example draws two circles.
# We can see the turtle drawing the first circle because `animate=True`.
# We then set `animate=False`, and the second circle is rendered all at once
# when we call `draw()`.

# %%
make_turtle(delay=0.005, height=240, width=240)

def circle():
    for _ in range(180):
        fd(2)
        lt(2)

# first circle, `animate` is on (the default)
circle()  # slow-ish
lt(15)
# second circle, turn off `animate`
get_turtle().animate=False
circle()  # almost instant, delay is ignored
draw()  # all lines rendered at once
# Out:
# <svg width="240" height="240" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 120,120 122,120 124,119.9 126,119.8 128,119.6 130,119.3 131.9,119 133.9,118.5 135.8,118.1 137.8,117.5 139.7,116.9 141.5,116.2 143.4,115.5 145.2,114.6 147,113.8 148.8,112.8 150.5,111.8 152.2,110.8 153.9,109.6 155.5,108.5 157.1,107.2 158.6,106 160.1,104.6 161.5,103.2 162.9,101.8 164.2,100.3 165.5,98.8 166.8,97.2 167.9,95.6 169.1,93.9 170.1,92.2 171.1,90.5 172.1,88.7 172.9,86.9 173.7,85.1 174.5,83.2 175.2,81.4 175.8,79.5 176.3,77.5 176.8,75.6 177.2,73.6 177.6,71.7 177.9,69.7 178.1,67.7 178.2,65.7 178.3,63.7 178.3,61.7 178.2,59.7 178.1,57.7 177.9,55.7 177.6,53.7 177.2,51.8 176.8,49.8 176.3,47.9 175.8,46 175.2,44.1 174.5,42.2 173.7,40.3 172.9,38.5 172.1,36.7 171.1,34.9 170.1,33.2 169.1,31.5 167.9,29.8 166.8,28.2 165.5,26.7 164.2,25.1 162.9,23.6 161.5,22.2 160.1,20.8 158.6,19.5 157.1,18.2 155.5,16.9 153.9,15.8 152.2,14.7 150.5,13.6 148.8,12.6 147,11.7 145.2,10.8 143.4,10 141.5,9.2 139.7,8.5 137.8,7.9 135.8,7.4 133.9,6.9 131.9,6.5 130,6.1 128,5.8 126,5.6 124,5.5 122,5.4 120,5.4 118,5.5 116,5.6 114,5.8 112,6.1 110.1,6.5 108.1,6.9 106.2,7.4 104.2,7.9 102.3,8.5 100.5,9.2 98.6,10 96.8,10.8 95,11.7 93.2,12.6 91.5,13.6 89.8,14.7 88.1,15.8 86.5,16.9 84.9,18.2 83.4,19.5 81.9,20.8 80.5,22.2 79.1,23.6 77.8,25.1 76.5,26.7 75.2,28.2 74.1,29.8 72.9,31.5 71.9,33.2 70.9,34.9 69.9,36.7 69.1,38.5 68.3,40.3 67.5,42.2 66.8,44.1 66.2,46 65.7,47.9 65.2,49.8 64.8,51.8 64.4,53.7 64.1,55.7 63.9,57.7 63.8,59.7 63.7,61.7 63.7,63.7 63.8,65.7 63.9,67.7 64.1,69.7 64.4,71.7 64.8,73.6 65.2,75.6 65.7,77.5 66.2,79.5 66.8,81.4 67.5,
0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### `jumpto(x, y)`
#
# Teleport the turtle to coordinates (x, y) without drawing. Contrast with `moveto(x, y)`.

# %%
make_turtle(delay=0.01)

def square():
    for _ in range(4):
        fd(30)
        rt(90)

for i in range(3):
    jumpto(i*60 + 5, i*40 + 5)
    square()
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 5,5 35,5 35,35 5,35 5,5" />'
#
# <path stroke="#663399" stroke-width="2" d="M 65,45 95,45 95,75 65,75 65,45" />'
#
# <path stroke="#663399" stroke-width="2" d="M 125,85 155,85 155,115 125,115 125,85" />'
#
# <g transform="rotate(-90.0,125.0,85.0) translate(125.0, 85.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### `moveto(x, y)`
#
# Move the turtle to coordinates (x, y), drawing if the pen is down. Contrast with `jumpto(x, y)`.

# %%
make_turtle(delay=0.01)

for i in range(3):
    moveto(i*60 + 5, i*40 + 5)
    square()
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 5,5 35,5 35,35 5,35 5,5 65,45 95,45 95,75 65,75 65,45 125,85 155,85 155,115 125,115 125,85" />'
#
# <g transform="rotate(-90.0,125.0,85.0) translate(125.0, 85.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### `set_color(color)`
#
# Set the `turtle.pen_color` attribute to `color`, which should be a string the `'#RRGGBB'` format or one of the many [Web color names](https://en.wikipedia.org/wiki/Web_colors) supported by modern browsers.

# %%
make_turtle()
colors = 'red orange gold green blue rebeccapurple'.split()
hide()
set_width(10)
for color in colors:
    set_color(color)
    fd(30)
    lt(360/len(colors))
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="red" stroke-width="10" d="M 150,75 180,75" />'
#
# <path stroke="orange" stroke-width="10" d="M 180,75 195,49" />'
#
# <path stroke="gold" stroke-width="10" d="M 195,49 180,23" />'
#
# <path stroke="green" stroke-width="10" d="M 180,23 150,23" />'
#
# <path stroke="blue" stroke-width="10" d="M 150,23 135,49" />'
#
# <path stroke="rebeccapurple" stroke-width="10" d="M 135,49 150,75" />'
#
# </svg>

# %% [markdown]
# ### `set_width(n)`
#
# Set the `turtle.pen_width` attribute to the integer `n`.

# %%
make_turtle()
bk(140)
for i in range(1, 26, 2):
    set_width(i)
    fd(20)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 10,75" />'
#
# <path stroke="#663399" stroke-width="1" d="M 10,75 30,75" />'
#
# <path stroke="#663399" stroke-width="3" d="M 30,75 50,75" />'
#
# <path stroke="#663399" stroke-width="5" d="M 50,75 70,75" />'
#
# <path stroke="#663399" stroke-width="7" d="M 70,75 90,75" />'
#
# <path stroke="#663399" stroke-width="9" d="M 90,75 110,75" />'
#
# <path stroke="#663399" stroke-width="11" d="M 110,75 130,75" />'
#
# <path stroke="#663399" stroke-width="13" d="M 130,75 150,75" />'
#
# <path stroke="#663399" stroke-width="15" d="M 150,75 170,75" />'
#
# <path stroke="#663399" stroke-width="17" d="M 170,75 190,75" />'
#
# <path stroke="#663399" stroke-width="19" d="M 190,75 210,75" />'
#
# <path stroke="#663399" stroke-width="21" d="M 210,75 230,75" />'
#
# <path stroke="#663399" stroke-width="23" d="M 230,75 250,75" />'
#
# <path stroke="#663399" stroke-width="25" d="M 250,75 270,75" />'
#
# <g transform="rotate(-90.0,270.0,75.0) translate(270.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>
