# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + str(local))
    return filename

download('https://raw.githubusercontent.com/AllenDowney/ThinkPython/v3/thinkpython.py')
download('https://raw.githubusercontent.com/AllenDowney/ThinkPython/v3/diagram.py') # no /main/, how?
download('https://raw.githubusercontent.com/ramalho/jupyturtle/main/jupyturtle.py') # why /main/?
# Out:
# 'jupyturtle.py'

# %%
import thinkpython

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Functions and Interfaces
#
# This chapter introduces a module called `Turtle`, which allows you to create simple drawings by giving instructions to an imaginary turtle.
# We will use this module to write functions that draw squares, polygons, and circles -- and to demonstrate **interface design**, which is a way of designing functions that work together.
#
# This chapter is the first of several case studies, which means there is less new content than in other chapters, and more exercises.

# %% [markdown]
# ## The Turtle module
#
# To use the `Turtle` module, we can import it like this.

# %%
from jupyturtle import Turtle

# %% [markdown]
# Now we can create a `Turtle` object and use the methods defined in the class, like `forward`.

# %%
t = Turtle()
t.forward(100)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle108b3ad20" transform="rotate(-90.0,300,100) translate(300, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="300" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# Each `Turtle` object has its own `Canvas` by default.
# A canvas is a space on the screen where we can draw.
# The turtle is drawn as a circular shell and a triangular head.
# The circle shows the location of the turtle and the triangle indicates the direction it is heading.
#
# `forward` moves the turtle a given distance in the direction it's facing, drawing a line segment along the way.
# The distance is in arbitrary units -- the actual size depends on your computer's screen.
#
# We will use methods defined in the `Turtle` class many times, so `jupyturtle` provides shortcuts
# which you can import like this.

# %%
from jupyturtle import forward as fd
fd(100)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle108a28380" transform="rotate(-180.0,350,50) translate(350, 50)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="300" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="300" y1="100" x2="350" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="350" y1="100" x2="350" y2="50" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# This version of the import statement imports `forward` with a shorter alias: `fd`.
#
# Note that calling `fd`, a new turtle and canvas is created.
#
# Further commands will update that same canvas.

# %% [markdown]
# `Turtle` provides two other functions we'll use, called `left` and `right`.
# We'll import them like this.

# %%
from jupyturtle import left as lt, right as rt, forward as fd

# %% [markdown]
# `left` causes the turtle to turn left. The argument is the angle of the turn in degrees.
# For example, we can make a 90 degree left turn like this.

# %%
fd(50)
lt(90)
fd(50)

# %% [markdown]
# This program moves the turtle east and then north, leaving two line segments behind.
# Before you go on, see if you can modify the previous program to make a square.

# %% [markdown]
# ## Making a square
#
# Here's one way to make a square.

# %%
from jupyturtle import make_turtle, forward, left

make_turtle()

forward(50)
left(90)

forward(50)
left(90)

forward(50)
left(90)

forward(50)
left(90)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle108a6e420" transform="rotate(-450.0,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="250" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250" y1="100" x2="250" y2="50" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250" y1="50" x2="200" y2="50" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="50" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# Because this program repeats the same pair of lines four times, we can do the same thing more concisely with a `for` loop.

# %%
make_turtle()
for i in range(4):
    forward(50)
    left(90)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle108babef0" transform="rotate(-450.0,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="250" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250" y1="100" x2="250" y2="50" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250" y1="50" x2="200" y2="50" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="50" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# ## Encapsulation and generalization
#
# Let's take the square-drawing code from the previous section and put it in a function called `square`.

# %%
def square():
    for i in range(4):
        forward(50)
        left(90)

# %% [markdown]
# Now we can call the function like this.

# %%
make_turtle()
square()
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle108baaf30" transform="rotate(-450.0,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="250" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250" y1="100" x2="250" y2="50" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250" y1="50" x2="200" y2="50" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="50" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# Wrapping a piece of code up in a function is called **encapsulation**.
# One of the benefits of encapsulation is that it attaches a name to the code, which serves as a kind of documentation. Another advantage is that if you re-use the code, it is more concise to call a function twice than to copy and paste the body!
#
# In the current version, the size of the square is always `50`.
# If we want to draw squares with different sizes, we can take the length of the sides as a parameter.

# %%
def square(length):
    for i in range(4):
        forward(length)
        left(90)

# %% [markdown]
# Now we can draw squares with different sizes.

# %%
make_turtle()
square(30)
square(60)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle108bab4a0" transform="rotate(-810.0,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="230" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230" y1="100" x2="230" y2="70" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230" y1="70" x2="200" y2="70" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="70" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="100" x2="260" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260" y1="100" x2="260" y2="40" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260" y1="40" x2="200" y2="40" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="40" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# Adding a parameter to a function is called **generalization** because it makes the function more general: with the previous version, the square is always the same size; with this version it can be any size.
#
# If we add another parameter, we can make it even more general.
# The following function draws regular polygons with a given of sides.

# %%
def polygon(n, length):
    angle = 360 / n
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# In a regular polygon with `n` sides, the angle between adjacent sides is `360 / n` degrees.
#
# The following example draws a `7`-sided polygon with side length `30`.

# %%
make_turtle()
polygon(7, 30)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle108ba81d0" transform="rotate(-450.00000000000006,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="230" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230" y1="100" x2="249" y2="77" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249" y1="77" x2="242" y2="48" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="242" y1="48" x2="215" y2="35" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="215" y1="35" x2="188" y2="48" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="188" y1="48" x2="181" y2="77" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="181" y1="77" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# When a function has more than a few numeric arguments, it is easy to forget what they are, or what order they should be in.
# It can be a good idea to include the names of the parameters in the argument list.

# %%
make_turtle()
polygon(n=7, length=30)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle108ba8380" transform="rotate(-450.00000000000006,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="230" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230" y1="100" x2="249" y2="77" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249" y1="77" x2="242" y2="48" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="242" y1="48" x2="215" y2="35" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="215" y1="35" x2="188" y2="48" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="188" y1="48" x2="181" y2="77" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="181" y1="77" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# These are sometimes called "named arguments" because they include the parameter names.
# But in Python they are more often called **keyword arguments** (not to be confused with Python keywords like `for` and `def`).
#
# This use of the assignment operator, `=`, is a reminder about how arguments and parameters work -- when you call a function, the arguments are assigned to the parameters.

# %% [markdown]
# ## Approximating a circle
#
# Now suppose we want to draw a circle.
# We can do that, approximately, by drawing a polygon with a large number of sides, so each side is small enough that it's hard to see.
# Here is a function that uses `polygon` to draw a `30`-sided polygon that approximates a circle.

# %%
import math

def circle(radius):
    circumference = 2 * math.pi * radius
    n = 30
    length = circumference / n
    polygon(n, length)

# %% [markdown]
# `circle` takes the radius of the the circle as a parameter.
# It computes `circumference`, which is the circumference of a circle with the given radius.
# `n` is the number of sides, so `circumference / n` is the length of each side.
#
# This function might take a long time to run.
# We can speed it up by calling `make_turtle` with a keyword argument called `speed` that controls the speed of the turtle.

# %%
make_turtle(delay=0.05)
circle(30)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle108b83b90" transform="rotate(-450.0,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="206" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="206" y1="100" x2="212" y2="99" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="212" y1="99" x2="218" y2="96" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="218" y1="96" x2="223" y2="92" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="223" y1="92" x2="227" y2="87" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="227" y1="87" x2="230" y2="82" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230" y1="82" x2="232" y2="76" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232" y1="76" x2="233" y2="70" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="233" y1="70" x2="232" y2="64" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232" y1="64" x2="230" y2="58" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230" y1="58" x2="227" y2="53" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="227" y1="53" x2="223" y2="48" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="223" y1="48" x2="218" y2="44" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="218" y1="44" x2="212" y2="41" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="212" y1="41" x2="206" y2="40" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="206" y1="40" x2="200" y2="40" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="40" x2="194" y2="41" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="194" y1="41" x2="188" y2="44" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="188" y1="44" x2="183" y2="48" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="183" y1="48" x2="179" y2="53" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="179" y1="53" x2="176" y2="58" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="176" y1="58" x2="174" y2="64" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="174" y1="64" x2="173" y2="70" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="173" y1="70" x2="174" y2="76" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="174" y1="76" x2="176" y2="82" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="176" y1="82" x2="179" y2="87" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="179" y1="87" x2="183" y2="92" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="183" y1="92" x2="188" y2="96" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="188" y1="96" x2="194" y2="99" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="194" y1="99" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# A limitation of this solution is that `n` is a constant, which means
# that for very big circles, the sides are too long, and for small
# circles, we waste time drawing very short sides.
# One option is to generalize the function by taking `n` as a parameter.
# But let's keep it simple for now.

# %% [markdown]
# ## Refactoring
#
# Now let's write a more general version of `circle`, called `arc`, that takes a second parameter, `angle`, and draws an arc of a circle that spans the given angle.
# For example, if `angle` is `360` degrees, it draws a complete circle. If `angle` is `180` degrees, it draws a half circle.
#
# To write `circle`, we were able to reuse `polygon`, because a many-sided polygon is a good approximation of a circle.
# But we can't use `polygon` to write `arc`.
#
# Instead, we'll create the more general version of `polygon`, called `polyline`.

# %%
def polyline(n, length, angle):
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# `polyline` takes as parameters the number of line segments to draw, `n`, the length of the segments, `length`, and the angle between them, `angle`.
#
# Now we can rewrite `polygon` to use `polyline`.

# %%
def polygon(n, length):
    angle = 360.0 / n
    polyline(n, length, angle)

# %% [markdown]
# And we can use `polyline` to write `arc`.

# %%
def arc(radius, angle):
    arc_length = 2 * math.pi * radius * angle / 360
    n = 30
    length = arc_length / n
    step_angle = float(angle) / n
    polyline(n, length, step_angle)

# %% [markdown]
# `arc` is similar to `circle`, except that it computes `arc_length`, which is a fraction of the circumference of a circle.
#
# Finally, we can rewrite `circle` to use `arc`.

# %%
def circle(radius):
    arc(radius,  360)

# %% [markdown]
# To check that these functions work as expected, we'll use them to draw something like a snail.

# %%
make_turtle(delay=0.05)
polygon(n=20, length=9)
arc(radius=70, angle=70)
circle(radius=10)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle108babd70" transform="rotate(-126.0,218,97) translate(218, 97)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="209" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="209" y1="100" x2="218" y2="97" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# This process -- rearranging a program to improve interfaces and facilitate code re-use -- is called **refactoring**.
#
# If we had planned ahead, we might have written `polyline` first and avoided refactoring, but often you don't know enough at the beginning of a project to design all the interfaces.
# Once you start coding, you understand the problem better.
# Sometimes refactoring is a sign that you have learned something.

# %% [markdown]
# ## Stack diagram
#
# When we call `circle`, it calls `arc`, which calls `polyline`.
# We can use a stack diagram to show this sequence of function calls and the parameters for each one.

# %%
from diagram import make_binding, make_frame, Frame, Stack

frame1 = make_frame(dict(radius=30), name='circle', loc='left')

frame2 = make_frame(dict(radius=30, angle=360), name='arc', loc='left', dx=1.1)

frame3 = make_frame(dict(n=60, length=3.04, angle=5.8),
                    name='polyline', loc='left', dx=1.1, offsetx=-0.27)

stack = Stack([frame1, frame2, frame3], dy=-0.4)

# %%
from diagram import diagram, adjust

width, height, x, y = [3.58, 1.31, 0.98, 1.06]
ax = diagram(width, height)
bbox = stack.draw(ax, x, y)
#adjust(x, y, bbox)

# %% [markdown]
# Notice that the value of `angle` in `polyline` is difference from the value of `angle` in `arc`.
# Parameters are local, which means you can use the same parameter name in different functions; it's a different variable in each function, and it can refer to a different value.

# %% [markdown]
# ## A development plan
#
# A **development plan** is a process for writing programs. The process we used in this case study is "encapsulation and generalization".
# The steps of this process are:
#
# 1.  Start by writing a small program with no function definitions.
#
# 2.  Once you get the program working, identify a coherent piece of it,
#     encapsulate the piece in a function and give it a name.
#     Copy and paste working code to avoid retyping (and re-debugging).
#
# 3.  Generalize the function by adding appropriate parameters.
#
# 4.  Repeat Steps 1 to 3 until you have a set of working functions.
#
# 5.  Look for opportunities to improve the program by refactoring. For
#     example, if you have similar code in several places, consider
#     factoring it into an appropriately general function.
#
# This process has some drawbacks -- we will see alternatives later -- but it can be useful if you don't know ahead of time how to divide the program into functions. This approach lets you design as you go along.

# %% [markdown]
# ## Docstrings
#
# A **docstring** is a string at the beginning of a function that explains the interface ("doc" is short for "documentation"). Here is an example:

# %%
def polyline(n, length, angle):
    """Draws line segments with the given length and angle between them.

    n: integer number of line segments
    length: length of the line segments
    angle: angle between segments (in degrees)
    """
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# By convention, docstrings are triple-quoted strings, also known as **multiline strings** because the triple quotes allow the string to span more than one line.
#
# A docstring should:
#
# * Explain concisely what the function does, without getting into the details of how it does it,
#
# * Explain what effect each parameter has on the behavior of the function, and
#
# * Indicate what type each parameter should be, if it is not obvious.
#
# Writing this kind of documentation is an important part of interface design. A well-designed interface should be simple to explain; if you have a hard time explaining one of your functions, maybe the interface could be improved.

# %% [markdown]
# ## Debugging
#
# An interface is like a contract between a function and a caller. The
# caller agrees to provide certain arguments and the function agrees to
# do certain work.
#
# For example, `polyline` requires three arguments: `n` has to be an integer; `length` should be a positive number; and `angle` has to be a number, which is understood to be in degrees.
#
# These requirements are called **preconditions** because they are supposed to be true before the function starts executing. Conversely, conditions at the end of the function are **postconditions**.
# Postconditions include the intended effect of the function (like drawing line segments) and any side effects (like moving the turtle or making other changes).
#
# Preconditions are the responsibility of the caller. If the caller violates a precondition and the function doesn't work correctly, the bug is in the caller, not the function.
#
# If the preconditions are satisfied and the postconditions are not, the bug is in the function. If your pre- and postconditions are clear, they can help with debugging.

# %% [markdown]
# ## Glossary
#
# **interface design:**
# A process for designing the interface of a function, which includes the parameters it should take.
#
# **canvas:**
# A window used to display graphical elements including lines, circles, rectangles, and other shapes.
#
# **encapsulation:**
#  The process of transforming a sequence of statements into a function definition.
#
# **generalization:**
#  The process of replacing something unnecessarily specific (like a number) with something appropriately general (like a variable or parameter).
#
# **keyword arguments:**
# An argument that includes the name of the parameter.
#
# **refactoring:**
#  The process of modifying a working program to improve function interfaces and other qualities of the code.
#
# **development plan:**
# A process for writing programs.
#
# **docstring:**
#  A string that appears at the top of a function definition to document the function's interface.
#
# **multiline strings:**
# A string enclosed in triple quotes that can span more than one line of a program.
#
# **precondition:**
#  A requirement that should be satisfied by the caller before a function starts.
#
# **postcondition:**
#  A requirement that should be satisfied by the function before it ends.

# %% [markdown]
# ## Exercises
#
# For the exercises below, there are a few more turtle functions you might want to use.
#
# * `penup` lifts the turtle's imaginary pen so it doesn't leave a trail when it moves.
#
# * `pendown` puts the pen back down.
#
# The following function uses `penup` and `pendown` to move the turtle without leaving a trail.

# %%
from jupyturtle import forward, penup, pendown

def jump(length):
    """Move forward length units without leaving a trail.

    Postcondition: Leaves the pen down.
    """
    penup()
    forward(length)
    pendown()
# Out:
# ImportError: cannot import name 'penup' from 'jupyturtle' (/Users/luciano/prj/jupyturtle/jupyturtle.py)

# %% [markdown]
# 🚧 Sorry, cannot import `penup` or `pendown` yet.
#
# I need to think about how to implement that.

# %% [markdown]
# ### Exercise
#
# Write a function called `rectangle` that draws a rectangle with given side lengths.
# For example, here's a rectangle that's `80` units wide and `40` units tall.

# %%
# Solution

def rectangle(length1, length2):
    """Draw a rectangle with the given lengths.

    length1: length of the first side
    length2: length of the second size
    """
    for i in range(2):
        forward(length1)
        left(90)
        forward(length2)
        left(90)

# %%
make_turtle()
rectangle(80, 40)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle107b71a30" transform="rotate(-450.0,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="280" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="280" y1="100" x2="280" y2="60" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="280" y1="60" x2="200" y2="60" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="60" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# ## Exercise
#
# Write a function called `rhombus` that draws a rhombus with a given side length and a given interior angle. For example, here's a rhombus with side length `50` and an interior angle of `60` degrees.

# %%
def rhombus(length, angle):
    for i in range(2):
        forward(length)
        left(angle)
        forward(length)
        left(180-angle)

# %%
make_turtle()
rhombus(50, 60)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle10c2ba1b0" transform="rotate(-450.0,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="250" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250" y1="100" x2="275" y2="57" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="275" y1="57" x2="225" y2="57" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="225" y1="57" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Now write a more general function called `parallelogram` that draws a quadrilateral with parallel sides. Then rewrite `rectangle` and `rhombus` to use `parallelogram`.

# %%
# Solution

def parallelogram(length1, length2, angle):
    for i in range(2):
        forward(length1)
        left(angle)
        forward(length2)
        left(180-angle)

# %%
# Solution

def rectangle(length1, length2):
    """Draw a rectangle with the given lengths.

    length1: length of the first side
    length2: length of the second size
    """
    parallelogram(length1, length2, 90)

# %%
# Solution

def rhombus(length, angle):
    parallelogram(length, length, angle)

# %%
make_turtle(delay=0.05)
jump(-120)

rectangle(80, 40)
jump(100)
rhombus(50, 60)
jump(80)
parallelogram(80, 50, 60)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle10c30ce60" transform="rotate(-90.0,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# </svg>
# NameError: name 'jump' is not defined

# %% [markdown]
# 🚧 Sorry, cannot import `jump` yet.
#
# I need to think about how to implement that.

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw shapes like this.
#
# Hint: Write a function called `triangle` that draws one triangular segment.

# %%
# Solution
import math

from jupyturtle import forward, left, right

def triangle(radius,  angle):
    """Draws an icosceles triangle.

    The turtle starts and ends at the peak, facing the middle of the base.

    radius: length of the equal legs
    angle: half peak angle in degrees
    """
    y = radius * math.sin(angle * math.pi / 180)

    right(angle)
    forward(radius)
    left(90+angle)
    forward(2*y)
    left(90+angle)
    forward(radius)
    left(180-angle)

# %%
from jupyturtle import make_turtle, hide
make_turtle()
hide()

for i in range(6):
    triangle(50, 10)
    left(60)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <line x1="200" y1="100" x2="249" y2="109" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249" y1="109" x2="249" y2="92" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249" y1="92" x2="200" y2="101" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="101" x2="232" y2="63" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232" y1="63" x2="217" y2="54" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="217" y1="54" x2="200" y2="101" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="101" x2="183" y2="54" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="183" y1="54" x2="168" y2="63" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="168" y1="63" x2="200" y2="101" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="101" x2="151" y2="92" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="151" y1="92" x2="151" y2="109" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="151" y1="109" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="100" x2="168" y2="138" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="168" y1="138" x2="183" y2="147" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="183" y1="147" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="100" x2="217" y2="147" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="217" y1="147" x2="232" y2="138" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232" y1="138" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %%
# Solution

def draw_pie(n, radius):
    """Draws a pie divided into radial segments.

    n: number of segments
    radius: length of the radial spokes
    """
    angle = 360.0 / n
    for i in range(n):
        triangle(radius,  angle/2)
        left(angle)

# %%
make_turtle(delay=0.05)
draw_pie(5, 40)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle11198d460" transform="rotate(-2250.0,200,99) translate(200, 99)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="232" y2="124" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232" y1="124" x2="232" y2="77" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232" y1="77" x2="200" y2="101" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="101" x2="232" y2="77" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232" y1="77" x2="187" y2="62" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="187" y1="62" x2="199" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="199" y1="100" x2="187" y2="62" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="187" y1="62" x2="159" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="159" y1="100" x2="199" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="199" y1="100" x2="159" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="159" y1="100" x2="187" y2="138" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="187" y1="138" x2="199" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="199" y1="100" x2="187" y2="138" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="187" y1="138" x2="232" y2="123" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232" y1="123" x2="200" y2="99" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %%
make_turtle(delay=0.05)
jump(-120)

size = 40
draw_pie(5, size)
jump(2*size)
draw_pie(6, size)
jump(2*size)
draw_pie(7, size)
jump(2*size)
draw_pie(8, size)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1117b0950" transform="rotate(-90.0,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# </svg>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 make_turtle(delay=0.05)
# ----> 2 jump(-120)
#       4 size = 40
#       5 draw_pie(5, size)
#
# NameError: name 'jump' is not defined

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw flowers like this.
#
# Hint: Use `arc` to write a function called `petal` that draws one flower petal.

# %%
# Solution

def petal(radius,  angle):
    """Draws a petal using two arcs.

    t: Turtle
    radius: radius of the arcs
    angle: angle (degrees) that subtends the arcs
    """
    for i in range(2):
        arc(radius,  angle)
        left(180-angle)

# %%
# Solution

def flower(n, radius, angle):
    """Draws a flower with n petals.

    n: number of petals
    radius: radius of the arcs
    angle: angle (degrees) that subtends the arcs
    """
    for i in range(n):
        petal(radius,  angle)
        left(360.0/n)

# %%
make_turtle()

#jump(-100)
flower(7, 60.0, 60.0)

#jump(100)
flower(10, 40.0, 80.0)

#jump(100)
flower(14, 140.0, 20.0)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle111790a70" transform="rotate(-90.0,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# </svg>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 make_turtle()
#       3 #jump(-100)
# ----> 4 flower(7, 60.0, 60.0)
#       6 #jump(100)
#       7 flower(10, 40.0, 80.0)
#
# Cell In[12], line 11, in flower(n, radius, angle)
#       4 """Draws a flower with n petals.
#       5
#       6 n: number of petals
#       7 radius: radius of the arcs
#       8 angle: angle (degrees) that subtends the arcs
#       9 """
#      10 for i in range(n):
# ---> 11     petal(radius,  angle)
#      12     left(360.0/n)
#
# Cell In[11], line 11, in petal(radius, angle)
#       4 """Draws a petal using two arcs.
#       5
#       6 t: Turtle
#       7 radius: radius of the arcs
#       8 angle: angle (degrees) that subtends the arcs
#       9 """
#      10 for i in range(2):
# ---> 11     arc(radius,  angle)
#      12     left(180-angle)
#
# NameError: name 'arc' is not defined

# %% [markdown]
# ### Ask an assistant
#
# There are several modules like `Turtle` in Python, and the one we used in this chapter has been customized for this book.
# So if you ask a virtual assistant for help, it won't know which module to use.
# But if you give it a few examples to work with, it can probably figure it out.
# For example, try this prompt and see if it can write a function that draws a spiral:
#
# ```
# The following program uses a Turtle module to draw a circle:
#
# from Turtle import make_turtle, forward, left
# import math
#
# def polygon(n, length):
#     angle = 360 / n
#     for i in range(n):
#         forward(length)
#         left(angle)
#
# def circle(radius):
#     circumference = 2 * math.pi * radius
#     n = 30
#     length = circumference / n
#     polygon(n, length)
#
# make_turtle(speed=12)
# circle(30)
#
# Write a function that draws a spiral.
# ```

# %% [markdown]
# Keep in mind that the result might use features we have not seen yet, and it might have errors.
# Copy the code from the VA and see if you can get it working.
# If you didn't get what you wanted, try modifying the prompt.

# %%
# Solution

from jupyturtle import make_turtle, forward, right

make_turtle(delay=0.05)

def spiral(length, angle):
    for _ in range(100):
        forward(length)
        right(angle)
        length += 2  # Increase the length for each segment

spiral(5, 90)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle10d507f50" transform="rotate(-90.0,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# </svg>

# %%
# Solution

# prompt: make that a circular spiral, and don't change the name of the module

from Turtle import make_turtle, forward, left
import math

def circular_spiral(radius, angle):
    turtle = make_turtle(speed=12)
    rotations = 5
    distance = 2 * math.pi * radius / 360  # Calculate the distance for each degree of rotation
    for _ in range(rotations * 360):
        forward(distance)
        left(angle)
        radius += 0.1  # Increase the radius for each segment
        distance = 2 * math.pi * radius / 360  # Recalculate the distance for the updated radius

circular_spiral(50, 1)
