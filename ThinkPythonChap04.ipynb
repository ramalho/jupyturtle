# %% [markdown]
# # Code from Downey's _Think Python_
#
# This notebook contains code for examples and exercises from chapter 4,
# _Functions and Interfaces_ of Allen Downey's
# _Think Python Third Edition_ (O'Reilly, 2024) using turtle graphics.
#
# I removed the main text, keeping only the section titles to make it easier to locate the code in the book.
# I also added some very brief comments for context.

# %% [markdown]
# ## The Turtle module
#
# Import the `Turtle` class:

# %%
from jupyturtle import Turtle

# %% [markdown]
# Create `Turtle` object, use a method:

# %%
t = Turtle()
t.forward(100)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="250.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# <g transform="rotate(-90.0,250.0,75.0) translate(250.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Shortcuts for exploratory programming with an imperative API:

# %%
from jupyturtle import fd
fd(100)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="250.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="250.0" y1="75.0" x2="250.0" y2="25.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# <g transform="rotate(180.0,250.0,25.0) translate(250.0, 25.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# The `fd()` call created a new turtle and drawing.
# Further commands will update that same drawing.

# %% [markdown]
# Import more functions:

# %%
from jupyturtle import lt, rt, fd

# %% [markdown]
# Experiment with `left`, aliased to `lt`.

# %%
lt(90)
fd(50)

# %% [markdown]
# ## Making a square

# %%
from jupyturtle import make_turtle, forward, left

make_turtle()

forward(50)
left(90)

forward(50)
left(90)

forward(50)
left(90)

forward(50)
left(90)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Using a `for` loop.

# %%
make_turtle()
for i in range(4):
    forward(50)
    left(90)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## Encapsulation and generalization
#
# Write function

# %%
def square():
    for i in range(4):
        forward(50)
        left(90)

# %% [markdown]
# Call it.

# %%
make_turtle()
square()
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Function with parameter

# %%
def square(length):
    for i in range(4):
        forward(length)
        left(90)

# %% [markdown]
# Now we can draw squares with different sizes.

# %%
make_turtle()
square(30)
square(60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="180.0" y1="75.0" x2="180.0" y2="45.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="180.0" y1="45.0" x2="150.0" y2="45.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="45.0" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="75.0" x2="210.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="210.0" y1="75.0" x2="210.0" y2="15.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="210.0" y1="15.0" x2="150.0" y2="15.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="15.0" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Generalization:

# %%
def polygon(n, length):
    angle = 360 / n
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# Example:

# %%
make_turtle()
polygon(7, 30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="180.0" y1="75.0" x2="198.7" y2="51.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="198.7" y1="51.5" x2="192.0" y2="22.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="192.0" y1="22.3" x2="165.0" y2="9.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="165.0" y1="9.3" x2="138.0" y2="22.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="138.0" y1="22.3" x2="131.3" y2="51.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="131.3" y1="51.5" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# <g transform="rotate(270.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Named arguments:

# %%
make_turtle()
polygon(n=7, length=30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="180.0" y1="75.0" x2="198.7" y2="51.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="198.7" y1="51.5" x2="192.0" y2="22.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="192.0" y1="22.3" x2="165.0" y2="9.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="165.0" y1="9.3" x2="138.0" y2="22.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="138.0" y1="22.3" x2="131.3" y2="51.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="131.3" y1="51.5" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# <g transform="rotate(270.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## Approximating a circle
#
# To draw a circle:

# %%
import math

def circle(radius):
    circumference = 2 * math.pi * radius
    n = 30
    length = circumference / n
    polygon(n, length)

# %% [markdown]
# The `delay` argument:

# %%
make_turtle(delay=.01)
circle(30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="156.3" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="156.3" y1="75.0" x2="162.4" y2="73.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="162.4" y1="73.7" x2="168.2" y2="71.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="168.2" y1="71.1" x2="173.3" y2="67.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="173.3" y1="67.4" x2="177.5" y2="62.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.5" y1="62.8" x2="180.6" y2="57.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="180.6" y1="57.3" x2="182.5" y2="51.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="182.5" y1="51.4" x2="183.2" y2="45.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="183.2" y1="45.1" x2="182.5" y2="38.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="182.5" y1="38.9" x2="180.6" y2="32.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="180.6" y1="32.9" x2="177.5" y2="27.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.5" y1="27.4" x2="173.3" y2="22.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="173.3" y1="22.8" x2="168.2" y2="19.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="168.2" y1="19.1" x2="162.4" y2="16.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="162.4" y1="16.5" x2="156.3" y2="15.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="156.3" y1="15.2" x2="150.0" y2="15.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="15.2" x2="143.9" y2="16.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="143.9" y1="16.5" x2="138.1" y2="19.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="138.1" y1="19.1" x2="133.0" y2="22.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="133.0" y1="22.8" x2="128.8" y2="27.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="128.8" y1="27.4" x2="125.7" y2="32.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="125.7" y1="32.9" x2="123.7" y2="38.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="123.7" y1="38.9" x2="123.1" y2="45.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="123.1" y1="45.1" x2="123.7" y2="51.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="123.7" y1="51.4" x2="125.7" y2="57.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="125.7" y1="57.3" x2="128.8" y2="62.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="128.8" y1="62.8" x2="133.0" y2="67.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="133.0" y1="67.4" x2="138.1" y2="71.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="138.1" y1="71.1" x2="143.9" y2="73.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="143.9" y1="73.7" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## Refactoring
#
# `polyline`, a more general version of `polygon`:

# %%
def polyline(n, length, angle):
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# Parameters:
#
# `n`: number of segments to draw
#
# `length`: length each segment
#
# `angle`: angle between them
#
# New `polygon` using `polyline`:

# %%
def polygon(n, length):
    angle = 360.0 / n
    polyline(n, length, angle)

# %% [markdown]
# Use `polyline` to write `arc`:

# %%
def arc(radius, angle):
    arc_length = 2 * math.pi * radius * angle / 360
    n = 30
    length = arc_length / n
    step_angle = float(angle) / n
    polyline(n, length, step_angle)

# %% [markdown]
# Rewrite `circle` to use `arc`:

# %%
def circle(radius):
    arc(radius,  360)

# %% [markdown]
# To check that these functions work as expected, we'll use them to draw something like a snail.

# %%
make_turtle(delay=0)
polygon(n=20, length=9)
arc(radius=70, angle=70)
circle(radius=10)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="159.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="159.0" y1="75.0" x2="167.6" y2="72.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="167.6" y1="72.2" x2="174.8" y2="66.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="174.8" y1="66.9" x2="180.1" y2="59.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="180.1" y1="59.6" x2="182.9" y2="51.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="182.9" y1="51.1" x2="182.9" y2="42.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="182.9" y1="42.1" x2="180.1" y2="33.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="180.1" y1="33.5" x2="174.8" y2="26.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="174.8" y1="26.2" x2="167.6" y2="21.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="167.6" y1="21.0" x2="159.0" y2="18.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="159.0" y1="18.2" x2="150.0" y2="18.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="18.2" x2="141.4" y2="21.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="141.4" y1="21.0" x2="134.2" y2="26.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="134.2" y1="26.2" x2="128.9" y2="33.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="128.9" y1="33.5" x2="126.1" y2="42.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="126.1" y1="42.1" x2="126.1" y2="51.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="126.1" y1="51.1" x2="128.9" y2="59.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="128.9" y1="59.6" x2="134.2" y2="66.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="134.2" y1="66.9" x2="141.4" y2="72.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="141.4" y1="72.2" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="75.0" x2="152.9" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="152.9" y1="75.0" x2="155.7" y2="74.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="155.7" y1="74.9" x2="158.5" y2="74.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="158.5" y1="74.7" x2="161.4" y2="74.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="161.4" y1="74.3" x2="164.2" y2="73.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="164.2" y1="73.8" x2="167.0" y2="73.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="167.0" y1="73.3" x2="169.7" y2="72.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="169.7" y1="72.6" x2="172.5" y2="71.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="172.5" y1="71.8" x2="175.2" y2="70.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="175.2" y1="70.9" x2="177.8" y2="69.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.8" y1="69.8" x2="180.5" y2="68.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="180.5" y1="68.7" x2="183.0" y2="67.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="183.0" y1="67.5" x2="185.5" y2="66.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="185.5" y1="66.1" x2="188.0" y2="64.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="188.0" y1="64.7" x2="190.4" y2="63.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="190.4" y1="63.2" x2="192.7" y2="61.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="192.7" y1="61.5" x2="195.0" y2="59.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="195.0" y1="59.8" x2="197.2" y2="58.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="197.2" y1="58.0" x2="199.3" y2="56.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="199.3" y1="56.1" x2="201.4" y2="54.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="201.4" y1="54.1" x2="203.3" y2="52.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="203.3" y1="52.0" x2="205.2" y2="49.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="205.2" y1="49.9" x2="207.0" y2="47.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="207.0" y1="47.6" x2="208.7" y2="45.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="208.7" y1="45.3" x2="210.2" y2="43.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="210.2" y1="43.0" x2="211.7" y2="40.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="211.7" y1="40.5" x2="213.1" y2="38.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="213.1" y1="38.1" x2="214.4" y2="35.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="214.4" y1="35.5" x2="215.6" y2="32.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="215.6" y1="32.9" x2="216.7" y2="30.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="216.7" y1="30.3" x2="217.4" y2="28.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="217.4" y1="28.3" x2="217.7" y2="26.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="217.7" y1="26.2" x2="217.6" y2="24.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="217.6" y1="24.2" x2="217.0" y2="22.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="217.0" y1="22.1" x2="216.0" y2="20.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="216.0" y1="20.3" x2="214.7" y2="18.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="214.7" y1="18.7" x2="213.0" y2="17.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="213.0" y1="17.4" x2="211.1" y2="16.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="211.1" y1="16.5" x2="209.1" y2="16.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="209.1" y1="16.0" x2="207.0" y2="15.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="207.0" y1="15.9" x2="204.9" y2="16.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="204.9" y1="16.3" x2="203.0" y2="17.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="203.0" y1="17.0" x2="201.3" y2="18.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="201.3" y1="18.2" x2="199.8" y2="19.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="199.8" y1="19.7" x2="198.7" y2="21.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="198.7" y1="21.5" x2="198.0" y2="23.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="198.0" y1="23.5" x2="197.7" y2="25.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="197.7" y1="25.5" x2="197.8" y2="27.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="197.8" y1="27.6" x2="198.4" y2="29.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="198.4" y1="29.6" x2="199.4" y2="31.5" str

# %% [markdown]
# ## Stack diagram
#
# (no turtle examples in this section)

# %% [markdown]
# ## Docstrings
#
# `polyline` with docstring:

# %%
def polyline(n, length, angle):
    """Draws line segments with the given length and angle between them.

    n: integer number of line segments
    length: length of the line segments
    angle: angle between segments (in degrees)
    """
    for i in range(n):
        forward(length)
        left(angle)

# %%
make_turtle(delay=0.5)
polyline(9, 30, 36)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="180.0" y1="75.0" x2="204.3" y2="57.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="204.3" y1="57.4" x2="213.5" y2="28.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="213.5" y1="28.8" x2="204.3" y2="0.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="204.3" y1="0.3" x2="180.0" y2="-17.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="180.0" y1="-17.3" x2="150.0" y2="-17.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="-17.3" x2="125.7" y2="0.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="125.7" y1="0.3" x2="116.5" y2="28.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="116.5" y1="28.8" x2="125.7" y2="57.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# <g transform="rotate(-54.0,125.7,57.4) translate(125.7, 57.4)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## Debugging
#
# (no turtle examples in this section)

# %% [markdown]
# ## Glossary
#
# (no turtle examples in this section)

# %% [markdown]
# ## Exercises
#
# `penup` and `pendown`

# %%
from jupyturtle import forward, penup, pendown

def jump(length):
    """Move forward length units without leaving a trail.

    Postcondition: Leaves the pen down.
    """
    penup()
    forward(length)
    pendown()

# %% [markdown]
# ### Exercise
#
# Draw a rectangle:

# %%
# Solution

def rectangle(length1, length2):
    """Draw a rectangle with the given lengths.

    length1: length of the first side
    length2: length of the second size
    """
    for i in range(2):
        forward(length1)
        left(90)
        forward(length2)
        left(90)

# %%
make_turtle()
rectangle(80, 40)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="230.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="230.0" y1="75.0" x2="230.0" y2="35.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="230.0" y1="35.0" x2="150.0" y2="35.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="35.0" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Draw a rhombus:

# %%
def rhombus(length, angle):
    for i in range(2):
        forward(length)
        left(angle)
        forward(length)
        left(180-angle)

# %%
make_turtle()
rhombus(50, 60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="200.0" y1="75.0" x2="225.0" y2="31.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="225.0" y1="31.7" x2="175.0" y2="31.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="175.0" y1="31.7" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write `parallelogram`, then rewrite `rectangle` and `rhombus` to use it:

# %%
# Solution

def parallelogram(length1, length2, angle):
    for i in range(2):
        forward(length1)
        left(angle)
        forward(length2)
        left(180-angle)

# %%
# Solution

def rectangle(length1, length2):
    """Draw a rectangle with the given lengths.

    length1: length of the first side
    length2: length of the second size
    """
    parallelogram(length1, length2, 90)

# %%
# Solution

def rhombus(length, angle):
    parallelogram(length, length, angle)

# %%
make_turtle(delay=0.05)
jump(-120)

rectangle(80, 40)
jump(100)
rhombus(50, 60)
jump(80)
parallelogram(80, 50, 60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="30.0" y1="75.0" x2="110.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="110.0" y1="75.0" x2="110.0" y2="35.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="110.0" y1="35.0" x2="30.0" y2="35.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="30.0" y1="35.0" x2="30.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="130.0" y1="75.0" x2="180.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="180.0" y1="75.0" x2="205.0" y2="31.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="205.0" y1="31.7" x2="155.0" y2="31.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="155.0" y1="31.7" x2="130.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="210.0" y1="75.0" x2="290.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="290.0" y1="75.0" x2="315.0" y2="31.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="315.0" y1="31.7" x2="235.0" y2="31.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="235.0" y1="31.7" x2="210.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# <g transform="rotate(-90.0,210.0,75.0) translate(210.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# A `triangle` function:

# %%
# Solution
import math

from jupyturtle import forward, left, right

def triangle(radius,  angle):
    """Draws an icosceles triangle.

    The turtle starts and ends at the peak, facing the middle of the base.

    radius: length of the equal legs
    angle: half peak angle in degrees
    """
    y = radius * math.sin(angle * math.pi / 180)

    right(angle)
    forward(radius)
    left(90+angle)
    forward(2*y)
    left(90+angle)
    forward(radius)
    left(180-angle)

# %% [markdown]
# (a little demonstration)

# %%
from jupyturtle import make_turtle, hide
make_turtle(delay=0)
hide()

for i in range(12):
    triangle(50, 10)
    left(30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="199.2" y2="83.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="199.2" y1="83.7" x2="199.2" y2="66.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="199.2" y1="66.3" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="75.0" x2="197.0" y2="57.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="197.0" y1="57.9" x2="188.3" y2="42.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="188.3" y1="42.9" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="75.0" x2="182.1" y2="36.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="182.1" y1="36.7" x2="167.1" y2="28.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="167.1" y1="28.0" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="75.0" x2="158.7" y2="25.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="158.7" y1="25.8" x2="141.3" y2="25.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="141.3" y1="25.8" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="75.0" x2="132.9" y2="28.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="132.9" y1="28.0" x2="117.9" y2="36.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="117.9" y1="36.7" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="75.0" x2="111.7" y2="42.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="111.7" y1="42.9" x2="103.0" y2="57.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="103.0" y1="57.9" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="75.0" x2="100.8" y2="66.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="100.8" y1="66.3" x2="100.8" y2="83.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="100.8" y1="83.7" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="75.0" x2="103.0" y2="92.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="103.0" y1="92.1" x2="111.7" y2="107.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="111.7" y1="107.1" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="75.0" x2="117.9" y2="113.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="117.9" y1="113.3" x2="132.9" y2="122.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="132.9" y1="122.0" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="75.0" x2="141.3" y2="124.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="141.3" y1="124.2" x2="158.7" y2="124.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="158.7" y1="124.2" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="75.0" x2="167.1" y2="122.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="167.1" y1="122.0" x2="182.1" y2="113.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="182.1" y1="113.3" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="75.0" x2="188.3" y2="107.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="188.3" y1="107.1" x2="197.0" y2="92.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="197.0" y1="92.1" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# </svg>

# %%
# Solution

def draw_pie(n, radius):
    """Draws a pie divided into radial segments.

    n: number of segments
    radius: length of the radial spokes
    """
    angle = 360.0 / n
    for i in range(n):
        triangle(radius,  angle/2)
        left(angle)

# %%
make_turtle(delay=0.01)
draw_pie(5, 40)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="182.4" y2="98.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="182.4" y1="98.5" x2="182.4" y2="51.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="182.4" y1="51.5" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="75.0" x2="182.4" y2="51.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="182.4" y1="51.5" x2="137.6" y2="37.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="137.6" y1="37.0" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="75.0" x2="137.6" y2="37.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="137.6" y1="37.0" x2="110.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="110.0" y1="75.0" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="75.0" x2="110.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="110.0" y1="75.0" x2="137.6" y2="113.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="137.6" y1="113.0" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="75.0" x2="137.6" y2="113.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="137.6" y1="113.0" x2="182.4" y2="98.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="182.4" y1="98.5" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
make_turtle(delay=0.01)
jump(-120)

size = 40
draw_pie(5, size)
jump(2*size)
draw_pie(6, size)
jump(2*size)
draw_pie(7, size)
jump(2*size)
draw_pie(8, size)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="30.0" y1="75.0" x2="62.4" y2="98.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="62.4" y1="98.5" x2="62.4" y2="51.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="62.4" y1="51.5" x2="30.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="30.0" y1="75.0" x2="62.4" y2="51.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="62.4" y1="51.5" x2="17.6" y2="37.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="17.6" y1="37.0" x2="30.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="30.0" y1="75.0" x2="17.6" y2="37.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="17.6" y1="37.0" x2="-10.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="-10.0" y1="75.0" x2="30.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="30.0" y1="75.0" x2="-10.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="-10.0" y1="75.0" x2="17.6" y2="113.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="17.6" y1="113.0" x2="30.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="30.0" y1="75.0" x2="17.6" y2="113.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="17.6" y1="113.0" x2="62.4" y2="98.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="62.4" y1="98.5" x2="30.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="110.0" y1="75.0" x2="144.6" y2="95.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="144.6" y1="95.0" x2="144.6" y2="55.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="144.6" y1="55.0" x2="110.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="110.0" y1="75.0" x2="144.6" y2="55.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="144.6" y1="55.0" x2="110.0" y2="35.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="110.0" y1="35.0" x2="110.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="110.0" y1="75.0" x2="110.0" y2="35.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="110.0" y1="35.0" x2="75.4" y2="55.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="75.4" y1="55.0" x2="110.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="110.0" y1="75.0" x2="75.4" y2="55.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="75.4" y1="55.0" x2="75.4" y2="95.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="75.4" y1="95.0" x2="110.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="110.0" y1="75.0" x2="75.4" y2="95.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="75.4" y1="95.0" x2="110.0" y2="115.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="110.0" y1="115.0" x2="110.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="110.0" y1="75.0" x2="110.0" y2="115.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="110.0" y1="115.0" x2="144.6" y2="95.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="144.6" y1="95.0" x2="110.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="190.0" y1="75.0" x2="226.0" y2="92.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="226.0" y1="92.4" x2="226.0" y2="57.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="226.0" y1="57.6" x2="190.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="190.0" y1="75.0" x2="226.0" y2="57.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="226.0" y1="57.6" x2="198.9" y2="36.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="198.9" y1="36.0" x2="190.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="190.0" y1="75.0" x2="198.9" y2="36.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="198.9" y1="36.0" x2="165.1" y2="43.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="165.1" y1="43.7" x2="190.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="190.0" y1="75.0" x2="165.1" y2="43.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="165.1" y1="43.7" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="75.0" x2="190.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="190.0" y1="75.0" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.0" y1="75.0" x2="165.1" y2="106.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="165.1" y1="106.3" x2="190.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="190.0" y1="75.0" x2="165.1" y2="106.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="165.1" y1="106.3" x2="198.9" y2="114.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="198.9" y1="114.0" x2="190.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="190.0" y1="75.0" x2="198.9" y2="114.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="198.9" y1="114.0" x2="226.0" y2="92.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="226.0" y1="92.4" x2="190.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="270.0" y1="75.0" x2="307.0" y2="90.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="307.0" y1="90.3" x2="307.0" y2="59.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="307.0" y1="59.7" x2="270.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="270.0" y1="75.0" x2="307.0" y2="59.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="307.0" y1="59.7" x2="285.3" y2="38.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="285.3" y1="38.0" x2="270.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="270.0" y1="75.0" x2="285.3" y2="38.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="285.3" y1="38.0" x2="254.7" y2="38.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="254.7" y1="38.0" x2="270.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="270.0" y1="75.0" x2="254.7" y2="38.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="254.7" y1="38.0" x2="233.0" y2="59.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="233.0" y1="59.7" x2="270.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="270.0" y1="75.0" x2="233.0" y2="59.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="233.0" y1="59.7" x2="233.0" y2="90.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="233.0" y1="90.3" x2="270.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="270.0" y1="75.0" x2="233.0" y2="90.3" stroke-linecap="r

# %% [markdown]
# ### Exercise
#
# Draw flowers with `petal`:

# %%
# Solution

def petal(radius,  angle):
    """Draws a petal using two arcs.

    t: Turtle
    radius: radius of the arcs
    angle: angle (degrees) that subtends the arcs
    """
    for i in range(2):
        arc(radius,  angle)
        left(180-angle)

# %%
# Solution

def flower(n, radius, angle):
    """Draws a flower with n petals.

    n: number of petals
    radius: radius of the arcs
    angle: angle (degrees) that subtends the arcs
    """
    for i in range(n):
        petal(radius,  angle)
        left(360/n)

# %%
make_turtle(delay=0)

jump(-100)
flower(7, 60.0, 60.0)

jump(100)
flower(10, 40.0, 80.0)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="50.0" y1="75.0" x2="52.1" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="52.1" y1="75.0" x2="54.2" y2="74.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="54.2" y1="74.9" x2="56.3" y2="74.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="56.3" y1="74.8" x2="58.4" y2="74.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="58.4" y1="74.6" x2="60.4" y2="74.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="60.4" y1="74.3" x2="62.5" y2="73.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="62.5" y1="73.9" x2="64.5" y2="73.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="64.5" y1="73.5" x2="66.6" y2="73.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="66.6" y1="73.0" x2="68.6" y2="72.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="68.6" y1="72.4" x2="70.6" y2="71.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="70.6" y1="71.7" x2="72.6" y2="71.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="72.6" y1="71.0" x2="74.5" y2="70.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="74.5" y1="70.2" x2="76.4" y2="69.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="76.4" y1="69.4" x2="78.3" y2="68.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="78.3" y1="68.5" x2="80.1" y2="67.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="80.1" y1="67.5" x2="82.0" y2="66.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="82.0" y1="66.4" x2="83.7" y2="65.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="83.7" y1="65.3" x2="85.5" y2="64.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="85.5" y1="64.2" x2="87.2" y2="62.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="87.2" y1="62.9" x2="88.8" y2="61.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="88.8" y1="61.6" x2="90.4" y2="60.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="90.4" y1="60.3" x2="92.0" y2="58.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="92.0" y1="58.9" x2="93.5" y2="57.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="93.5" y1="57.4" x2="94.9" y2="55.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="94.9" y1="55.9" x2="96.3" y2="54.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="96.3" y1="54.4" x2="97.7" y2="52.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="97.7" y1="52.8" x2="99.0" y2="51.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="99.0" y1="51.1" x2="100.2" y2="49.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="100.2" y1="49.4" x2="101.4" y2="47.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="101.4" y1="47.7" x2="102.5" y2="45.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="102.5" y1="45.9" x2="100.4" y2="45.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="100.4" y1="45.9" x2="98.3" y2="46.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="98.3" y1="46.0" x2="96.2" y2="46.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="96.2" y1="46.1" x2="94.1" y2="46.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="94.1" y1="46.3" x2="92.0" y2="46.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="92.0" y1="46.6" x2="90.0" y2="47.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="90.0" y1="47.0" x2="87.9" y2="47.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="87.9" y1="47.4" x2="85.9" y2="47.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="85.9" y1="47.9" x2="83.9" y2="48.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="83.9" y1="48.5" x2="81.9" y2="49.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="81.9" y1="49.2" x2="79.9" y2="49.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="79.9" y1="49.9" x2="78.0" y2="50.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="78.0" y1="50.7" x2="76.1" y2="51.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="76.1" y1="51.5" x2="74.2" y2="52.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="74.2" y1="52.4" x2="72.3" y2="53.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="72.3" y1="53.4" x2="70.5" y2="54.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="70.5" y1="54.5" x2="68.8" y2="55.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="68.8" y1="55.6" x2="67.0" y2="56.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="67.0" y1="56.8" x2="65.3" y2="58.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="65.3" y1="58.0" x2="63.7" y2="59.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="63.7" y1="59.3" x2="62.1" y2="60.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="62.1" y1="60.6" x2="60.5" y2="62.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="60.5" y1="62.0" x2="59.0" y2="63.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="59.0" y1="63.5" x2="57.5" y2="65.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="57.5" y1="65.0" x2="56.1" y2="66.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="56.1" y1="66.5" x2="54.8" y2="68.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="54.8" y1="68.1" x2="53.5" y2="69.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="53.5" y1="69.8" x2="52.3" y2="71.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="52.3" y1="71.5" x2="51.1" y2="73.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="51.1" y1="73.2" x2="50.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="50.0" y1="75.0" x2="51.3" y2="73.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="51.3" y1="73.4" x2="52.6" y2="71.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="52.6" y1="71.7" x2="53.7" y2="70.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="53.7" y1="70.0" x2="54.9" y2="68.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="54.9" y1="68.2" x2="55.9" y2="66.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="55.9" y1="66.4" x2="56.9" y2="64.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="56.9" y1="64.5" x2="57.9" y2="62.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="57.9" y1="62.7" x2="58.7" y2="60.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="58.7" y1="60.8" x2="59.5" y2="58.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="59.5" y1="58.8" x2="60.3" y2="56.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="60.3" y1="56.9" x2="61.0" y2="54.9" stroke-linecap="rou

# %% [markdown]
# The next drawing has lots of small lines, so it may be very slow or even crash you browser.

# %%
# WARNING: slow, may freeze your browser

make_turtle(delay=0) # start a new drawing
hide() # don't draw the turtle
jump(100)
flower(14, 140.0, 20.0)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="250.0" y1="75.0" x2="251.6" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="251.6" y1="75.0" x2="253.3" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="253.3" y1="75.0" x2="254.9" y2="74.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="254.9" y1="74.9" x2="256.5" y2="74.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="256.5" y1="74.9" x2="258.1" y2="74.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="258.1" y1="74.8" x2="259.8" y2="74.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="259.8" y1="74.7" x2="261.4" y2="74.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="261.4" y1="74.6" x2="263.0" y2="74.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="263.0" y1="74.5" x2="264.6" y2="74.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="264.6" y1="74.3" x2="266.3" y2="74.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="266.3" y1="74.1" x2="267.9" y2="74.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="267.9" y1="74.0" x2="269.5" y2="73.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="269.5" y1="73.8" x2="271.1" y2="73.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="271.1" y1="73.5" x2="272.7" y2="73.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="272.7" y1="73.3" x2="274.3" y2="73.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="274.3" y1="73.0" x2="275.9" y2="72.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="275.9" y1="72.7" x2="277.5" y2="72.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="277.5" y1="72.4" x2="279.1" y2="72.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="279.1" y1="72.1" x2="280.7" y2="71.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="280.7" y1="71.8" x2="282.3" y2="71.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="282.3" y1="71.4" x2="283.9" y2="71.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="283.9" y1="71.0" x2="285.5" y2="70.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="285.5" y1="70.6" x2="287.0" y2="70.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="287.0" y1="70.2" x2="288.6" y2="69.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="288.6" y1="69.8" x2="290.2" y2="69.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="290.2" y1="69.4" x2="291.7" y2="68.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="291.7" y1="68.9" x2="293.3" y2="68.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="293.3" y1="68.4" x2="294.9" y2="67.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="294.9" y1="67.9" x2="296.4" y2="67.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="296.4" y1="67.4" x2="297.9" y2="66.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="297.9" y1="66.8" x2="296.3" y2="66.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="296.3" y1="66.8" x2="294.7" y2="66.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="294.7" y1="66.9" x2="293.0" y2="66.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="293.0" y1="66.9" x2="291.4" y2="66.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="291.4" y1="66.9" x2="289.8" y2="67.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="289.8" y1="67.0" x2="288.2" y2="67.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="288.2" y1="67.1" x2="286.5" y2="67.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="286.5" y1="67.2" x2="284.9" y2="67.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="284.9" y1="67.4" x2="283.3" y2="67.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="283.3" y1="67.5" x2="281.7" y2="67.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="281.7" y1="67.7" x2="280.1" y2="67.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="280.1" y1="67.9" x2="278.4" y2="68.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="278.4" y1="68.1" x2="276.8" y2="68.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="276.8" y1="68.3" x2="275.2" y2="68.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="275.2" y1="68.6" x2="273.6" y2="68.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="273.6" y1="68.8" x2="272.0" y2="69.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="272.0" y1="69.1" x2="270.4" y2="69.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="270.4" y1="69.4" x2="268.8" y2="69.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="268.8" y1="69.7" x2="267.2" y2="70.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="267.2" y1="70.1" x2="265.6" y2="70.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="265.6" y1="70.4" x2="264.0" y2="70.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="264.0" y1="70.8" x2="262.5" y2="71.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="262.5" y1="71.2" x2="260.9" y2="71.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="260.9" y1="71.6" x2="259.3" y2="72.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="259.3" y1="72.0" x2="257.7" y2="72.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="257.7" y1="72.5" x2="256.2" y2="73.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="256.2" y1="73.0" x2="254.6" y2="73.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="254.6" y1="73.4" x2="253.1" y2="73.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="253.1" y1="73.9" x2="251.5" y2="74.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="251.5" y1="74.5" x2="250.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="250.0" y1="75.0" x2="251.5" y2="74.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="251.5" y1="74.3" x2="252.9" y2="73.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="252.9" y1="73.6" x2="254.4" y2="72.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="254.4" y1="72.8" x2="255.8" y2="72.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="255.8" y1="72.1" x2="257.3" y2="71.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="257.3" y1="71.3" x2="258.7" y2="70.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="258.7" y1="70.5" x2="260.1" y2="69.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="260.1" y1="69.7" x2="261.5" y2="68.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="261.5" y1="68.9" x2="262.9" y2="68.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="262.9" y1="68.0" x2="264.3" y2="67.2"

# %% [markdown]
# For faster results, set `auto_render` to `False`.
# The drawing will only be rendered when you call `render()`.

# %%
from jupyturtle import get_turtle, render

make_turtle(auto_render=False)
hide()
jump(100)
flower(14, 140.0, 20.0)
render()
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="250.0" y1="75.0" x2="251.6" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="251.6" y1="75.0" x2="253.3" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="253.3" y1="75.0" x2="254.9" y2="74.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="254.9" y1="74.9" x2="256.5" y2="74.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="256.5" y1="74.9" x2="258.1" y2="74.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="258.1" y1="74.8" x2="259.8" y2="74.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="259.8" y1="74.7" x2="261.4" y2="74.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="261.4" y1="74.6" x2="263.0" y2="74.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="263.0" y1="74.5" x2="264.6" y2="74.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="264.6" y1="74.3" x2="266.3" y2="74.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="266.3" y1="74.1" x2="267.9" y2="74.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="267.9" y1="74.0" x2="269.5" y2="73.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="269.5" y1="73.8" x2="271.1" y2="73.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="271.1" y1="73.5" x2="272.7" y2="73.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="272.7" y1="73.3" x2="274.3" y2="73.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="274.3" y1="73.0" x2="275.9" y2="72.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="275.9" y1="72.7" x2="277.5" y2="72.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="277.5" y1="72.4" x2="279.1" y2="72.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="279.1" y1="72.1" x2="280.7" y2="71.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="280.7" y1="71.8" x2="282.3" y2="71.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="282.3" y1="71.4" x2="283.9" y2="71.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="283.9" y1="71.0" x2="285.5" y2="70.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="285.5" y1="70.6" x2="287.0" y2="70.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="287.0" y1="70.2" x2="288.6" y2="69.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="288.6" y1="69.8" x2="290.2" y2="69.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="290.2" y1="69.4" x2="291.7" y2="68.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="291.7" y1="68.9" x2="293.3" y2="68.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="293.3" y1="68.4" x2="294.9" y2="67.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="294.9" y1="67.9" x2="296.4" y2="67.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="296.4" y1="67.4" x2="297.9" y2="66.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="297.9" y1="66.8" x2="296.3" y2="66.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="296.3" y1="66.8" x2="294.7" y2="66.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="294.7" y1="66.9" x2="293.0" y2="66.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="293.0" y1="66.9" x2="291.4" y2="66.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="291.4" y1="66.9" x2="289.8" y2="67.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="289.8" y1="67.0" x2="288.2" y2="67.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="288.2" y1="67.1" x2="286.5" y2="67.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="286.5" y1="67.2" x2="284.9" y2="67.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="284.9" y1="67.4" x2="283.3" y2="67.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="283.3" y1="67.5" x2="281.7" y2="67.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="281.7" y1="67.7" x2="280.1" y2="67.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="280.1" y1="67.9" x2="278.4" y2="68.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="278.4" y1="68.1" x2="276.8" y2="68.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="276.8" y1="68.3" x2="275.2" y2="68.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="275.2" y1="68.6" x2="273.6" y2="68.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="273.6" y1="68.8" x2="272.0" y2="69.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="272.0" y1="69.1" x2="270.4" y2="69.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="270.4" y1="69.4" x2="268.8" y2="69.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="268.8" y1="69.7" x2="267.2" y2="70.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="267.2" y1="70.1" x2="265.6" y2="70.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="265.6" y1="70.4" x2="264.0" y2="70.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="264.0" y1="70.8" x2="262.5" y2="71.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="262.5" y1="71.2" x2="260.9" y2="71.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="260.9" y1="71.6" x2="259.3" y2="72.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="259.3" y1="72.0" x2="257.7" y2="72.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="257.7" y1="72.5" x2="256.2" y2="73.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="256.2" y1="73.0" x2="254.6" y2="73.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="254.6" y1="73.4" x2="253.1" y2="73.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="253.1" y1="73.9" x2="251.5" y2="74.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="251.5" y1="74.5" x2="250.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="250.0" y1="75.0" x2="251.5" y2="74.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="251.5" y1="74.3" x2="252.9" y2="73.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="252.9" y1="73.6" x2="254.4" y2="72.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="254.4" y1="72.8" x2="255.8" y2="72.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="255.8" y1="72.1" x2="257.3" y2="71.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="257.3" y1="71.3" x2="258.7" y2="70.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="258.7" y1="70.5" x2="260.1" y2="69.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="260.1" y1="69.7" x2="261.5" y2="68.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="261.5" y1="68.9" x2="262.9" y2="68.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="262.9" y1="68.0" x2="264.3" y2="67.2"

# %% [markdown]
# When a turtle is used in a `with` statement,
# the drawing is rendered only at the end of the `with` block.
# In this case, the `auto_render` setting is preserved but
# set to `False` within the block.
# The `delay` has no effect within the block.

# %%
from jupyturtle import get_turtle

with make_turtle():
    hide()
    jump(100)
    flower(14, 140.0, 20.0)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="250.0" y1="75.0" x2="251.6" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="251.6" y1="75.0" x2="253.3" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="253.3" y1="75.0" x2="254.9" y2="74.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="254.9" y1="74.9" x2="256.5" y2="74.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="256.5" y1="74.9" x2="258.1" y2="74.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="258.1" y1="74.8" x2="259.8" y2="74.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="259.8" y1="74.7" x2="261.4" y2="74.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="261.4" y1="74.6" x2="263.0" y2="74.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="263.0" y1="74.5" x2="264.6" y2="74.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="264.6" y1="74.3" x2="266.3" y2="74.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="266.3" y1="74.1" x2="267.9" y2="74.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="267.9" y1="74.0" x2="269.5" y2="73.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="269.5" y1="73.8" x2="271.1" y2="73.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="271.1" y1="73.5" x2="272.7" y2="73.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="272.7" y1="73.3" x2="274.3" y2="73.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="274.3" y1="73.0" x2="275.9" y2="72.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="275.9" y1="72.7" x2="277.5" y2="72.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="277.5" y1="72.4" x2="279.1" y2="72.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="279.1" y1="72.1" x2="280.7" y2="71.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="280.7" y1="71.8" x2="282.3" y2="71.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="282.3" y1="71.4" x2="283.9" y2="71.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="283.9" y1="71.0" x2="285.5" y2="70.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="285.5" y1="70.6" x2="287.0" y2="70.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="287.0" y1="70.2" x2="288.6" y2="69.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="288.6" y1="69.8" x2="290.2" y2="69.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="290.2" y1="69.4" x2="291.7" y2="68.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="291.7" y1="68.9" x2="293.3" y2="68.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="293.3" y1="68.4" x2="294.9" y2="67.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="294.9" y1="67.9" x2="296.4" y2="67.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="296.4" y1="67.4" x2="297.9" y2="66.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="297.9" y1="66.8" x2="296.3" y2="66.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="296.3" y1="66.8" x2="294.7" y2="66.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="294.7" y1="66.9" x2="293.0" y2="66.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="293.0" y1="66.9" x2="291.4" y2="66.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="291.4" y1="66.9" x2="289.8" y2="67.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="289.8" y1="67.0" x2="288.2" y2="67.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="288.2" y1="67.1" x2="286.5" y2="67.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="286.5" y1="67.2" x2="284.9" y2="67.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="284.9" y1="67.4" x2="283.3" y2="67.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="283.3" y1="67.5" x2="281.7" y2="67.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="281.7" y1="67.7" x2="280.1" y2="67.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="280.1" y1="67.9" x2="278.4" y2="68.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="278.4" y1="68.1" x2="276.8" y2="68.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="276.8" y1="68.3" x2="275.2" y2="68.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="275.2" y1="68.6" x2="273.6" y2="68.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="273.6" y1="68.8" x2="272.0" y2="69.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="272.0" y1="69.1" x2="270.4" y2="69.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="270.4" y1="69.4" x2="268.8" y2="69.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="268.8" y1="69.7" x2="267.2" y2="70.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="267.2" y1="70.1" x2="265.6" y2="70.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="265.6" y1="70.4" x2="264.0" y2="70.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="264.0" y1="70.8" x2="262.5" y2="71.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="262.5" y1="71.2" x2="260.9" y2="71.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="260.9" y1="71.6" x2="259.3" y2="72.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="259.3" y1="72.0" x2="257.7" y2="72.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="257.7" y1="72.5" x2="256.2" y2="73.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="256.2" y1="73.0" x2="254.6" y2="73.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="254.6" y1="73.4" x2="253.1" y2="73.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="253.1" y1="73.9" x2="251.5" y2="74.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="251.5" y1="74.5" x2="250.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="250.0" y1="75.0" x2="251.5" y2="74.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="251.5" y1="74.3" x2="252.9" y2="73.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="252.9" y1="73.6" x2="254.4" y2="72.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="254.4" y1="72.8" x2="255.8" y2="72.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="255.8" y1="72.1" x2="257.3" y2="71.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="257.3" y1="71.3" x2="258.7" y2="70.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="258.7" y1="70.5" x2="260.1" y2="69.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="260.1" y1="69.7" x2="261.5" y2="68.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="261.5" y1="68.9" x2="262.9" y2="68.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="262.9" y1="68.0" x2="264.3" y2="67.2"

# %% [markdown]
# ### Ask an assistant
#
# Draw a spiral:

# %%
# Solution

from jupyturtle import make_turtle, forward, right

make_turtle(delay=0.01)

def spiral(length, angle):
    for _ in range(100):
        forward(length)
        right(angle)
        length += 2  # Increase the length for each segment

spiral(5, 90)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="155.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="155.0" y1="75.0" x2="155.0" y2="82.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="155.0" y1="82.0" x2="146.0" y2="82.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="146.0" y1="82.0" x2="146.0" y2="71.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="146.0" y1="71.0" x2="159.0" y2="71.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="159.0" y1="71.0" x2="159.0" y2="86.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="159.0" y1="86.0" x2="142.0" y2="86.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="142.0" y1="86.0" x2="142.0" y2="67.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="142.0" y1="67.0" x2="163.0" y2="67.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="163.0" y1="67.0" x2="163.0" y2="90.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="163.0" y1="90.0" x2="138.0" y2="90.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="138.0" y1="90.0" x2="138.0" y2="63.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="138.0" y1="63.0" x2="167.0" y2="63.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="167.0" y1="63.0" x2="167.0" y2="94.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="167.0" y1="94.0" x2="134.0" y2="94.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="134.0" y1="94.0" x2="134.0" y2="59.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="134.0" y1="59.0" x2="171.0" y2="59.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="171.0" y1="59.0" x2="171.0" y2="98.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="171.0" y1="98.0" x2="130.0" y2="98.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="130.0" y1="98.0" x2="130.0" y2="55.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="130.0" y1="55.0" x2="175.0" y2="55.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="175.0" y1="55.0" x2="175.0" y2="102.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="175.0" y1="102.0" x2="126.0" y2="102.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="126.0" y1="102.0" x2="126.0" y2="51.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="126.0" y1="51.0" x2="179.0" y2="51.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="179.0" y1="51.0" x2="179.0" y2="106.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="179.0" y1="106.0" x2="122.0" y2="106.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="122.0" y1="106.0" x2="122.0" y2="47.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="122.0" y1="47.0" x2="183.0" y2="47.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="183.0" y1="47.0" x2="183.0" y2="110.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="183.0" y1="110.0" x2="118.0" y2="110.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="118.0" y1="110.0" x2="118.0" y2="43.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="118.0" y1="43.0" x2="187.0" y2="43.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="187.0" y1="43.0" x2="187.0" y2="114.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="187.0" y1="114.0" x2="114.0" y2="114.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="114.0" y1="114.0" x2="114.0" y2="39.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="114.0" y1="39.0" x2="191.0" y2="39.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="191.0" y1="39.0" x2="191.0" y2="118.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="191.0" y1="118.0" x2="110.0" y2="118.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="110.0" y1="118.0" x2="110.0" y2="35.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="110.0" y1="35.0" x2="195.0" y2="35.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="195.0" y1="35.0" x2="195.0" y2="122.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="195.0" y1="122.0" x2="106.0" y2="122.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="106.0" y1="122.0" x2="106.0" y2="31.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="106.0" y1="31.0" x2="199.0" y2="31.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="199.0" y1="31.0" x2="199.0" y2="126.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="199.0" y1="126.0" x2="102.0" y2="126.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="102.0" y1="126.0" x2="102.0" y2="27.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="102.0" y1="27.0" x2="203.0" y2="27.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="203.0" y1="27.0" x2="203.0" y2="130.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="203.0" y1="130.0" x2="98.0" y2="130.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="98.0" y1="130.0" x2="98.0" y2="23.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="98.0" y1="23.0" x2="207.0" y2="23.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="207.0" y1="23.0" x2="207.0" y2="134.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="207.0" y1="134.0" x2="94.0" y2="134.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="94.0" y1="134.0" x2="94.0" y2="19.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="94.0" y1="19.0" x2="211.0" y2="19.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="211.0" y1="19.0" x2="211.0" y2="138.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="211.0" y1="138.0" x2="90.0" y2="138.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="90.0" y1="138.0" x2="90.0" y2="15.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="90.0" y1="15.0" x2="215.0" y2="15.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="215.0" y1="15.0" x2="215.0" y2="142.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="215.0" y1="142.0" x2="86.0" y2="142.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="86.0" y1="142.0" x2="86.0" y2="11.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="86.0" y1="11.0" x2="219.0" y2="11.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="219.0" y1="11.0" x2="219.0" y2="146.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="219.0" y1="146.0" x2="82.0" y2="146.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="82.0" y1="146.0" x2="82.0" y2="7.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="82.0" y1="7.0" x2="223.0" y2="7.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="223.0" y1="7.0"

# %%
# Solution

# prompt: make that a circular spiral, and don't change the name of the module

from jupyturtle import make_turtle, forward, left
import math

make_turtle(delay=0)

def circular_spiral(radius, angle):
    rotations = 5
    distance = 2 * math.pi * radius / 360  # Calculate the distance for each degree of rotation
    for _ in range(rotations * 360):
        forward(distance)
        left(angle)
        radius += 0.1  # Increase the radius for each segment
        distance = 2 * math.pi * radius / 360  # Recalculate the distance for the updated radius

circular_spiral(50, 1)
print('done')
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="150.9" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.9" y1="75.0" x2="151.7" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="151.7" y1="75.0" x2="152.6" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="152.6" y1="75.0" x2="153.5" y2="74.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="153.5" y1="74.9" x2="154.4" y2="74.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="154.4" y1="74.8" x2="155.3" y2="74.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="155.3" y1="74.8" x2="156.1" y2="74.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="156.1" y1="74.7" x2="157.0" y2="74.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="157.0" y1="74.6" x2="157.9" y2="74.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="157.9" y1="74.4" x2="158.8" y2="74.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="158.8" y1="74.3" x2="159.6" y2="74.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="159.6" y1="74.2" x2="160.5" y2="74.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="160.5" y1="74.0" x2="161.4" y2="73.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="161.4" y1="73.8" x2="162.3" y2="73.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="162.3" y1="73.6" x2="163.1" y2="73.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="163.1" y1="73.4" x2="164.0" y2="73.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="164.0" y1="73.1" x2="164.9" y2="72.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="164.9" y1="72.9" x2="165.7" y2="72.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="165.7" y1="72.6" x2="166.6" y2="72.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="166.6" y1="72.4" x2="167.4" y2="72.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="167.4" y1="72.1" x2="168.3" y2="71.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="168.3" y1="71.7" x2="169.2" y2="71.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="169.2" y1="71.4" x2="170.0" y2="71.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="170.0" y1="71.1" x2="170.8" y2="70.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="170.8" y1="70.7" x2="171.7" y2="70.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="171.7" y1="70.4" x2="172.5" y2="70.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="172.5" y1="70.0" x2="173.3" y2="69.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="173.3" y1="69.6" x2="174.1" y2="69.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="174.1" y1="69.1" x2="175.0" y2="68.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="175.0" y1="68.7" x2="175.8" y2="68.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="175.8" y1="68.3" x2="176.6" y2="67.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="176.6" y1="67.8" x2="177.4" y2="67.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.4" y1="67.3" x2="178.2" y2="66.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.2" y1="66.8" x2="178.9" y2="66.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.9" y1="66.3" x2="179.7" y2="65.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="179.7" y1="65.8" x2="180.5" y2="65.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="180.5" y1="65.3" x2="181.2" y2="64.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="181.2" y1="64.7" x2="182.0" y2="64.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="182.0" y1="64.2" x2="182.7" y2="63.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="182.7" y1="63.6" x2="183.4" y2="63.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="183.4" y1="63.0" x2="184.2" y2="62.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="184.2" y1="62.4" x2="184.9" y2="61.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="184.9" y1="61.8" x2="185.6" y2="61.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="185.6" y1="61.1" x2="186.3" y2="60.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="186.3" y1="60.5" x2="187.0" y2="59.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="187.0" y1="59.8" x2="187.6" y2="59.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="187.6" y1="59.1" x2="188.3" y2="58.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="188.3" y1="58.5" x2="188.9" y2="57.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="188.9" y1="57.8" x2="189.6" y2="57.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="189.6" y1="57.1" x2="190.2" y2="56.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="190.2" y1="56.3" x2="190.8" y2="55.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="190.8" y1="55.6" x2="191.4" y2="54.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="191.4" y1="54.8" x2="192.0" y2="54.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="192.0" y1="54.1" x2="192.6" y2="53.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="192.6" y1="53.3" x2="193.2" y2="52.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="193.2" y1="52.5" x2="193.7" y2="51.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="193.7" y1="51.7" x2="194.3" y2="50.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="194.3" y1="50.9" x2="194.8" y2="50.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="194.8" y1="50.1" x2="195.3" y2="49.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="195.3" y1="49.3" x2="195.8" y2="48.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="195.8" y1="48.5" x2="196.3" y2="47.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="196.3" y1="47.6" x2="196.8" y2="46.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="196.8" y1="46.8" x2="197.2" y2="45.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="197.2" y1="45.9" x2="197.7" y2="45.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="197.7" y1="45.0" x2="198.1" y2="44.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="198.1" y1="44.1" x2="198.5" y2="43.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="198.5" y1="43.2" x2="198.9" y2="42.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="198.9" y1="42.3" x2="199.3" y2="41.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="199.3" y1="41.4" x2="199.7" y2="40.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="199.7" y1="40.5" x2="200.1" y2="39.6" str
# done

# %%
# Solution

# quick version

make_turtle(auto_render=False, width=550, height=550)

circular_spiral(50, 1)
render()
# Out:
# <svg width="550" height="550">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="275" y1="275" x2="275.9" y2="275.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="275.9" y1="275.0" x2="276.7" y2="275.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="276.7" y1="275.0" x2="277.6" y2="275.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="277.6" y1="275.0" x2="278.5" y2="274.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="278.5" y1="274.9" x2="279.4" y2="274.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="279.4" y1="274.8" x2="280.3" y2="274.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="280.3" y1="274.8" x2="281.1" y2="274.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="281.1" y1="274.7" x2="282.0" y2="274.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="282.0" y1="274.6" x2="282.9" y2="274.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="282.9" y1="274.4" x2="283.8" y2="274.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="283.8" y1="274.3" x2="284.6" y2="274.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="284.6" y1="274.2" x2="285.5" y2="274.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="285.5" y1="274.0" x2="286.4" y2="273.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="286.4" y1="273.8" x2="287.3" y2="273.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="287.3" y1="273.6" x2="288.1" y2="273.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="288.1" y1="273.4" x2="289.0" y2="273.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="289.0" y1="273.1" x2="289.9" y2="272.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="289.9" y1="272.9" x2="290.7" y2="272.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="290.7" y1="272.6" x2="291.6" y2="272.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="291.6" y1="272.4" x2="292.4" y2="272.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="292.4" y1="272.1" x2="293.3" y2="271.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="293.3" y1="271.7" x2="294.2" y2="271.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="294.2" y1="271.4" x2="295.0" y2="271.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="295.0" y1="271.1" x2="295.8" y2="270.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="295.8" y1="270.7" x2="296.7" y2="270.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="296.7" y1="270.4" x2="297.5" y2="270.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="297.5" y1="270.0" x2="298.3" y2="269.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="298.3" y1="269.6" x2="299.1" y2="269.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="299.1" y1="269.1" x2="300.0" y2="268.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="300.0" y1="268.7" x2="300.8" y2="268.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="300.8" y1="268.3" x2="301.6" y2="267.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="301.6" y1="267.8" x2="302.4" y2="267.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="302.4" y1="267.3" x2="303.2" y2="266.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="303.2" y1="266.8" x2="303.9" y2="266.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="303.9" y1="266.3" x2="304.7" y2="265.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="304.7" y1="265.8" x2="305.5" y2="265.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="305.5" y1="265.3" x2="306.2" y2="264.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="306.2" y1="264.7" x2="307.0" y2="264.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="307.0" y1="264.2" x2="307.7" y2="263.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="307.7" y1="263.6" x2="308.4" y2="263.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="308.4" y1="263.0" x2="309.2" y2="262.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="309.2" y1="262.4" x2="309.9" y2="261.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="309.9" y1="261.8" x2="310.6" y2="261.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="310.6" y1="261.1" x2="311.3" y2="260.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="311.3" y1="260.5" x2="312.0" y2="259.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="312.0" y1="259.8" x2="312.6" y2="259.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="312.6" y1="259.1" x2="313.3" y2="258.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="313.3" y1="258.5" x2="313.9" y2="257.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="313.9" y1="257.8" x2="314.6" y2="257.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="314.6" y1="257.1" x2="315.2" y2="256.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="315.2" y1="256.3" x2="315.8" y2="255.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="315.8" y1="255.6" x2="316.4" y2="254.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="316.4" y1="254.8" x2="317.0" y2="254.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="317.0" y1="254.1" x2="317.6" y2="253.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="317.6" y1="253.3" x2="318.2" y2="252.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="318.2" y1="252.5" x2="318.7" y2="251.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="318.7" y1="251.7" x2="319.3" y2="250.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="319.3" y1="250.9" x2="319.8" y2="250.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="319.8" y1="250.1" x2="320.3" y2="249.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="320.3" y1="249.3" x2="320.8" y2="248.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="320.8" y1="248.5" x2="321.3" y2="247.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="321.3" y1="247.6" x2="321.8" y2="246.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="321.8" y1="246.8" x2="322.2" y2="245.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="322.2" y1="245.9" x2="322.7" y2="245.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="322.7" y1="245.0" x2="323.1" y2="244.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="323.1" y1="244.1" x2="323.5" y2="243.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="323.5" y1="243.2" x2="323.9" y2="242.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="323.9" y1="242.3" x2="324.3" y2="241.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="324.3" y1="241.4" x
