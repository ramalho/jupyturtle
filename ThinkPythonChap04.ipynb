# %% [markdown]
# # Code from Downey's _Think Python_
#
# This notebook contains code for examples and exercises from chapter 4,
# _Functions and Interfaces_ of Allen Downey's
# _Think Python Third Edition_ (O'Reilly, 2024) using turtle graphics.
#
# I removed the main text, keeping only the section titles to make it easier to locate the code in the book.
# I also added some very brief comments for context.

# %% [markdown]
# ## The Turtle module
#
# Import the `Turtle` class:

# %%
from jupyturtle import Turtle

# %% [markdown]
# Create `Turtle` object, use a method:

# %%
t = Turtle()
t.forward(100)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle105995190" transform="rotate(-90.0,300.0,100.0) translate(300.0, 100.0)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="300.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# Shortcuts for exploratory programming with an imperative API:

# %%
from jupyturtle import fd
fd(100)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle105994d10" transform="rotate(-180.0,350.0,50.0) translate(350.0, 50.0)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="300.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="300.0" y1="100.0" x2="350.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="350.0" y1="100.0" x2="350.0" y2="50.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# The `fd()` call created a new turtle and canvas.
# Further commands will update that same canvas.

# %% [markdown]
# Import more functions:

# %%
from jupyturtle import lt, rt, fd

# %% [markdown]
# Experiment with `left`, aliased to `lt`.

# %%
fd(50)
lt(90)
fd(50)

# %% [markdown]
# ## Making a square

# %%
from jupyturtle import make_turtle, forward, left

make_turtle()

forward(50)
left(90)

forward(50)
left(90)

forward(50)
left(90)

forward(50)
left(90)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle10596b4a0" transform="rotate(-450.0,200.0,100.0) translate(200.0, 100.0)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="250.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250.0" y1="100.0" x2="250.0" y2="50.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250.0" y1="50.0" x2="200.0" y2="49.99999999999999" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200.0" y1="49.99999999999999" x2="200.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# Using a `for` loop.

# %%
make_turtle()
for i in range(4):
    forward(50)
    left(90)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle105929a60" transform="rotate(-450.0,200.0,100.0) translate(200.0, 100.0)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="250.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250.0" y1="100.0" x2="250.0" y2="50.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250.0" y1="50.0" x2="200.0" y2="49.99999999999999" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200.0" y1="49.99999999999999" x2="200.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# ## Encapsulation and generalization
#
# Write function

# %%
def square():
    for i in range(4):
        forward(50)
        left(90)

# %% [markdown]
# Call it.

# %%
make_turtle()
square()
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle105929d00" transform="rotate(-450.0,200.0,100.0) translate(200.0, 100.0)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="250.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250.0" y1="100.0" x2="250.0" y2="50.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250.0" y1="50.0" x2="200.0" y2="49.99999999999999" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200.0" y1="49.99999999999999" x2="200.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# Function with parameter

# %%
def square(length):
    for i in range(4):
        forward(length)
        left(90)

# %% [markdown]
# Now we can draw squares with different sizes.

# %%
make_turtle()
square(30)
square(60)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1059943b0" transform="rotate(-810.0,199.99999999999997,100.0) translate(199.99999999999997, 100.0)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="230.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230.0" y1="100.0" x2="230.0" y2="70.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230.0" y1="70.0" x2="200.0" y2="70.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200.0" y1="70.0" x2="200.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200.0" y1="100.0" x2="260.0" y2="100.00000000000001" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260.0" y1="100.00000000000001" x2="260.0" y2="40.000000000000014" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260.0" y1="40.000000000000014" x2="200.0" y2="39.99999999999999" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200.0" y1="39.99999999999999" x2="199.99999999999997" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# Generalization:

# %%
def polygon(n, length):
    angle = 360 / n
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# Example:

# %%
make_turtle()
polygon(7, 30)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1059c3740" transform="rotate(-450.00000000000006,200.00000000000006,99.99999999999999) translate(200.00000000000006, 99.99999999999999)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="230.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230.0" y1="100.0" x2="248.70469405576202" y2="76.5450555259591" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="248.70469405576202" y1="76.5450555259591" x2="242.0290660370726" y2="47.29721816050439" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="242.0290660370726" y1="47.29721816050439" x2="215.00000000000003" y2="34.280705986977644" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="215.00000000000003" y1="34.280705986977644" x2="187.97093396292746" y2="47.297218160504386" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="187.97093396292746" y1="47.297218160504386" x2="181.29530594423804" y2="76.5450555259591" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="181.29530594423804" y1="76.5450555259591" x2="200.00000000000006" y2="99.99999999999999" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# Named arguments:

# %%
make_turtle()
polygon(n=7, length=30)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1059d0a70" transform="rotate(-450.00000000000006,200.00000000000006,99.99999999999999) translate(200.00000000000006, 99.99999999999999)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="230.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230.0" y1="100.0" x2="248.70469405576202" y2="76.5450555259591" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="248.70469405576202" y1="76.5450555259591" x2="242.0290660370726" y2="47.29721816050439" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="242.0290660370726" y1="47.29721816050439" x2="215.00000000000003" y2="34.280705986977644" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="215.00000000000003" y1="34.280705986977644" x2="187.97093396292746" y2="47.297218160504386" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="187.97093396292746" y1="47.297218160504386" x2="181.29530594423804" y2="76.5450555259591" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="181.29530594423804" y1="76.5450555259591" x2="200.00000000000006" y2="99.99999999999999" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# ## Approximating a circle
#
# To draw a circle:

# %%
import math

def circle(radius):
    circumference = 2 * math.pi * radius
    n = 30
    length = circumference / n
    polygon(n, length)

# %% [markdown]
# The `delay` argument (named `speed` in ColabTurtle):

# %%
make_turtle(delay=0.05)
circle(30)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1059c3740" transform="rotate(-450.0,199.99999999999997,99.99999999999999) translate(199.99999999999997, 99.99999999999999)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="206.2831853071796" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="206.2831853071796" y1="100.0" x2="212.4290679403632" y2="98.69365231906299" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="212.4290679403632" y1="98.69365231906299" x2="218.16904333726384" y2="96.13805061939757" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="218.16904333726384" y1="96.13805061939757" x2="223.2522470295791" y2="92.44488695841666" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="223.2522470295791" y1="92.44488695841666" x2="227.45651862403724" y2="87.77557030987056" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="227.45651862403724" y1="87.77557030987056" x2="230.59811127762703" y2="82.3341722171679" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230.59811127762703" y1="82.3341722171679" x2="232.53972231635248" y2="76.3585078876848" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232.53972231635248" y1="76.3585078876848" x2="233.19649402093785" y2="70.10974252703846" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="233.19649402093785" y1="70.10974252703846" x2="232.53972231635245" y2="63.86097716639213" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232.53972231635245" y1="63.86097716639213" x2="230.598111277627" y2="57.88531283690902" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230.598111277627" y1="57.88531283690902" x2="227.45651862403722" y2="52.44391474420637" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="227.45651862403722" y1="52.44391474420637" x2="223.25224702957908" y2="47.77459809566027" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="223.25224702957908" y1="47.77459809566027" x2="218.16904333726382" y2="44.08143443467935" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="218.16904333726382" y1="44.08143443467935" x2="212.42906794036318" y2="41.525832735013935" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="212.42906794036318" y1="41.525832735013935" x2="206.28318530717956" y2="40.21948505407693" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="206.28318530717956" y1="40.21948505407693" x2="199.99999999999997" y2="40.21948505407693" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="199.99999999999997" y1="40.21948505407693" x2="193.85411736681635" y2="41.525832735013935" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="193.85411736681635" y1="41.525832735013935" x2="188.11414196991572" y2="44.08143443467935" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="188.11414196991572" y1="44.08143443467935" x2="183.03093827760046" y2="47.77459809566027" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="183.03093827760046" y1="47.77459809566027" x2="178.82666668314232" y2="52.44391474420637" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="178.82666668314232" y1="52.44391474420637" x2="175.68507402955254" y2="57.885312836909016" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="175.68507402955254" y1="57.885312836909016" x2="173.74346299082708" y2="63.860977166392125" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="173.74346299082708" y1="63.860977166392125" x2="173.08669128624172" y2="70.10974252703845" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="173.08669128624172" y1="70.10974252703845" x2="173.74346299082708" y2="76.35850788768478" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="173.74346299082708" y1="76.35850788768478" x2="175.68507402955254" y2="82.33417221716789" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="175.68507402955254" y1="82.33417221716789" x2="178.82666668314232" y2="87.77557030987055" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="178.82666668314232" y1="87.77557030987055" x2="183.03093827760046" y2="92.44488695841665" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="183.03093827760046" y1="92.44488695841665" x2="188.11414196991572" y2="96.13805061939756" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="188.11414196991572" y1="96.13805061939756" x2="193.85411736681635" y2="98.69365231906298" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="193.85411736681635" y1="98.69365231906298" x2="199.99999999999997" y2="99.99999999999999" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# ## Refactoring
#
# `polyline`, a more general version of `polygon`:

# %%
def polyline(n, length, angle):
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# Parameters:
#
# `n`: number of segments to draw
#
# `length`: length each segment
#
# `angle`: angle between them
#
# New `polygon` using `polyline`:

# %%
def polygon(n, length):
    angle = 360.0 / n
    polyline(n, length, angle)

# %% [markdown]
# Use `polyline` to write `arc`:

# %%
def arc(radius, angle):
    arc_length = 2 * math.pi * radius * angle / 360
    n = 30
    length = arc_length / n
    step_angle = float(angle) / n
    polyline(n, length, step_angle)

# %% [markdown]
# Rewrite `circle` to use `arc`:

# %%
def circle(radius):
    arc(radius,  360)

# %% [markdown]
# To check that these functions work as expected, we'll use them to draw something like a snail.

# %%
make_turtle(delay=0.01)
polygon(n=20, length=9)
arc(radius=70, angle=70)
circle(radius=10)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle105997410" transform="rotate(-879.9999999999994,266.7072452702874,55.28716875008488) translate(266.7072452702874, 55.28716875008488)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="209.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="209.0" y1="100.0" x2="217.55950864665638" y2="97.21884705062547" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="217.55950864665638" y1="97.21884705062547" x2="224.8406615960309" y2="91.9287797799932" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="224.8406615960309" y1="91.9287797799932" x2="230.13072886666316" y2="84.64762683061868" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230.13072886666316" y1="84.64762683061868" x2="232.9118818160377" y2="76.0881181839623" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232.9118818160377" y1="76.0881181839623" x2="232.9118818160377" y2="67.0881181839623" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232.9118818160377" y1="67.0881181839623" x2="230.13072886666316" y2="58.52860953730591" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230.13072886666316" y1="58.52860953730591" x2="224.8406615960309" y2="51.24745658793138" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="224.8406615960309" y1="51.24745658793138" x2="217.55950864665638" y2="45.957389317299125" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="217.55950864665638" y1="45.957389317299125" x2="209.0" y2="43.176236367924595" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="209.0" y1="43.176236367924595" x2="200.0" y2="43.176236367924595" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200.0" y1="43.176236367924595" x2="191.44049135334362" y2="45.95738931729912" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="191.44049135334362" y1="45.95738931729912" x2="184.1593384039691" y2="51.247456587931374" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="184.1593384039691" y1="51.247456587931374" x2="178.86927113333684" y2="58.5286095373059" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="178.86927113333684" y1="58.5286095373059" x2="176.0881181839623" y2="67.08811818396228" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="176.0881181839623" y1="67.08811818396228" x2="176.0881181839623" y2="76.08811818396228" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="176.0881181839623" y1="76.08811818396228" x2="178.86927113333684" y2="84.64762683061866" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="178.86927113333684" y1="84.64762683061866" x2="184.1593384039691" y2="91.92877977999319" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="184.1593384039691" y1="91.92877977999319" x2="191.44049135334362" y2="97.21884705062546" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="191.44049135334362" y1="97.21884705062546" x2="200.0" y2="99.99999999999999" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200.0" y1="99.99999999999999" x2="202.85070444492408" y2="99.99999999999999" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="202.85070444492408" y1="99.99999999999999" x2="205.69904530890327" y2="99.88393900355372" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="205.69904530890327" y1="99.88393900355372" x2="208.5402993494404" y2="99.65200946804492" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="208.5402993494404" y1="99.65200946804492" x2="211.3697550757166" y2="99.3045959890999" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="211.3697550757166" y1="99.3045959890999" x2="214.18272056139003" y2="98.8422746628343" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="214.18272056139003" y1="98.8422746628343" x2="216.9745312249518" y2="98.26581213054561" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="216.9745312249518" y1="98.26581213054561" x2="219.7405575647376" y2="97.57616430743519" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="219.7405575647376" y1="97.57616430743519" x2="222.47621283576842" y2="96.77447479746822" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="222.47621283576842" y1="96.77447479746822" x2="225.17696065569015" y2="95.86207299699991" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="225.17696065569015" y1="95.86207299699991" x2="227.83832252719984" y2="94.84047189031281" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="227.83832252719984" y1="94.84047189031281" x2="230.45588526448432" y2="93.71136554072051" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230.45588526448432" y1="93.71136554072051" x2="233.02530831135658" y2="92.47662628139832" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="233.02530831135658" y1="92.47662628139832" x2="235.54233093895454" y2="91.13830161059914" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="235.54233093895454" y1="91.13830161059914" x2="238.00277931106658" y2="89.69861079640289" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="238.00277931106658" y1="89.69861079640289" x2="240.402573405368" y2="88.15994119662983" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="240.402573405368" y1="88.15994119662983" x2="242.7377337790913" y2="86.5248443000202" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="242.7377337790913" y1="86.5248443000202" x2="245.00438816791072" y2="84.79603149524479" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="245.00438816791072" y1="84.79603149524479" x2="247.19877790709938" y2="82.97636957476249" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="247.19877790709938" y1="82.97636957476249" x2="249.31726416431013" y2="81.06887598098056" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249.31726416431013" y1="81.06887598098056" x2="251.35633397364538" y2="79.07671380260066" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="251.35633397364538" y1="79.07671380260066" x2="253.31260606100977" y2="77.00318652944777" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="253.31260606100977" y1="77.00318652944777" x2="255.1828364510856" y2="74.85173257447995" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="255.1828364510856" y1="74.85173257447995" x2="256.9639238466336" y2="72.62591957206266" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="256.9639238466336" y1="72.62591957206266" x2="258.65291477119865" y2="70.32943846196252" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="258.65291477119865" y1="70.32943846196252" x2="260.2470084666927" y2="67.96609736887082" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260.2470084666927" y1="67.96609736887082" x2="261.7435615377335" y2="65.53981528760569" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="261.7435615377335" y1="65.53981528760569" x2="263.1400923350374" y2="63.05461558446482" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="263.1400923350374" y1="6

# %% [markdown]
# ## Stack diagram
#
# (no turtle examples in this section)

# %% [markdown]
# ## Docstrings
#
# `polyline` with docstring:

# %%
def polyline(n, length, angle):
    """Draws line segments with the given length and angle between them.

    n: integer number of line segments
    length: length of the line segments
    angle: angle between segments (in degrees)
    """
    for i in range(n):
        forward(length)
        left(angle)

# %%
make_turtle()
polyline(9, 30, 36)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1059d2a80" transform="rotate(-414.0,175.72949016875154,82.36644243122579) translate(175.72949016875154, 82.36644243122579)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="230.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230.0" y1="100.0" x2="254.27050983124843" y2="82.3664424312258" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="254.27050983124843" y1="82.3664424312258" x2="263.54101966249686" y2="53.8347469423712" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="263.54101966249686" y1="53.8347469423712" x2="254.27050983124843" y2="25.303051453516588" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="254.27050983124843" y1="25.303051453516588" x2="230.0" y2="7.669493884742391" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230.0" y1="7.669493884742391" x2="200.0" y2="7.669493884742387" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200.0" y1="7.669493884742387" x2="175.72949016875157" y2="25.303051453516577" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="175.72949016875157" y1="25.303051453516577" x2="166.45898033750314" y2="53.83474694237118" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="166.45898033750314" y1="53.83474694237118" x2="175.72949016875154" y2="82.36644243122579" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# ## Debugging
#
# (no turtle examples in this section)

# %% [markdown]
# ## Glossary
#
# (no turtle examples in this section)

# %% [markdown]
# ## Exercises
#
# `penup` and `pendown`

# %%
from jupyturtle import forward, penup, pendown

def jump(length):
    """Move forward length units without leaving a trail.

    Postcondition: Leaves the pen down.
    """
    penup()
    forward(length)
    pendown()

# %% [markdown]
# ### Exercise
#
# Draw a rectangle:

# %%
# Solution

def rectangle(length1, length2):
    """Draw a rectangle with the given lengths.

    length1: length of the first side
    length2: length of the second size
    """
    for i in range(2):
        forward(length1)
        left(90)
        forward(length2)
        left(90)

# %%
make_turtle()
rectangle(80, 40)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle105997410" transform="rotate(-450.0,200.0,100.0) translate(200.0, 100.0)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="280.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="280.0" y1="100.0" x2="280.0" y2="60.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="280.0" y1="60.0" x2="200.0" y2="59.99999999999999" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200.0" y1="59.99999999999999" x2="200.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Draw a rhombus:

# %%
def rhombus(length, angle):
    for i in range(2):
        forward(length)
        left(angle)
        forward(length)
        left(180-angle)

# %%
make_turtle()
rhombus(50, 60)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1059d3d10" transform="rotate(-450.0,199.99999999999997,99.99999999999997) translate(199.99999999999997, 99.99999999999997)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="250.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250.0" y1="100.0" x2="275.0" y2="56.69872981077807" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="275.0" y1="56.69872981077807" x2="225.0" y2="56.69872981077806" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="225.0" y1="56.69872981077806" x2="199.99999999999997" y2="99.99999999999997" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write `parallelogram`, then rewrite `rectangle` and `rhombus` to use it:

# %%
# Solution

def parallelogram(length1, length2, angle):
    for i in range(2):
        forward(length1)
        left(angle)
        forward(length2)
        left(180-angle)

# %%
# Solution

def rectangle(length1, length2):
    """Draw a rectangle with the given lengths.

    length1: length of the first side
    length2: length of the second size
    """
    parallelogram(length1, length2, 90)

# %%
# Solution

def rhombus(length, angle):
    parallelogram(length, length, angle)

# %%
make_turtle(delay=0.05)
jump(-120)

rectangle(80, 40)
jump(100)
rhombus(50, 60)
jump(80)
parallelogram(80, 50, 60)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle105997410" transform="rotate(-1170.0,259.99999999999994,100.00000000000001) translate(259.99999999999994, 100.00000000000001)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="80.0" y1="100.0" x2="160.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160.0" y1="100.0" x2="160.0" y2="60.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160.0" y1="60.0" x2="80.0" y2="59.99999999999999" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="80.0" y1="59.99999999999999" x2="79.99999999999999" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="180.0" y1="100.00000000000003" x2="230.0" y2="100.00000000000004" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230.0" y1="100.00000000000004" x2="255.0" y2="56.698729810778104" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="255.0" y1="56.698729810778104" x2="205.0" y2="56.69872981077808" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="205.0" y1="56.69872981077808" x2="180.0" y2="100.00000000000003" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260.0" y1="100.00000000000007" x2="340.0" y2="100.00000000000011" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="340.0" y1="100.00000000000011" x2="365.0" y2="56.698729810778175" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="365.0" y1="56.698729810778175" x2="285.0" y2="56.698729810778126" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="285.0" y1="56.698729810778126" x2="259.99999999999994" y2="100.00000000000001" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# A `triangle` function:

# %%
# Solution
import math

from jupyturtle import forward, left, right

def triangle(radius,  angle):
    """Draws an icosceles triangle.

    The turtle starts and ends at the peak, facing the middle of the base.

    radius: length of the equal legs
    angle: half peak angle in degrees
    """
    y = radius * math.sin(angle * math.pi / 180)

    right(angle)
    forward(radius)
    left(90+angle)
    forward(2*y)
    left(90+angle)
    forward(radius)
    left(180-angle)

# %% [markdown]
# (a little demonstration)

# %%
from jupyturtle import make_turtle, hide
make_turtle()
hide()

for i in range(12):
    triangle(50, 10)
    left(30)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <line x1="200" y1="100" x2="249.2403876506104" y2="108.68240888334651" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249.2403876506104" y1="108.68240888334651" x2="249.2403876506104" y2="91.31759111665347" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249.2403876506104" y1="91.31759111665347" x2="200.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200.0" y1="100.0" x2="246.9846310392954" y2="82.89899283371655" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="246.9846310392954" y1="82.89899283371655" x2="238.3022221559489" y2="67.86061951567301" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="238.3022221559489" y1="67.86061951567301" x2="200.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200.0" y1="100.0" x2="232.13938048432695" y2="61.69777784405109" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232.13938048432695" y1="61.69777784405109" x2="217.1010071662834" y2="53.01536896070457" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="217.1010071662834" y1="53.01536896070457" x2="199.9999999999999" y2="99.99999999999994" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="199.9999999999999" y1="99.99999999999994" x2="208.68240888334634" y2="50.75961234938953" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="208.68240888334634" y1="50.75961234938953" x2="191.31759111665332" y2="50.75961234938951" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="191.31759111665332" y1="50.75961234938951" x2="199.99999999999986" y2="99.99999999999991" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="199.99999999999986" y1="99.99999999999991" x2="182.89899283371642" y2="53.0153689607045" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="182.89899283371642" y1="53.0153689607045" x2="167.86061951567288" y2="61.69777784405099" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="167.86061951567288" y1="61.69777784405099" x2="199.99999999999983" y2="99.99999999999989" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="199.99999999999983" y1="99.99999999999989" x2="161.69777784405105" y2="67.86061951567277" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="161.69777784405105" y1="67.86061951567277" x2="153.01536896070454" y2="82.8989928337163" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="153.01536896070454" y1="82.8989928337163" x2="199.99999999999994" y2="99.99999999999979" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="199.99999999999994" y1="99.99999999999979" x2="150.75961234938956" y2="91.3175911166532" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="150.75961234938956" y1="91.3175911166532" x2="150.7596123493895" y2="108.68240888334624" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="150.7596123493895" y1="108.68240888334624" x2="199.9999999999999" y2="99.99999999999964" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="199.9999999999999" y1="99.99999999999964" x2="153.01536896070448" y2="117.10100716628314" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="153.01536896070448" y1="117.10100716628314" x2="161.697777844051" y2="132.13938048432667" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="161.697777844051" y1="132.13938048432667" x2="199.99999999999997" y2="99.9999999999998" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="199.99999999999997" y1="99.9999999999998" x2="167.86061951567288" y2="138.30222215594858" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="167.86061951567288" y1="138.30222215594858" x2="182.89899283371642" y2="146.98463103929507" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="182.89899283371642" y1="146.98463103929507" x2="199.99999999999986" y2="99.99999999999966" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="199.99999999999986" y1="99.99999999999966" x2="191.31759111665332" y2="149.24038765061005" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="191.31759111665332" y1="149.24038765061005" x2="208.68240888334634" y2="149.24038765061007" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="208.68240888334634" y1="149.24038765061007" x2="199.9999999999997" y2="99.99999999999969" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="199.9999999999997" y1="99.99999999999969" x2="217.10100716628324" y2="146.98463103929507" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="217.10100716628324" y1="146.98463103929507" x2="232.13938048432684" y2="138.30222215594864" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232.13938048432684" y1="138.30222215594864" x2="199.99999999999994" y2="99.99999999999969" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="199.99999999999994" y1="99.99999999999969" x2="238.30222215594878" y2="132.13938048432675" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="238.30222215594878" y1="132.13938048432675" x2="246.98463103929527" y2="117.1010071662832" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="246.98463103929527" y1="117.1010071662832" x2="199.99999999999994" y2="99.99999999999947" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %%
# Solution

def draw_pie(n, radius):
    """Draws a pie divided into radial segments.

    n: number of segments
    radius: length of the radial spokes
    """
    angle = 360.0 / n
    for i in range(n):
        triangle(radius,  angle/2)
        left(angle)

# %%
make_turtle(delay=0.01)
draw_pie(5, 40)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle105997410" transform="rotate(-2250.0,200.0000000000001,99.99999999999994) translate(200.0000000000001, 99.99999999999994)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="232.3606797749979" y2="123.51141009169893" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232.3606797749979" y1="123.51141009169893" x2="232.3606797749979" y2="76.48858990830108" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232.3606797749979" y1="76.48858990830108" x2="200.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200.0" y1="100.0" x2="232.3606797749979" y2="76.48858990830108" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232.3606797749979" y1="76.48858990830108" x2="187.6393202250021" y2="61.95773934819384" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="187.6393202250021" y1="61.95773934819384" x2="200.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200.0" y1="100.0" x2="187.6393202250021" y2="61.95773934819385" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="187.6393202250021" y1="61.95773934819385" x2="160.00000000000006" y2="100.00000000000003" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160.00000000000006" y1="100.00000000000003" x2="200.00000000000006" y2="100.00000000000006" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200.00000000000006" y1="100.00000000000006" x2="160.00000000000006" y2="100.00000000000003" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160.00000000000006" y1="100.00000000000003" x2="187.6393202250022" y2="138.04226065180615" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="187.6393202250022" y1="138.04226065180615" x2="200.00000000000014" y2="100.00000000000001" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200.00000000000014" y1="100.00000000000001" x2="187.6393202250022" y2="138.04226065180615" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="187.6393202250022" y1="138.04226065180615" x2="232.36067977499798" y2="123.5114100916989" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232.36067977499798" y1="123.5114100916989" x2="200.0000000000001" y2="99.99999999999994" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %%
make_turtle(delay=0.01)
jump(-120)

size = 40
draw_pie(5, size)
jump(2*size)
draw_pie(6, size)
jump(2*size)
draw_pie(7, size)
jump(2*size)
draw_pie(8, size)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1059d3b90" transform="rotate(-10890.0,319.99999999999824,100.00000000000021) translate(319.99999999999824, 100.00000000000021)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="80.0" y1="100.0" x2="112.36067977499789" y2="123.51141009169893" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="112.36067977499789" y1="123.51141009169893" x2="112.36067977499789" y2="76.48858990830108" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="112.36067977499789" y1="76.48858990830108" x2="80.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="80.0" y1="100.0" x2="112.3606797749979" y2="76.48858990830108" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="112.3606797749979" y1="76.48858990830108" x2="67.63932022500211" y2="61.95773934819384" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="67.63932022500211" y1="61.95773934819384" x2="79.99999999999999" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="79.99999999999999" y1="100.0" x2="67.63932022500211" y2="61.95773934819385" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="67.63932022500211" y1="61.95773934819385" x2="40.00000000000004" y2="100.00000000000003" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="40.00000000000004" y1="100.00000000000003" x2="80.00000000000004" y2="100.00000000000006" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="80.00000000000004" y1="100.00000000000006" x2="40.00000000000004" y2="100.00000000000003" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="40.00000000000004" y1="100.00000000000003" x2="67.63932022500218" y2="138.04226065180615" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="67.63932022500218" y1="138.04226065180615" x2="80.00000000000011" y2="100.00000000000001" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="80.00000000000011" y1="100.00000000000001" x2="67.63932022500217" y2="138.04226065180615" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="67.63932022500217" y1="138.04226065180615" x2="112.36067977499795" y2="123.5114100916989" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="112.36067977499795" y1="123.5114100916989" x2="80.00000000000009" y2="99.99999999999994" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160.00000000000009" y1="100.00000000000006" x2="194.6410161513777" y2="119.99999999999997" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="194.6410161513777" y1="119.99999999999997" x2="194.6410161513777" y2="79.99999999999997" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="194.6410161513777" y1="79.99999999999997" x2="160.0000000000001" y2="99.9999999999999" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160.0000000000001" y1="99.9999999999999" x2="194.64101615137764" y2="79.99999999999986" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="194.64101615137764" y1="79.99999999999986" x2="160.0000000000001" y2="59.999999999999815" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160.0000000000001" y1="59.999999999999815" x2="159.99999999999997" y2="99.99999999999982" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="159.99999999999997" y1="99.99999999999982" x2="159.99999999999997" y2="59.999999999999815" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="159.99999999999997" y1="59.999999999999815" x2="125.35898384862237" y2="79.99999999999972" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="125.35898384862237" y1="79.99999999999972" x2="159.99999999999994" y2="99.99999999999964" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="159.99999999999994" y1="99.99999999999964" x2="125.35898384862243" y2="79.99999999999959" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="125.35898384862243" y1="79.99999999999959" x2="125.35898384862226" y2="119.99999999999957" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="125.35898384862226" y1="119.99999999999957" x2="159.9999999999998" y2="99.99999999999956" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="159.9999999999998" y1="99.99999999999956" x2="125.35898384862233" y2="119.9999999999997" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="125.35898384862233" y1="119.9999999999997" x2="159.9999999999999" y2="139.99999999999966" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="159.9999999999999" y1="139.99999999999966" x2="159.99999999999991" y2="99.99999999999966" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="159.99999999999991" y1="99.99999999999966" x2="160.0" y2="139.99999999999966" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160.0" y1="139.99999999999966" x2="194.64101615137753" y2="119.99999999999966" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="194.64101615137753" y1="119.99999999999966" x2="160.00000000000003" y2="99.99999999999957" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="240.00000000000003" y1="99.99999999999926" x2="276.03875471609695" y2="117.35534956470131" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="276.03875471609695" y1="117.35534956470131" x2="276.038754716097" y2="82.64465043529665" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="276.038754716097" y1="82.64465043529665" x2="240.00000000000006" y2="99.99999999999861" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="240.00000000000006" y1="99.99999999999861" x2="276.0387547160967" y2="82.64465043529603" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="276.0387547160967" y1="82.64465043529603" x2="248.90083735825257" y2="61.00288351272536" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="248.90083735825257" y1="61.00288351272536" x2="239.99999999999957" y2="99.99999999999821" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="239.99999999999957" y1="99.99999999999821" x2="248.9008373582519" y2="61.002883512725205" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="248.9008373582519" y1="61.002883512725205" x2="215.06040792564994" y2="68.7267407012769" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="215.06040792564994" y1="68.7267407012769" x2="239.99999999999895" y2="99.99999999999837" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="239.99999999999895" y1="99.99999999999837" x2="215.0604079256494" y2="68.72674070127734" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="215.0604079256494" y1="68.72674070127734" x2="199.99999999999912" y2="99.9999999999987" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="199.99999999999912" y1="99.9999999999987" x2="239.99999999999912" y2="99.9999999999986" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="239.99999999999912" y1="99.9999999999986" x2="199.99999999999912" y2="99.99999999999942" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="199.99999999999912" y1="99.99999999999942" x2="215.06040792565014" y2="131.27325929872043" stroke-linecap="round"
#     style="stroke:#000;st

# %% [markdown]
# ### Exercise
#
# Draw flowers with `petal`:

# %%
# Solution

def petal(radius,  angle):
    """Draws a petal using two arcs.

    t: Turtle
    radius: radius of the arcs
    angle: angle (degrees) that subtends the arcs
    """
    for i in range(2):
        arc(radius,  angle)
        left(180-angle)

# %%
# Solution

def flower(n, radius, angle):
    """Draws a flower with n petals.

    n: number of petals
    radius: radius of the arcs
    angle: angle (degrees) that subtends the arcs
    """
    for i in range(n):
        petal(radius,  angle)
        left(360/n)

# %%
make_turtle()

jump(-100)
flower(7, 60.0, 60.0)

jump(100)
flower(10, 40.0, 80.0)

jump(100)
flower(14, 140.0, 20.0)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle105997410" transform="rotate(-12329.999999999802,300.00000000002825,99.99999999988002) translate(300.00000000002825, 99.99999999988002)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="100.0" y1="100.0" x2="102.0943951023932" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="102.0943951023932" y1="100.0" x2="104.18751435587868" y2="99.92690666503029" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="104.18751435587868" y1="99.92690666503029" x2="106.27680761706637" y2="99.78080904806038" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="106.27680761706637" y1="99.78080904806038" x2="108.35972940394848" y2="99.56188514653192" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="108.35972940394848" y1="99.56188514653192" x2="110.4337419971772" y2="99.27040168549628" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="110.4337419971772" y1="99.27040168549628" x2="112.49631853188481" y2="98.90671379265116" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="112.49631853188481" y1="98.90671379265116" x2="114.54494607627934" y2="98.47126456567216" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="114.54494607627934" y1="98.47126456567216" x2="116.57712869326484" y2="97.96458453236653" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="116.57712869326484" y1="97.96458453236653" x2="118.59039048135624" y2="97.3872910043068" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="118.59039048135624" y1="97.3872910043068" x2="120.58227859118394" y2="96.74008732473165" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="120.58227859118394" y1="96.74008732473165" x2="122.55036621391297" y2="96.02376201163055" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="122.55036621391297" y1="96.02376201163055" x2="124.49225553793569" y2="95.23918779705606" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="124.49225553793569" y1="95.23918779705606" x2="126.4055806702359" y2="94.38732056383425" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="126.4055806702359" y1="94.38732056383425" x2="128.28801051886504" y2="93.46919818096872" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="128.28801051886504" y1="93.46919818096872" x2="130.13725163301862" y2="92.48593923915706" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="130.13725163301862" y1="92.48593923915706" x2="131.95105099725285" y2="91.43874168796046" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="131.95105099725285" y1="91.43874168796046" x2="133.72719877643675" y2="90.32888137628663" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="133.72719877643675" y1="90.32888137628663" x2="135.46353100809597" y2="89.15771049796447" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="135.46353100809597" y1="89.15771049796447" x2="137.15793223886772" y2="87.92665594430417" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="137.15793223886772" y1="87.92665594430417" x2="138.80833810185482" y2="86.63721756564995" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="138.80833810185482" y1="86.63721756564995" x2="140.41273783173872" y2="85.29096634404343" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="140.41273783173872" y1="85.29096634404343" x2="141.96917671458743" y2="83.88954247922405" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="141.96917671458743" y1="83.88954247922405" x2="143.4757584693732" y2="82.43465339029828" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="143.4757584693732" y1="82.43465339029828" x2="144.93064755829897" y2="80.92807163551251" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="144.93064755829897" y1="80.92807163551251" x2="146.33207142311835" y2="79.37163275266381" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="146.33207142311835" y1="79.37163275266381" x2="147.67832264472486" y2="77.7672330227799" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="147.67832264472486" y1="77.7672330227799" x2="148.9677610233791" y2="76.11682715979282" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="148.9677610233791" y1="76.11682715979282" x2="150.1988155770394" y2="74.42242592902106" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="150.1988155770394" y1="74.42242592902106" x2="151.36998645536156" y2="72.68609369736184" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="151.36998645536156" y1="72.68609369736184" x2="152.47984676703538" y2="70.90994591817795" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="152.47984676703538" y1="70.90994591817795" x2="150.38545166464218" y2="70.90994591817795" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="150.38545166464218" y1="70.90994591817795" x2="148.2923324111567" y2="70.98303925314765" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="148.2923324111567" y1="70.98303925314765" x2="146.20303914996902" y2="71.12913687011756" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="146.20303914996902" y1="71.12913687011756" x2="144.1201173630869" y2="71.34806077164602" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="144.1201173630869" y1="71.34806077164602" x2="142.0461047698582" y2="71.63954423268166" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="142.0461047698582" y1="71.63954423268166" x2="139.9835282351506" y2="72.00323212552678" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="139.9835282351506" y1="72.00323212552678" x2="137.93490069075605" y2="72.43868135250578" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="137.93490069075605" y1="72.43868135250578" x2="135.90271807377056" y2="72.94536138581141" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="135.90271807377056" y1="72.94536138581141" x2="133.88945628567916" y2="73.52265491387114" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="133.88945628567916" y1="73.52265491387114" x2="131.89756817585146" y2="74.16985859344629" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="131.89756817585146" y1="74.16985859344629" x2="129.92948055312243" y2="74.88618390654739" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="129.92948055312243" y1="74.88618390654739" x2="127.9875912290997" y2="75.67075812112188" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="127.9875912290997" y1="75.67075812112188" x2="126.07426609679949" y2="76.52262535434369" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="126.07426609679949" y1="76.52262535434369" x2="124.19183624817035" y2="77.44074773720922" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="124.19183624817035" y1="77.44074773720922" x2="122.34259513401675" y2="78.42400667902088" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="122.34259513401675" y1="78.42400667902088" x2="120.52879576978253" y2="79.47120423021748" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="120.52879576978253" y1="79.47120423021748" x2="118.75264799

# %% [markdown]
# ### Ask an assistant
#
# Draw a spiral:

# %%
# Solution

from jupyturtle import make_turtle, forward, right

make_turtle()

def spiral(length, angle):
    for _ in range(100):
        forward(length)
        right(angle)
        length += 2  # Increase the length for each segment

spiral(5, 90)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle105994d10" transform="rotate(8910.0,99.99999999999521,8.29913915367797e-12) translate(99.99999999999521, 8.29913915367797e-12)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="205.0" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="205.0" y1="100.0" x2="205.0" y2="107.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="205.0" y1="107.0" x2="196.0" y2="107.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="196.0" y1="107.0" x2="196.0" y2="96.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="196.0" y1="96.0" x2="209.0" y2="96.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="209.0" y1="96.0" x2="209.0" y2="111.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="209.0" y1="111.0" x2="192.0" y2="111.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="192.0" y1="111.0" x2="192.0" y2="92.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="192.0" y1="92.0" x2="213.0" y2="91.99999999999999" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="213.0" y1="91.99999999999999" x2="213.0" y2="114.99999999999999" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="213.0" y1="114.99999999999999" x2="188.0" y2="115.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="188.0" y1="115.0" x2="188.00000000000003" y2="88.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="188.00000000000003" y1="88.0" x2="217.00000000000003" y2="87.99999999999999" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="217.00000000000003" y1="87.99999999999999" x2="217.0" y2="118.99999999999999" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="217.0" y1="118.99999999999999" x2="184.0" y2="119.00000000000001" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="184.0" y1="119.00000000000001" x2="184.00000000000003" y2="84.00000000000001" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="184.00000000000003" y1="84.00000000000001" x2="221.00000000000003" y2="83.99999999999997" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="221.00000000000003" y1="83.99999999999997" x2="221.0" y2="122.99999999999997" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="221.0" y1="122.99999999999997" x2="180.0" y2="123.00000000000001" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="180.0" y1="123.00000000000001" x2="180.00000000000003" y2="80.00000000000001" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="180.00000000000003" y1="80.00000000000001" x2="225.00000000000003" y2="79.99999999999996" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="225.00000000000003" y1="79.99999999999996" x2="225.0" y2="126.99999999999996" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="225.0" y1="126.99999999999996" x2="176.0" y2="126.99999999999984" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="176.0" y1="126.99999999999984" x2="175.99999999999983" y2="75.99999999999984" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="175.99999999999983" y1="75.99999999999984" x2="228.99999999999983" y2="75.99999999999977" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="228.99999999999983" y1="75.99999999999977" x2="228.99999999999983" y2="130.99999999999977" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="228.99999999999983" y1="130.99999999999977" x2="171.99999999999983" y2="130.99999999999966" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="171.99999999999983" y1="130.99999999999966" x2="171.99999999999963" y2="71.99999999999966" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="171.99999999999963" y1="71.99999999999966" x2="232.99999999999963" y2="71.99999999999956" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232.99999999999963" y1="71.99999999999956" x2="232.99999999999963" y2="134.99999999999955" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232.99999999999963" y1="134.99999999999955" x2="167.99999999999963" y2="134.99999999999943" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="167.99999999999963" y1="134.99999999999943" x2="167.99999999999937" y2="67.99999999999943" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="167.99999999999937" y1="67.99999999999943" x2="236.99999999999937" y2="67.99999999999929" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="236.99999999999937" y1="67.99999999999929" x2="236.9999999999994" y2="138.9999999999993" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="236.9999999999994" y1="138.9999999999993" x2="163.9999999999994" y2="138.99999999999918" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="163.9999999999994" y1="138.99999999999918" x2="163.99999999999912" y2="63.999999999999176" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="163.99999999999912" y1="63.999999999999176" x2="240.99999999999912" y2="63.999999999999005" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="240.99999999999912" y1="63.999999999999005" x2="240.99999999999915" y2="142.999999999999" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="240.99999999999915" y1="142.999999999999" x2="159.99999999999915" y2="142.99999999999892" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="159.99999999999915" y1="142.99999999999892" x2="159.9999999999988" y2="59.99999999999892" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="159.9999999999988" y1="59.99999999999892" x2="244.9999999999988" y2="59.999999999998714" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="244.9999999999988" y1="59.999999999998714" x2="244.9999999999995" y2="146.99999999999872" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="244.9999999999995" y1="146.99999999999872" x2="155.9999999999995" y2="146.99999999999864" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="155.9999999999995" y1="146.99999999999864" x2="155.9999999999991" y2="55.999999999998636" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="155.9999999999991" y1="55.999999999998636" x2="248.9999999999991" y2="55.99999999999905" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="248.9999999999991" y1="55.99999999999905" x2="248.99999999999918" y2="150.99999999999903" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="248.99999999999918" y1="150.99999999999903" x2="151.99999999999918" y2="150.99999999999966" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="151.99999999999918" y1="150.99999999999966" x2="151.99999999999943" y2="51.99999999999966" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="151.99999999999943" y1="51.99999999999966" x2="252.99999999999943" y2="51.99999999999936" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="252.99999999999943" y1="51.99999999999936" x2="253.00000000000028" y2="154.99999999999937" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="253.00000000000028" y1="154

# %%
# Solution

# prompt: make that a circular spiral, and don't change the name of the module

from jupyturtle import make_turtle, forward, left
import math

make_turtle()

def circular_spiral(radius, angle):
    rotations = 5
    distance = 2 * math.pi * radius / 360  # Calculate the distance for each degree of rotation
    for _ in range(rotations * 360):
        forward(distance)
        left(angle)
        radius += 0.1  # Increase the radius for each segment
        distance = 2 * math.pi * radius / 360  # Recalculate the distance for the updated radius

circular_spiral(50, 1)
print('done')
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle10596b4a0" transform="rotate(-1890.0,198.4292036732049,279.99543071549573) translate(198.4292036732049, 279.99543071549573)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="200.87266462599717" y2="100.0" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200.87266462599717" y1="100.0" x2="201.74694140437484" y2="99.98473944206819" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="201.74694140437484" y1="99.98473944206819" x2="202.6225629587496" y2="99.95416206360586" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="202.6225629587496" y1="99.95416206360586" x2="203.49926044022266" y2="99.90821629549883" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="203.49926044022266" y1="99.90821629549883" x2="204.37676360992148" y2="99.84685529637147" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="204.37676360992148" y1="99.84685529637147" x2="205.25480092228838" y2="99.7700369853866" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="205.25480092228838" y1="99.7700369853866" x2="206.13309960909035" y2="99.67772407357543" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="206.13309960909035" y1="99.67772407357543" x2="207.01138576412424" y2="99.56988409368249" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="207.01138576412424" y1="99.56988409368249" x2="207.88938442859106" y2="99.44648942851073" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="207.88938442859106" y1="99.44648942851073" x2="208.76681967711252" y2="99.30751733775264" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="208.76681967711252" y1="99.30751733775264" x2="209.64341470436327" y2="99.15294998329347" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="209.64341470436327" y1="99.15294998329347" x2="210.51889191229134" y2="98.98277445297339" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="210.51889191229134" y1="98.98277445297339" x2="211.39297299789968" y2="98.79698278279568" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="211.39297299789968" y1="98.79698278279568" x2="212.2653790415607" y2="98.59557197756865" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="212.2653790415607" y1="98.59557197756865" x2="213.13583059583615" y2="98.37854402996942" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="213.13583059583615" y1="98.37854402996942" x2="214.00404777477388" y2="98.14590593801823" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="214.00404777477388" y1="98.14590593801823" x2="214.86975034365318" y2="97.89766972095255" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="214.86975034365318" y1="97.89766972095255" x2="215.73265780914983" y2="97.63385243349049" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="215.73265780914983" y1="97.63385243349049" x2="216.59248950989212" y2="97.35447617847387" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="216.59248950989212" y1="97.35447617847387" x2="217.4489647073785" y2="97.05956811788158" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="217.4489647073785" y1="97.05956811788158" x2="218.30180267722776" y2="96.74916048220445" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="218.30180267722776" y1="96.74916048220445" x2="219.15072280073176" y2="96.42329057817344" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="219.15072280073176" y1="96.42329057817344" x2="219.99544465668166" y2="96.08200079483353" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="219.99544465668166" y1="96.08200079483353" x2="220.83568811343696" y2="95.725338607956" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="220.83568811343696" y1="95.725338607956" x2="221.67117342120804" y2="95.35335658278248" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="221.67117342120804" y1="95.35335658278248" x2="222.50162130452134" y2="94.96611237509488" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="222.50162130452134" y1="94.96611237509488" x2="223.3267530548371" y2="94.56366873060549" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="223.3267530548371" y1="94.56366873060549" x2="224.14629062328933" y2="94.1460934826623" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="224.14629062328933" y1="94.1460934826623" x2="224.9599567135169" y2="93.71345954826516" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="224.9599567135169" y1="93.71345954826516" x2="225.76747487455543" y2="93.26584492238901" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="225.76747487455543" y1="93.26584492238901" x2="226.56856959375887" y2="92.80333267061052" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="226.56856959375887" y1="92.80333267061052" x2="227.3629663897199" y2="92.32601092003586" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="227.3629663897199" y1="92.32601092003586" x2="228.1503919051581" y2="91.83397284852713" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="228.1503919051581" y1="91.83397284852713" x2="228.93057399974475" y2="91.32731667222582" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="228.93057399974475" y1="91.32731667222582" x2="229.7032418428331" y2="90.80614563137246" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="229.7032418428331" y1="90.80614563137246" x2="230.46812600606287" y2="90.27056797442175" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230.46812600606287" y1="90.27056797442175" x2="231.2249585558076" y2="89.72069694045348" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="231.2249585558076" y1="89.72069694045348" x2="231.97347314543364" y2="89.15665073987974" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="231.97347314543364" y1="89.15665073987974" x2="232.71340510733953" y2="88.57855253344975" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232.71340510733953" y1="88.57855253344975" x2="233.44449154474398" y2="87.9865304095542" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="233.44449154474398" y1="87.9865304095542" x2="234.16647142319175" y2="87.38071735983127" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="234.16647142319175" y1="87.38071735983127" x2="234.8790856617454" y2="86.76125125307759" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="234.8790856617454" y1="86.76125125307759" x2="235.58207722383204" y2="86.1282748074675" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="235.58207722383204" y1="86.1282748074675" x2="236.27519120771376" y2="85.48193556108482" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="236.27519120771376" y1="85.48193556108482" x2="236.95817493654997" y2="84.82238584077182" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="236.95817493654997" y1="84.82238584077182" x2="237.63077804802117" y2="84.14978272930061" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="237.63077804802117" y1="84.14978272930061" x2="238.29275258348238" y2="83.4642880
# done
