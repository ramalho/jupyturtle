# %% [markdown]
# # Functions and Interfaces
#
# This notebook contains code for examples and exercises from chapter 4 of Allen Downey's _Think Python Third Edition_ (O'Reilly, 2024) using turtle graphics.
#
# I removed the main text, keeping only the section titles to make it easier to locate the code in the book. I also added some very brief comments for context.

# %% [markdown]
# ## The Turtle module
#
# Import `Turtle`

# %%
from jupyturtle import Turtle

# %% [markdown]
# Create `Turtle` object, use a method.

# %%
t = Turtle()
t.forward(100)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1064b17c0" transform="rotate(-90.0,300,100) translate(300, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="300" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# Imperative API with shortcuts for exploratory programming

# %%
from jupyturtle import forward as fd
fd(100)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle10648ef90" transform="rotate(-180.0,350,50) translate(350, 50)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="300" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="300" y1="100" x2="350" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="350" y1="100" x2="350" y2="50" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# The `fd()` call created a new turtle and canvas.
# Further commands will update that same canvas.

# %% [markdown]
# Import more functions

# %%
from jupyturtle import left as lt, right as rt, forward as fd

# %% [markdown]
# Experiment with `left`.

# %%
fd(50)
lt(90)
fd(50)

# %% [markdown]
# ## Making a square

# %%
from jupyturtle import make_turtle, forward, left

make_turtle()

forward(50)
left(90)

forward(50)
left(90)

forward(50)
left(90)

forward(50)
left(90)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle10648ca40" transform="rotate(-450.0,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="250" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250" y1="100" x2="250" y2="50" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250" y1="50" x2="200" y2="50" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="50" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# Using a `for` loop.

# %%
make_turtle()
for i in range(4):
    forward(50)
    left(90)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1063df950" transform="rotate(-450.0,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="250" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250" y1="100" x2="250" y2="50" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250" y1="50" x2="200" y2="50" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="50" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# ## Encapsulation and generalization
#
# Write function

# %%
def square():
    for i in range(4):
        forward(50)
        left(90)

# %% [markdown]
# Call it.

# %%
make_turtle()
square()
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle10648cdd0" transform="rotate(-450.0,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="250" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250" y1="100" x2="250" y2="50" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250" y1="50" x2="200" y2="50" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="50" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# Function with parameter

# %%
def square(length):
    for i in range(4):
        forward(length)
        left(90)

# %% [markdown]
# Now we can draw squares with different sizes.

# %%
make_turtle()
square(30)
square(60)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle10648ca40" transform="rotate(-810.0,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="230" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230" y1="100" x2="230" y2="70" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230" y1="70" x2="200" y2="70" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="70" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="100" x2="260" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260" y1="100" x2="260" y2="40" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260" y1="40" x2="200" y2="40" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="40" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# Generalization:

# %%
def polygon(n, length):
    angle = 360 / n
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# Example:

# %%
make_turtle()
polygon(7, 30)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1064b1d00" transform="rotate(-450.00000000000006,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="230" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230" y1="100" x2="249" y2="77" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249" y1="77" x2="242" y2="48" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="242" y1="48" x2="215" y2="35" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="215" y1="35" x2="188" y2="48" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="188" y1="48" x2="181" y2="77" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="181" y1="77" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# Named arguments:

# %%
make_turtle()
polygon(n=7, length=30)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle10648ca40" transform="rotate(-450.00000000000006,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="230" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230" y1="100" x2="249" y2="77" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249" y1="77" x2="242" y2="48" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="242" y1="48" x2="215" y2="35" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="215" y1="35" x2="188" y2="48" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="188" y1="48" x2="181" y2="77" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="181" y1="77" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# ## Approximating a circle
#
# To draw a circle:

# %%
import math

def circle(radius):
    circumference = 2 * math.pi * radius
    n = 30
    length = circumference / n
    polygon(n, length)

# %% [markdown]
# The `delay` argument (named `speed` in ColabTurtle):

# %%
make_turtle(delay=0.05)
circle(30)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle106462ab0" transform="rotate(-450.0,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="206" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="206" y1="100" x2="212" y2="99" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="212" y1="99" x2="218" y2="96" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="218" y1="96" x2="223" y2="92" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="223" y1="92" x2="227" y2="87" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="227" y1="87" x2="230" y2="82" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230" y1="82" x2="232" y2="76" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232" y1="76" x2="233" y2="70" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="233" y1="70" x2="232" y2="64" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232" y1="64" x2="230" y2="58" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230" y1="58" x2="227" y2="53" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="227" y1="53" x2="223" y2="48" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="223" y1="48" x2="218" y2="44" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="218" y1="44" x2="212" y2="41" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="212" y1="41" x2="206" y2="40" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="206" y1="40" x2="200" y2="40" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="40" x2="194" y2="41" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="194" y1="41" x2="188" y2="44" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="188" y1="44" x2="183" y2="48" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="183" y1="48" x2="179" y2="53" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="179" y1="53" x2="176" y2="58" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="176" y1="58" x2="174" y2="64" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="174" y1="64" x2="173" y2="70" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="173" y1="70" x2="174" y2="76" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="174" y1="76" x2="176" y2="82" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="176" y1="82" x2="179" y2="87" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="179" y1="87" x2="183" y2="92" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="183" y1="92" x2="188" y2="96" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="188" y1="96" x2="194" y2="99" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="194" y1="99" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# ## Refactoring
#
# `polyline`, a more general version of `polygon`:

# %%
def polyline(n, length, angle):
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# Parameters:
#
# `n`: number of segments to draw
#
# `length`: length each segment
#
# `angle`: angle between them
#
# New `polygon` using `polyline`:

# %%
def polygon(n, length):
    angle = 360.0 / n
    polyline(n, length, angle)

# %% [markdown]
# Use `polyline` to write `arc`:

# %%
def arc(radius, angle):
    arc_length = 2 * math.pi * radius * angle / 360
    n = 30
    length = arc_length / n
    step_angle = float(angle) / n
    polyline(n, length, step_angle)

# %% [markdown]
# Rewrite `circle` to use `arc`:

# %%
def circle(radius):
    arc(radius,  360)

# %% [markdown]
# To check that these functions work as expected, we'll use them to draw something like a snail.

# %%
make_turtle(delay=0.01)
polygon(n=20, length=9)
arc(radius=70, angle=70)
circle(radius=10)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1064b1430" transform="rotate(-879.9999999999994,268,56) translate(268, 56)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="209" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="209" y1="100" x2="218" y2="97" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="218" y1="97" x2="225" y2="92" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="225" y1="92" x2="230" y2="85" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230" y1="85" x2="233" y2="76" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="233" y1="76" x2="233" y2="67" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="233" y1="67" x2="230" y2="58" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230" y1="58" x2="225" y2="51" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="225" y1="51" x2="218" y2="46" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="218" y1="46" x2="209" y2="43" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="209" y1="43" x2="200" y2="43" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="43" x2="191" y2="46" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="191" y1="46" x2="184" y2="51" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="184" y1="51" x2="179" y2="58" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="179" y1="58" x2="176" y2="67" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="176" y1="67" x2="176" y2="76" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="176" y1="76" x2="179" y2="85" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="179" y1="85" x2="184" y2="92" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="184" y1="92" x2="191" y2="97" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="191" y1="97" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="100" x2="203" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="203" y1="100" x2="206" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="206" y1="100" x2="209" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="209" y1="100" x2="212" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="212" y1="100" x2="215" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="215" y1="100" x2="218" y2="99" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="218" y1="99" x2="221" y2="98" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="221" y1="98" x2="224" y2="97" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="224" y1="97" x2="227" y2="96" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="227" y1="96" x2="230" y2="95" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230" y1="95" x2="233" y2="94" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="233" y1="94" x2="236" y2="93" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="236" y1="93" x2="239" y2="92" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="239" y1="92" x2="241" y2="91" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="241" y1="91" x2="243" y2="89" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="243" y1="89" x2="245" y2="87" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="245" y1="87" x2="247" y2="85" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="247" y1="85" x2="249" y2="83" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249" y1="83" x2="251" y2="81" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="251" y1="81" x2="253" y2="79" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="253" y1="79" x2="255" y2="77" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="255" y1="77" x2="257" y2="75" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="257" y1="75" x2="259" y2="73" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="259" y1="73" x2="261" y2="71" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="261" y1="71" x2="263" y2="69" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="263" y1="69" x2="264" y2="67" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="264" y1="67" x2="265" y2="65" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="265" y1="65" x2="266" y2="62" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="266" y1="62" x2="267" y2="59" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="267" y1="59" x2="268" y2="56" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="268" y1="56" x2="269" y2="54" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="269" y1="54" x2="269" y2="52" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="269" y1="52" x2="269" y2="50" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="269" y1="50" x2="268" y2="48" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="268" y1="48" x2="267" y2="46" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="267" y1="46" x2="266" y2="44" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="266" y1="44" x2="264" y2="43" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="264" y1="43" x2="262" y2="42" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="262" y1="42" x2="260" y2="41" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260" y1="41" x2="258" y2="41" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="258" y1="41" x2="256" y2="41" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="256" y1="41" x2="254" y2="42" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="254" y1="42" x2="252" y2="43" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="252" y1="43" x2="251" y2="45" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="251" y1="45" x2="250" y2="47" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250" y1="47" x2="249" y2="49" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249" y1="49" x2="249" y2="51" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249" y1="51" x2="249" y2="53" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249" y1="53" x2="250" y2="55" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250" y1="55" x2="251" y2="57" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="251" y1="57" x2="252" y2="59" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="252" y1="59" x2="254" y2="60" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="254" y1="60" x2="256" y2="61" stroke-linecap="round"
#     sty

# %% [markdown]
# ## Stack diagram
#
# (no turtle examples in this section)

# %% [markdown]
# ## Docstrings
#
# `polyline` with docstring:

# %%
def polyline(n, length, angle):
    """Draws line segments with the given length and angle between them.

    n: integer number of line segments
    length: length of the line segments
    angle: angle between segments (in degrees)
    """
    for i in range(n):
        forward(length)
        left(angle)

# %%
make_turtle()
polyline(9, 30, 36)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1064d4590" transform="rotate(-414.0,176,82) translate(176, 82)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="230" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230" y1="100" x2="254" y2="82" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="254" y1="82" x2="263" y2="53" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="263" y1="53" x2="254" y2="24" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="254" y1="24" x2="230" y2="6" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230" y1="6" x2="200" y2="6" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="6" x2="176" y2="24" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="176" y1="24" x2="167" y2="53" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="167" y1="53" x2="176" y2="82" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# ## Debugging
#
# (no turtle examples in this section)

# %% [markdown]
# ## Glossary
#
# (no turtle examples in this section)

# %% [markdown]
# ## Exercises
#
# `penup` and `pendown`

# %%
from jupyturtle import forward, penup, pendown

def jump(length):
    """Move forward length units without leaving a trail.

    Postcondition: Leaves the pen down.
    """
    penup()
    forward(length)
    pendown()

# %% [markdown]
# ### Exercise
#
# Draw a rectangle:

# %%
# Solution

def rectangle(length1, length2):
    """Draw a rectangle with the given lengths.

    length1: length of the first side
    length2: length of the second size
    """
    for i in range(2):
        forward(length1)
        left(90)
        forward(length2)
        left(90)

# %%
make_turtle()
rectangle(80, 40)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1064b1d00" transform="rotate(-450.0,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="280" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="280" y1="100" x2="280" y2="60" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="280" y1="60" x2="200" y2="60" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="60" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Draw a rhombus:

# %%
def rhombus(length, angle):
    for i in range(2):
        forward(length)
        left(angle)
        forward(length)
        left(180-angle)

# %%
make_turtle()
rhombus(50, 60)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1064f0050" transform="rotate(-450.0,200,100) translate(200, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="250" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250" y1="100" x2="275" y2="57" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="275" y1="57" x2="225" y2="57" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="225" y1="57" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write `parallelogram`, then rewrite `rectangle` and `rhombus` to use it:

# %%
# Solution

def parallelogram(length1, length2, angle):
    for i in range(2):
        forward(length1)
        left(angle)
        forward(length2)
        left(180-angle)

# %%
# Solution

def rectangle(length1, length2):
    """Draw a rectangle with the given lengths.

    length1: length of the first side
    length2: length of the second size
    """
    parallelogram(length1, length2, 90)

# %%
# Solution

def rhombus(length, angle):
    parallelogram(length, length, angle)

# %%
make_turtle(delay=0.05)
jump(-120)

rectangle(80, 40)
jump(100)
rhombus(50, 60)
jump(80)
parallelogram(80, 50, 60)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1064b1d00" transform="rotate(-1170.0,260,100) translate(260, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="80" y1="100" x2="160" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160" y1="100" x2="160" y2="60" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160" y1="60" x2="80" y2="60" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="80" y1="60" x2="80" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="180" y1="100" x2="230" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230" y1="100" x2="255" y2="57" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="255" y1="57" x2="205" y2="57" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="205" y1="57" x2="180" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260" y1="100" x2="340" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="340" y1="100" x2="365" y2="57" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="365" y1="57" x2="285" y2="57" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="285" y1="57" x2="260" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# A `triangle` function:

# %%
# Solution
import math

from jupyturtle import forward, left, right

def triangle(radius,  angle):
    """Draws an icosceles triangle.

    The turtle starts and ends at the peak, facing the middle of the base.

    radius: length of the equal legs
    angle: half peak angle in degrees
    """
    y = radius * math.sin(angle * math.pi / 180)

    right(angle)
    forward(radius)
    left(90+angle)
    forward(2*y)
    left(90+angle)
    forward(radius)
    left(180-angle)

# %% [markdown]
# (a little demonstration)

# %%
from jupyturtle import make_turtle, hide
make_turtle()
hide()

for i in range(12):
    triangle(50, 10)
    left(30)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <line x1="200" y1="100" x2="249" y2="109" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249" y1="109" x2="249" y2="92" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249" y1="92" x2="200" y2="101" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="101" x2="247" y2="84" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="247" y1="84" x2="238" y2="69" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="238" y1="69" x2="200" y2="101" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="101" x2="232" y2="63" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232" y1="63" x2="217" y2="54" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="217" y1="54" x2="200" y2="101" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="101" x2="209" y2="52" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="209" y1="52" x2="192" y2="52" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="192" y1="52" x2="201" y2="101" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="201" y1="101" x2="184" y2="54" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="184" y1="54" x2="169" y2="63" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="169" y1="63" x2="201" y2="101" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="201" y1="101" x2="163" y2="69" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="163" y1="69" x2="154" y2="84" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="154" y1="84" x2="201" y2="101" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="201" y1="101" x2="152" y2="92" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="152" y1="92" x2="152" y2="109" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="152" y1="109" x2="201" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="201" y1="100" x2="154" y2="117" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="154" y1="117" x2="163" y2="132" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="163" y1="132" x2="201" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="201" y1="100" x2="169" y2="138" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="169" y1="138" x2="184" y2="147" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="184" y1="147" x2="201" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="201" y1="100" x2="192" y2="149" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="192" y1="149" x2="209" y2="149" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="209" y1="149" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="100" x2="217" y2="147" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="217" y1="147" x2="232" y2="138" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232" y1="138" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="100" x2="238" y2="132" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="238" y1="132" x2="247" y2="117" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="247" y1="117" x2="200" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %%
# Solution

def draw_pie(n, radius):
    """Draws a pie divided into radial segments.

    n: number of segments
    radius: length of the radial spokes
    """
    angle = 360.0 / n
    for i in range(n):
        triangle(radius,  angle/2)
        left(angle)

# %%
make_turtle(delay=0.01)
draw_pie(5, 40)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle10648c3b0" transform="rotate(-2250.0,200,99) translate(200, 99)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="232" y2="124" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232" y1="124" x2="232" y2="77" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232" y1="77" x2="200" y2="101" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="101" x2="232" y2="77" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232" y1="77" x2="187" y2="62" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="187" y1="62" x2="199" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="199" y1="100" x2="187" y2="62" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="187" y1="62" x2="159" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="159" y1="100" x2="199" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="199" y1="100" x2="159" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="159" y1="100" x2="187" y2="138" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="187" y1="138" x2="199" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="199" y1="100" x2="187" y2="138" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="187" y1="138" x2="232" y2="123" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232" y1="123" x2="200" y2="99" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# </svg>

# %%
make_turtle(delay=0.01)
jump(-120)

size = 40
draw_pie(5, size)
jump(2*size)
draw_pie(6, size)
jump(2*size)
draw_pie(7, size)
jump(2*size)
draw_pie(8, size)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1064f21b0" transform="rotate(-10890.0,320,98) translate(320, 98)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="80" y1="100" x2="112" y2="124" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="112" y1="124" x2="112" y2="77" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="112" y1="77" x2="80" y2="101" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="80" y1="101" x2="112" y2="77" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="112" y1="77" x2="67" y2="62" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="67" y1="62" x2="79" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="79" y1="100" x2="67" y2="62" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="67" y1="62" x2="39" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="39" y1="100" x2="79" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="79" y1="100" x2="39" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="39" y1="100" x2="67" y2="138" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="67" y1="138" x2="79" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="79" y1="100" x2="67" y2="138" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="67" y1="138" x2="112" y2="123" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="112" y1="123" x2="80" y2="99" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160" y1="99" x2="195" y2="119" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="195" y1="119" x2="195" y2="79" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="195" y1="79" x2="160" y2="99" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160" y1="99" x2="195" y2="79" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="195" y1="79" x2="160" y2="59" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160" y1="59" x2="160" y2="99" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160" y1="99" x2="160" y2="59" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160" y1="59" x2="125" y2="79" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="125" y1="79" x2="160" y2="99" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160" y1="99" x2="125" y2="79" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="125" y1="79" x2="125" y2="119" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="125" y1="119" x2="160" y2="99" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160" y1="99" x2="125" y2="119" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="125" y1="119" x2="160" y2="139" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160" y1="139" x2="160" y2="99" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160" y1="99" x2="160" y2="139" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160" y1="139" x2="195" y2="119" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="195" y1="119" x2="160" y2="99" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="240" y1="99" x2="276" y2="116" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="276" y1="116" x2="276" y2="81" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="276" y1="81" x2="240" y2="98" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="240" y1="98" x2="276" y2="81" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="276" y1="81" x2="249" y2="59" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249" y1="59" x2="240" y2="98" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="240" y1="98" x2="249" y2="59" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249" y1="59" x2="215" y2="67" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="215" y1="67" x2="240" y2="98" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="240" y1="98" x2="215" y2="67" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="215" y1="67" x2="200" y2="98" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="98" x2="240" y2="98" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="240" y1="98" x2="200" y2="98" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="200" y1="98" x2="215" y2="129" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="215" y1="129" x2="240" y2="98" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="240" y1="98" x2="215" y2="129" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="215" y1="129" x2="249" y2="137" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249" y1="137" x2="240" y2="98" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="240" y1="98" x2="249" y2="137" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249" y1="137" x2="276" y2="115" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="276" y1="115" x2="240" y2="98" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="320" y1="98" x2="357" y2="113" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="357" y1="113" x2="357" y2="82" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="357" y1="82" x2="320" y2="97" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="320" y1="97" x2="357" y2="82" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="357" y1="82" x2="335" y2="60" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="335" y1="60" x2="320" y2="97" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="320" y1="97" x2="335" y2="60" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="335" y1="60" x2="304" y2="60" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="304" y1="60" x2="319" y2="97" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="319" y1="97" x2="304" y2="60" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="304" y1="60" x2="282" y2="82" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="282" y1="82" x2="319" y2="97" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="319" y1="97" x2="282" y2="82" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="282" y1="82" x2="282" y2="113" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="282" y1="113" x2="319" y2="98" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="319" y1="98" x2="282" y2="113" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="282" y1="113" x2="304" y2="135" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="304" y1="135" x2="319" y2="98" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="319" y1="98" x2="304" y2="135" stroke-linecap="round"

# %% [markdown]
# ### Exercise
#
# Draw flowers with `petal`:

# %%
# Solution

def petal(radius,  angle):
    """Draws a petal using two arcs.

    t: Turtle
    radius: radius of the arcs
    angle: angle (degrees) that subtends the arcs
    """
    for i in range(2):
        arc(radius,  angle)
        left(180-angle)

# %%
# Solution

def flower(n, radius, angle):
    """Draws a flower with n petals.

    n: number of petals
    radius: radius of the arcs
    angle: angle (degrees) that subtends the arcs
    """
    for i in range(n):
        petal(radius,  angle)
        left(360/n)

# %%
make_turtle()

jump(-100)
flower(7, 60.0, 60.0)

jump(100)
flower(10, 40.0, 80.0)

jump(100)
flower(14, 140.0, 20.0)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1064b1d00" transform="rotate(-12329.999999999802,300,100) translate(300, 100)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="100" y1="100" x2="102" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="102" y1="100" x2="104" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="104" y1="100" x2="106" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="106" y1="100" x2="108" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="108" y1="100" x2="110" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="110" y1="100" x2="112" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="112" y1="100" x2="114" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="114" y1="100" x2="116" y2="99" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="116" y1="99" x2="118" y2="98" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="118" y1="98" x2="120" y2="97" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="120" y1="97" x2="122" y2="96" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="122" y1="96" x2="124" y2="95" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="124" y1="95" x2="126" y2="94" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="126" y1="94" x2="128" y2="93" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="128" y1="93" x2="130" y2="92" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="130" y1="92" x2="132" y2="91" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="132" y1="91" x2="134" y2="90" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="134" y1="90" x2="136" y2="89" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="136" y1="89" x2="138" y2="88" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="138" y1="88" x2="140" y2="87" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="140" y1="87" x2="142" y2="86" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="142" y1="86" x2="144" y2="85" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="144" y1="85" x2="146" y2="84" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="146" y1="84" x2="147" y2="82" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="147" y1="82" x2="148" y2="80" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="148" y1="80" x2="149" y2="78" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="149" y1="78" x2="150" y2="76" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="150" y1="76" x2="151" y2="74" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="151" y1="74" x2="152" y2="72" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="152" y1="72" x2="153" y2="70" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="153" y1="70" x2="151" y2="70" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="151" y1="70" x2="149" y2="70" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="149" y1="70" x2="147" y2="70" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="147" y1="70" x2="145" y2="70" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="145" y1="70" x2="143" y2="70" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="143" y1="70" x2="141" y2="70" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="141" y1="70" x2="139" y2="70" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="139" y1="70" x2="137" y2="71" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="137" y1="71" x2="135" y2="72" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="135" y1="72" x2="133" y2="73" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="133" y1="73" x2="131" y2="74" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="131" y1="74" x2="129" y2="75" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="129" y1="75" x2="127" y2="76" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="127" y1="76" x2="125" y2="77" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="125" y1="77" x2="123" y2="78" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="123" y1="78" x2="121" y2="79" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="121" y1="79" x2="119" y2="80" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="119" y1="80" x2="117" y2="81" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="117" y1="81" x2="115" y2="82" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="115" y1="82" x2="113" y2="83" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="113" y1="83" x2="111" y2="84" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="111" y1="84" x2="109" y2="85" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="109" y1="85" x2="107" y2="86" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="107" y1="86" x2="106" y2="88" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="106" y1="88" x2="105" y2="90" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="105" y1="90" x2="104" y2="92" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="104" y1="92" x2="103" y2="94" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="103" y1="94" x2="102" y2="96" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="102" y1="96" x2="101" y2="98" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="101" y1="98" x2="100" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="100" y1="100" x2="101" y2="98" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="101" y1="98" x2="102" y2="96" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="102" y1="96" x2="103" y2="94" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="103" y1="94" x2="104" y2="92" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="104" y1="92" x2="105" y2="90" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="105" y1="90" x2="106" y2="88" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="106" y1="88" x2="107" y2="86" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="107" y1="86" x2="108" y2="84" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="108" y1="84" x2="109" y2="82" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="109" y1="82" x2="110" y2="80" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="110" y1="80" x2="111" y2="78" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="111" y1="78" x2="112" y2="76" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="112" y1="76" x2="113" y2="74" stroke-linecap="round"

# %% [markdown]
# ### Ask an assistant
#
# Draw a spiral:

# %%
# Solution

from jupyturtle import make_turtle, forward, right

make_turtle()

def spiral(length, angle):
    for _ in range(100):
        forward(length)
        right(angle)
        length += 2  # Increase the length for each segment

spiral(5, 90)
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1064d6840" transform="rotate(8910.0,100,0) translate(100, 0)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="205" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="205" y1="100" x2="205" y2="107" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="205" y1="107" x2="196" y2="107" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="196" y1="107" x2="196" y2="96" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="196" y1="96" x2="209" y2="96" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="209" y1="96" x2="209" y2="111" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="209" y1="111" x2="192" y2="111" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="192" y1="111" x2="192" y2="92" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="192" y1="92" x2="213" y2="92" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="213" y1="92" x2="213" y2="115" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="213" y1="115" x2="188" y2="115" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="188" y1="115" x2="188" y2="88" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="188" y1="88" x2="217" y2="88" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="217" y1="88" x2="217" y2="119" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="217" y1="119" x2="184" y2="119" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="184" y1="119" x2="184" y2="84" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="184" y1="84" x2="221" y2="84" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="221" y1="84" x2="221" y2="123" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="221" y1="123" x2="180" y2="123" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="180" y1="123" x2="180" y2="80" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="180" y1="80" x2="225" y2="80" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="225" y1="80" x2="225" y2="127" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="225" y1="127" x2="176" y2="127" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="176" y1="127" x2="176" y2="76" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="176" y1="76" x2="229" y2="76" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="229" y1="76" x2="229" y2="131" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="229" y1="131" x2="172" y2="131" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="172" y1="131" x2="172" y2="72" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="172" y1="72" x2="233" y2="72" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="233" y1="72" x2="233" y2="135" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="233" y1="135" x2="168" y2="135" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="168" y1="135" x2="168" y2="68" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="168" y1="68" x2="237" y2="68" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="237" y1="68" x2="237" y2="139" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="237" y1="139" x2="164" y2="139" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="164" y1="139" x2="164" y2="64" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="164" y1="64" x2="241" y2="64" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="241" y1="64" x2="241" y2="143" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="241" y1="143" x2="160" y2="143" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160" y1="143" x2="160" y2="60" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="160" y1="60" x2="245" y2="60" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="245" y1="60" x2="245" y2="147" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="245" y1="147" x2="156" y2="147" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="156" y1="147" x2="156" y2="56" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="156" y1="56" x2="249" y2="56" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249" y1="56" x2="249" y2="151" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249" y1="151" x2="152" y2="151" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="152" y1="151" x2="152" y2="52" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="152" y1="52" x2="253" y2="52" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="253" y1="52" x2="253" y2="155" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="253" y1="155" x2="148" y2="155" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="148" y1="155" x2="148" y2="48" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="148" y1="48" x2="257" y2="48" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="257" y1="48" x2="257" y2="159" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="257" y1="159" x2="144" y2="159" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="144" y1="159" x2="144" y2="44" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="144" y1="44" x2="261" y2="44" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="261" y1="44" x2="261" y2="163" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="261" y1="163" x2="140" y2="163" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="140" y1="163" x2="140" y2="40" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="140" y1="40" x2="265" y2="40" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="265" y1="40" x2="265" y2="167" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="265" y1="167" x2="136" y2="167" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="136" y1="167" x2="136" y2="36" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="136" y1="36" x2="269" y2="36" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="269" y1="36" x2="269" y2="171" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="269" y1="171" x2="132" y2="171" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="132" y1="171" x2="132" y2="32" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="132" y1="32" x2="273" y2="32" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="273" y1="32" x2="273" y2="175" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="273" y1="175" x2="128" y2="175" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="128" y1="175" x2="128" y2="28" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="128" y1="28" x

# %%
# Solution

# prompt: make that a circular spiral, and don't change the name of the module

from jupyturtle import make_turtle, forward, left
import math

make_turtle()

def circular_spiral(radius, angle):
    rotations = 5
    distance = 2 * math.pi * radius / 360  # Calculate the distance for each degree of rotation
    for _ in range(rotations * 360):
        forward(distance)
        left(angle)
        radius += 0.1  # Increase the radius for each segment
        distance = 2 * math.pi * radius / 360  # Recalculate the distance for the updated radius

circular_spiral(50, 1)
print('done')
# Out:
# <svg width="400" height="200">
#     <rect width="100%" height="100%" fill="#FFF" />
#
#
# <g id="turtle1064f3350" transform="rotate(-1890.0,189,269) translate(189, 269)">
#     <circle stroke="#777" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#777;stroke:#777;stroke-width:2"/>
# </g>
#
# <line x1="200" y1="100" x2="201" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="201" y1="100" x2="202" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="202" y1="100" x2="203" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="203" y1="100" x2="204" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="204" y1="100" x2="205" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="205" y1="100" x2="206" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="206" y1="100" x2="207" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="207" y1="100" x2="208" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="208" y1="100" x2="209" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="209" y1="100" x2="210" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="210" y1="100" x2="211" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="211" y1="100" x2="212" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="212" y1="100" x2="213" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="213" y1="100" x2="214" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="214" y1="100" x2="215" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="215" y1="100" x2="216" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="216" y1="100" x2="217" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="217" y1="100" x2="218" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="218" y1="100" x2="219" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="219" y1="100" x2="220" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="220" y1="100" x2="221" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="221" y1="100" x2="222" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="222" y1="100" x2="223" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="223" y1="100" x2="224" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="224" y1="100" x2="225" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="225" y1="100" x2="226" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="226" y1="100" x2="227" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="227" y1="100" x2="228" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="228" y1="100" x2="229" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="229" y1="100" x2="230" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="230" y1="100" x2="231" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="231" y1="100" x2="232" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="232" y1="100" x2="233" y2="100" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="233" y1="100" x2="234" y2="99" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="234" y1="99" x2="235" y2="98" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="235" y1="98" x2="236" y2="97" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="236" y1="97" x2="237" y2="96" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="237" y1="96" x2="238" y2="95" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="238" y1="95" x2="239" y2="94" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="239" y1="94" x2="240" y2="93" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="240" y1="93" x2="241" y2="92" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="241" y1="92" x2="242" y2="91" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="242" y1="91" x2="243" y2="90" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="243" y1="90" x2="244" y2="89" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="244" y1="89" x2="245" y2="88" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="245" y1="88" x2="246" y2="87" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="246" y1="87" x2="247" y2="86" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="247" y1="86" x2="248" y2="85" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="248" y1="85" x2="249" y2="84" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="249" y1="84" x2="250" y2="83" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="250" y1="83" x2="251" y2="82" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="251" y1="82" x2="252" y2="81" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="252" y1="81" x2="253" y2="80" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="253" y1="80" x2="254" y2="79" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="254" y1="79" x2="255" y2="78" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="255" y1="78" x2="256" y2="77" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="256" y1="77" x2="257" y2="76" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="257" y1="76" x2="258" y2="75" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="258" y1="75" x2="259" y2="74" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="259" y1="74" x2="260" y2="73" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260" y1="73" x2="260" y2="72" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260" y1="72" x2="260" y2="71" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260" y1="71" x2="260" y2="70" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260" y1="70" x2="260" y2="69" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260" y1="69" x2="260" y2="68" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260" y1="68" x2="260" y2="67" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260" y1="67" x2="260" y2="66" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260" y1="66" x2="260" y2="65" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260" y1="65" x2="260" y2="64" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260" y1="64" x2="260" y2="63" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260" y1="63" x2="260" y2="62" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260" y1="62" x2="260" y2="61" stroke-linecap="round"
#     style="stroke:#000;stroke-width:2"/>
#
# <line x1="260" y1="61" x2="
# done
