# %% [markdown]
# # Turtle command reference
#
# #### [`back`](#forward(n);-back(n)-—-aliases-fd;-bk) [`bk`](#forward(n);-back(n)-—-aliases-fd;-bk) [`forward`](#forward(n);-back(n)-—-aliases-fd;-bk) [`fd`](#forward(n);-back(n)-—-aliases-fd;-bk) [`get_turtle`](#get_turtle()) [`hide`](#hide()) [`jumpto`](#jumpto()) [`left`](#left(n);-right(n)-—-aliases-lt;-rt) [`lt`](#left(n);-right(n)-—-aliases-lt;-rt) [`make_turtle`](#get_turtle())
# #### [`moveto`](#moveto()) [`no_pen`](#no_pen()) [`pendown`](#pendown()) [`penup`](#penup()) [`render`](#render()) [`right`](#left(n);-right(n)-—-aliases-lt;-rt) [`rt`](#left(n);-right(n)-—-aliases-lt;-rt) [`show`](#show()) [`toggle_pen`](#toggle_pen())

# %% [markdown]
# ## Introduction to the turtle and canvas

# %% [markdown]
# Import all names exported by the `jupyturtle` module, then move the turtle.

# %%
from jupyturtle import *
fd(50)
# Out:
# <svg width="300" height="150" style="fill:none;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 200.0,75.0" />'
#
# <g transform="rotate(-90.0,200.0,75.0) translate(200.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Most commands will automatically create a turtle and blank canvas,
# if there isn't one already.
#
# To start a new drawing, call `make_turtle()`

# %%
make_turtle()
fd(60)
lt(120)
fd(60)  # see more turtle commands below drawing
# Out:
# <svg width="300" height="150" style="fill:none;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 210.0,75.0 179.99999999999997,23.038475772933694 149.99999999999997,75.00000000000001" />'
#
# <g transform="rotate(30.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Further commands apply to the latest turtle.

# %%
lt(120)
fd(60)

# %% [markdown]
# ## Essential commands
#
# Learn these first.

# %% [markdown]
# ### `forward(n)`; `back(n)` — aliases `fd`; `bk`
#
# Move turtle forward or backward `n` units, leaving a trail if the pen is down.

# %%
make_turtle()
fd(50)
bk(75)
fd(25)
# Out:
# <svg width="300" height="150" style="fill:none;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 200.0,75.0 125.0,75.0 150.0,75.0" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### `left(n)`; `right(n)` — aliases `lt`; `rt`
#
# Turn turtle left or right `n` degrees, remaining in place.

# %%
make_turtle()
lt(45)
rt(90)
# Out:
# <svg width="300" height="150" style="fill:none;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <g transform="rotate(-45.0,150,75) translate(150, 75)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### `penup()`; `pendown()`
#
# Raise or lower the turtle's pen. The turtle leaves a trail only when the pen is down (the default).

# %%
make_turtle()

for _ in range(4):
    fd(10)
    penup()
    fd(20)
    pendown()
# Out:
# <svg width="300" height="150" style="fill:none;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 160.0,75.0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 180.0,75.0 190.0,75.0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 210.0,75.0 220.0,75.0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 240.0,75.0 250.0,75.0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 270.0,75.0" />'
#
# <g transform="rotate(-90.0,270.0,75.0) translate(270.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### `no_pen()`

# %% [markdown]
# Returs a context manager that calls `penup()` at the top of the `with` block
# and resets the pen to its previous state at the end of the block.
#
# This is useful to move the turtle without drawing for a few steps.

# %%
make_turtle(delay=0.1)

rt(60)

for _ in range(3):
    lt(60)
    fd(30)
    with no_pen():
        lt(60)
        fd(30)
# Out:
# <svg width="300" height="150" style="fill:none;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 180.0,75.0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 195.0,49.01923788646684 180.0,23.038475772933687" />'
#
# <path stroke="#663399" stroke-width="2" d="M 150.0,23.03847577293369 135.0,49.019237886466854" />'
#
# <path stroke="#663399" stroke-width="2" d="M 150.0,75.00000000000001" />'
#
# <g transform="rotate(-30.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### toggle_pen()
#
# Lower the pen if it's up; raises it if it's down.

# %%
make_turtle(delay=.01)

for _ in range(20):
    fd(5)
    toggle_pen()
# Out:
# <svg width="300" height="150" style="fill:none;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 155.0,75.0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 160.0,75.0 165.0,75.0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 170.0,75.0 175.0,75.0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 180.0,75.0 185.0,75.0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 190.0,75.0 195.0,75.0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 200.0,75.0 205.0,75.0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 210.0,75.0 215.0,75.0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 220.0,75.0 225.0,75.0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 230.0,75.0 235.0,75.0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 240.0,75.0 245.0,75.0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 250.0,75.0" />'
#
# <g transform="rotate(-90.0,250.0,75.0) translate(250.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### `hide()`; `show()`

# %% [markdown]
# Make the turtle invisible or visible. The turtle is visible by default. Making it invisible speeds up drawing.

# %%
make_turtle()
hide()
forward(100)
# Out:
# <svg width="300" height="150" style="fill:none;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 250.0,75.0" />'
#
# </svg>

# %% [markdown]
# ### `make_turtle(auto_render=True, delay=0.2, width=300, height=150)`
#
# Create a new turtle and canvas. Assign new turtle to `_main_turtle`. Further commands are sent to `_main_turtle`.
#
# Optional arguments:
#
# `auto_render=True` updates the drawing with each turtle command. This is slow for complex drawings with many lines. Set to `False` for much faster processing, then use `render()` to render the drawing.
#
# `delay=?` sets a delay in seconds after each turtle command. Default is `0`.
# For debugging, setting `delay=.5` makes the turtle pause for ½ second so it's easy to watch each step as it happens.
#
# `width=?` / `height=?` define the size of the drawing area.
#
# Use `auto_render=False` and `render()` to draw  circles and arcs almost instantly.
#
# The `delay` is ignored when `auto_render` is `False`,
# because the drawing will only be updated once, after a call to `render()`.

# %%
make_turtle(delay=5, auto_render=False, height=240, width=240)

def circle():
    for _ in range(180):
        fd(2)
        lt(2)

for _ in range(24):
    circle()
    lt(15)

render()
# Out:
# Warning: delay is ignored when auto_render=False
# <svg width="240" height="240" style="fill:none;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 120,120 122.0,120.0 123.9987816540382,119.930201006595 125.99390975455785,119.79068805910674 127.9829535452944,119.58163113257143 129.96348968277752,119.3032849306513 131.93310518880193,118.95598857531743 133.88940039026954,118.54016519368191 135.82999184282153,118.05632140248258 137.75251523469817,117.50504669084859 139.65462826728847,116.88701270209869 141.53401350886028,116.20297241544735 143.38838121799387,115.45375922861552 145.21547213327906,114.64028594246392 147.0130602258774,113.76354364888576 148.77895541159526,112.82460052331398 150.51100621916413,111.82460052331398 152.207102411477,110.76476199484756 153.86517755658707,109.64637618790607 155.48321154533696,108.47080568332112 157.0592330525504,107.2394827326698 158.59132193878835,105.95390751329673 160.07761158974316,104.61564630057902 161.51629119042045,103.22632955966102 162.90560793133844,101.78764995898372 164.24386914405616,100.30136030802893 165.52944436342923,98.76927142179098 166.76076731408054,97.19324991457754 167.9363378186655,95.57521592582764 169.05472362560698,93.91714078071755 170.11456215407338,92.2210445884047 171.11456215407338,90.48899378083581 172.05350527964515,88.72309859511796 172.9302475732233,86.92551050251963 173.74372085937492,85.09841958723443 174.49293404620676,83.24405187810086 175.1769743328581,81.36466663652905 175.79500832160798,79.46255360393874 176.34628303324197,77.5400302120621 176.83012682444132,75.59943875951011 177.24595020607683,73.6431435580425 177.5932465614107,71.67352805201809 177.87159276333082,69.69299191453494 178.08064968986614,67.7039481237984 178.22016263735438,65.70882002327875 178.2899616307594,63.71003836924056 178.2899616307594,61.71003836924056 178.22016263735438,59.71125671520237 178.08064968986614,57.71612861468272 177.87159276333082,55.72708482394617 177.5932465614107,53.74654868646303 177.24595020607683,51.77693318043861 176.8301268244413,49.820637978971 176.34628303324195,47.88004652641901 175.79500832160795,45.95752313454237 175.17697433285807,44.05541010195206 174.49293404620673,42.176024860380245 173.7437208593749,40.32165715124667 172.93024757322328,38.494566235961464 172.05350527964512,36.69697814336313 171.11456215407335,34.93108295764528 170.11456215407335,33.199032150076405 169.05472362560695,31.502935957763555 167.93633781866546,29.844860812653472 166.7607673140805,28.22682682390358 165.5294443634292,26.650805316690136 164.24386914405613,25.11871643045218 162.9056079313384,23.632426779497393 161.51629119042042,22.19374717882009 160.07761158974313,20.804430437902095 158.59132193878833,19.46616922518438 157.05923305255038,18.1805940058113 155.48321154533693,16.949271055159983 153.86517755658704,15.773700550575036 152.20710241147697,14.655314743633543 150.5110062191641,13.595476215167134 148.77895541159523,12.595476215167134 147.01306022587738,11.656533089595351 145.21547213327904,10.779790796017195 143.38838121799384,9.966317509865595 141.53401350886026,9.217104323033771 139.65462826728844,8.533064036382434 137.75251523469814,7.9150300476325395 135.8299918428215,7.363755335998541 133.88940039026951,6.8799115447992065 131.9331051888019,6.464088163163687 129.9634896827775,6.116791807829826 127.98295354529435,5.838445605909695 125.9939097545578,5.629388679374388 123.99878165403815,5.489875731886138 121.99999999999996,5.420076738481137 119.99999999999996,5.420076738481137 118.00121834596176,5.489875731886139 116.00609024544211,5.62938867937439 114.01704645470556,5.838445605909698 112.03651031722242,6.116791807829828 110.06689481119801,6.464088163163688 108.1105996097304,6.8799115447992065 106.1700081571784,7.363755335998542 104.24748476530176,7.91503004763254 102.34537173271146,8.533064036382436 100.46598649113965,9.217104323033773 98.61161878200608,9.966317509865597 96.78452786672088,10.779790796017197 94.98693977412255,11.656533089595351 93.2210445884047,12.595476215167132 91.48899378083581,13.595476215167132 89.79289758852296,14.655314743633541 88.13482244 ...

# %% [markdown]
# With `auto_render=True` (the default value), we can see the drawing as it happens.
# The drawing below will be updated at 361 times: 180 updates per circle, plus the update of `lt(15)`.
#
# > **Note**: The `jupyturtle` Python code generates the drawing as SVG code, which is then rendered by the browser's graphic engine. For each update, automatic or not, a complete new drawing is generated and rendered.

# %%
make_turtle(delay=0, height=240, width=240)

def circle():
    for _ in range(180):
        fd(2)
        lt(2)
        
circle()
lt(15)
circle()
# Out:
# <svg width="240" height="240" style="fill:none;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 120,120 122.0,120.0 123.9987816540382,119.930201006595 125.99390975455785,119.79068805910674 127.9829535452944,119.58163113257143 129.96348968277752,119.3032849306513 131.93310518880193,118.95598857531743 133.88940039026954,118.54016519368191 135.82999184282153,118.05632140248258 137.75251523469817,117.50504669084859 139.65462826728847,116.88701270209869 141.53401350886028,116.20297241544735 143.38838121799387,115.45375922861552 145.21547213327906,114.64028594246392 147.0130602258774,113.76354364888576 148.77895541159526,112.82460052331398 150.51100621916413,111.82460052331398 152.207102411477,110.76476199484756 153.86517755658707,109.64637618790607 155.48321154533696,108.47080568332112 157.0592330525504,107.2394827326698 158.59132193878835,105.95390751329673 160.07761158974316,104.61564630057902 161.51629119042045,103.22632955966102 162.90560793133844,101.78764995898372 164.24386914405616,100.30136030802893 165.52944436342923,98.76927142179098 166.76076731408054,97.19324991457754 167.9363378186655,95.57521592582764 169.05472362560698,93.91714078071755 170.11456215407338,92.2210445884047 171.11456215407338,90.48899378083581 172.05350527964515,88.72309859511796 172.9302475732233,86.92551050251963 173.74372085937492,85.09841958723443 174.49293404620676,83.24405187810086 175.1769743328581,81.36466663652905 175.79500832160798,79.46255360393874 176.34628303324197,77.5400302120621 176.83012682444132,75.59943875951011 177.24595020607683,73.6431435580425 177.5932465614107,71.67352805201809 177.87159276333082,69.69299191453494 178.08064968986614,67.7039481237984 178.22016263735438,65.70882002327875 178.2899616307594,63.71003836924056 178.2899616307594,61.71003836924056 178.22016263735438,59.71125671520237 178.08064968986614,57.71612861468272 177.87159276333082,55.72708482394617 177.5932465614107,53.74654868646303 177.24595020607683,51.77693318043861 176.8301268244413,49.820637978971 176.34628303324195,47.88004652641901 175.79500832160795,45.95752313454237 175.17697433285807,44.05541010195206 174.49293404620673,42.176024860380245 173.7437208593749,40.32165715124667 172.93024757322328,38.494566235961464 172.05350527964512,36.69697814336313 171.11456215407335,34.93108295764528 170.11456215407335,33.199032150076405 169.05472362560695,31.502935957763555 167.93633781866546,29.844860812653472 166.7607673140805,28.22682682390358 165.5294443634292,26.650805316690136 164.24386914405613,25.11871643045218 162.9056079313384,23.632426779497393 161.51629119042042,22.19374717882009 160.07761158974313,20.804430437902095 158.59132193878833,19.46616922518438 157.05923305255038,18.1805940058113 155.48321154533693,16.949271055159983 153.86517755658704,15.773700550575036 152.20710241147697,14.655314743633543 150.5110062191641,13.595476215167134 148.77895541159523,12.595476215167134 147.01306022587738,11.656533089595351 145.21547213327904,10.779790796017195 143.38838121799384,9.966317509865595 141.53401350886026,9.217104323033771 139.65462826728844,8.533064036382434 137.75251523469814,7.9150300476325395 135.8299918428215,7.363755335998541 133.88940039026951,6.8799115447992065 131.9331051888019,6.464088163163687 129.9634896827775,6.116791807829826 127.98295354529435,5.838445605909695 125.9939097545578,5.629388679374388 123.99878165403815,5.489875731886138 121.99999999999996,5.420076738481137 119.99999999999996,5.420076738481137 118.00121834596176,5.489875731886139 116.00609024544211,5.62938867937439 114.01704645470556,5.838445605909698 112.03651031722242,6.116791807829828 110.06689481119801,6.464088163163688 108.1105996097304,6.8799115447992065 106.1700081571784,7.363755335998542 104.24748476530176,7.91503004763254 102.34537173271146,8.533064036382436 100.46598649113965,9.217104323033773 98.61161878200608,9.966317509865597 96.78452786672088,10.779790796017197 94.98693977412255,11.656533089595351 93.2210445884047,12.595476215167132 91.48899378083581,13.595476215167132 89.79289758852296,14.655314743633541 88.13482244 ...

# %% [markdown]
# ### `get_turtle()`
#
# Returns existing `_main_turtle`, or creates and sets it if it was `None`.
# Useful when you need to change some turtle attribute, like `auto_render` or `delay` after `make_turtle()`.
# See example in `render()`.

# %% [markdown]
# ### `render()`
#
# Update the drawing.
# Use `render()` to render the drawing after setting `auto_render=False` and
# issuing turtle commands like `fd()`, `lt()` etc.
#
# When `auto_render=True`, `render()` is automatically called after each turtle command.
#
# The next example draws two circles.
# We can see the turtle drawing the first circle because `auto_render=True`.
# We then set `auto_render=False`, and the second circle is rendered all at once
# when we call `render()`.

# %%
make_turtle(delay=0.005, height=240, width=240)

def circle():
    for _ in range(180):
        fd(2)
        lt(2)

# first circle, `auto_render` is on (the default)
circle()  # slow-ish
lt(15)
# second circle, turn off `auto_render`
get_turtle().auto_render=False
circle()  # almost instant, delay is ignored
render()  # all lines rendered at once
# Out:
# <svg width="240" height="240" style="fill:none;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 120,120 122.0,120.0 123.9987816540382,119.930201006595 125.99390975455785,119.79068805910674 127.9829535452944,119.58163113257143 129.96348968277752,119.3032849306513 131.93310518880193,118.95598857531743 133.88940039026954,118.54016519368191 135.82999184282153,118.05632140248258 137.75251523469817,117.50504669084859 139.65462826728847,116.88701270209869 141.53401350886028,116.20297241544735 143.38838121799387,115.45375922861552 145.21547213327906,114.64028594246392 147.0130602258774,113.76354364888576 148.77895541159526,112.82460052331398 150.51100621916413,111.82460052331398 152.207102411477,110.76476199484756 153.86517755658707,109.64637618790607 155.48321154533696,108.47080568332112 157.0592330525504,107.2394827326698 158.59132193878835,105.95390751329673 160.07761158974316,104.61564630057902 161.51629119042045,103.22632955966102 162.90560793133844,101.78764995898372 164.24386914405616,100.30136030802893 165.52944436342923,98.76927142179098 166.76076731408054,97.19324991457754 167.9363378186655,95.57521592582764 169.05472362560698,93.91714078071755 170.11456215407338,92.2210445884047 171.11456215407338,90.48899378083581 172.05350527964515,88.72309859511796 172.9302475732233,86.92551050251963 173.74372085937492,85.09841958723443 174.49293404620676,83.24405187810086 175.1769743328581,81.36466663652905 175.79500832160798,79.46255360393874 176.34628303324197,77.5400302120621 176.83012682444132,75.59943875951011 177.24595020607683,73.6431435580425 177.5932465614107,71.67352805201809 177.87159276333082,69.69299191453494 178.08064968986614,67.7039481237984 178.22016263735438,65.70882002327875 178.2899616307594,63.71003836924056 178.2899616307594,61.71003836924056 178.22016263735438,59.71125671520237 178.08064968986614,57.71612861468272 177.87159276333082,55.72708482394617 177.5932465614107,53.74654868646303 177.24595020607683,51.77693318043861 176.8301268244413,49.820637978971 176.34628303324195,47.88004652641901 175.79500832160795,45.95752313454237 175.17697433285807,44.05541010195206 174.49293404620673,42.176024860380245 173.7437208593749,40.32165715124667 172.93024757322328,38.494566235961464 172.05350527964512,36.69697814336313 171.11456215407335,34.93108295764528 170.11456215407335,33.199032150076405 169.05472362560695,31.502935957763555 167.93633781866546,29.844860812653472 166.7607673140805,28.22682682390358 165.5294443634292,26.650805316690136 164.24386914405613,25.11871643045218 162.9056079313384,23.632426779497393 161.51629119042042,22.19374717882009 160.07761158974313,20.804430437902095 158.59132193878833,19.46616922518438 157.05923305255038,18.1805940058113 155.48321154533693,16.949271055159983 153.86517755658704,15.773700550575036 152.20710241147697,14.655314743633543 150.5110062191641,13.595476215167134 148.77895541159523,12.595476215167134 147.01306022587738,11.656533089595351 145.21547213327904,10.779790796017195 143.38838121799384,9.966317509865595 141.53401350886026,9.217104323033771 139.65462826728844,8.533064036382434 137.75251523469814,7.9150300476325395 135.8299918428215,7.363755335998541 133.88940039026951,6.8799115447992065 131.9331051888019,6.464088163163687 129.9634896827775,6.116791807829826 127.98295354529435,5.838445605909695 125.9939097545578,5.629388679374388 123.99878165403815,5.489875731886138 121.99999999999996,5.420076738481137 119.99999999999996,5.420076738481137 118.00121834596176,5.489875731886139 116.00609024544211,5.62938867937439 114.01704645470556,5.838445605909698 112.03651031722242,6.116791807829828 110.06689481119801,6.464088163163688 108.1105996097304,6.8799115447992065 106.1700081571784,7.363755335998542 104.24748476530176,7.91503004763254 102.34537173271146,8.533064036382436 100.46598649113965,9.217104323033773 98.61161878200608,9.966317509865597 96.78452786672088,10.779790796017197 94.98693977412255,11.656533089595351 93.2210445884047,12.595476215167132 91.48899378083581,13.595476215167132 89.79289758852296,14.655314743633541 88.13482244 ...

# %% [markdown]
# ### `jumpto(x, y)`
#
# Teleport the turtle to coordinates (x, y) without drawing. Contrast with `moveto(x, y)`.

# %%
make_turtle(delay=0.01)

def square():
    for _ in range(4):
        fd(30)
        rt(90)

for i in range(3):
    jumpto(i*60 + 5, i*40 + 5)
    square()
# Out:
# <svg width="300" height="150" style="fill:none;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 5,5 35.0,5.0 35.0,35.0 5.0,35.00000000000001 4.999999999999995,5.000000000000007" />'
#
# <path stroke="#663399" stroke-width="2" d="M 65,45 95.0,45.0 95.0,75.0 65.0,75.0 65.0,45.0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 125,85 155.0,85.0 155.0,115.0 125.0,115.0 125.0,85.0" />'
#
# <g transform="rotate(-90.0,125.0,85.0) translate(125.0, 85.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### `moveto(x, y)`
#
# Move the turtle to coordinates (x, y), drawing if the pen is down. Contrast with `jumpto(x, y)`.

# %%
make_turtle(delay=0.01)

for i in range(3):
    moveto(i*60 + 5, i*40 + 5)
    square()
# Out:
# <svg width="300" height="150" style="fill:none;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 5,5 35.0,5.0 35.0,35.0 5.0,35.00000000000001 4.999999999999995,5.000000000000007 65,45 95.0,45.0 95.0,75.0 65.0,75.0 65.0,45.0 125,85 155.0,85.0 155.0,115.0 125.0,115.0 125.0,85.0" />'
#
# <g transform="rotate(-90.0,125.0,85.0) translate(125.0, 85.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>
