# %% [markdown]
# # Turtle command reference

# %% [markdown]
# ## Introduction to the turtle and canvas

# %% [markdown]
# Import all names exported by the `jupyturtle` module, then move the turtle.

# %%
from jupyturtle import *
fd(50)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# <g transform="rotate(-90.0,200.0,75.0) translate(200.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Most commands will automatically create a turtle and blank canvas,
# if there isn't one already.
#
# To start a new drawing, call `make_turtle()`

# %%
make_turtle()
fd(60)
lt(120)
fd(60)  # see more turtle commands below drawing
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="210.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="210.0" y1="75.0" x2="180.0" y2="23.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="180.0" y1="23.0" x2="150.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# <g transform="rotate(30.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Further commands apply to the existing turtle.

# %%
lt(120)
fd(60)

# %% [markdown]
# ## Essential commands
#
# Learn these first.

# %% [markdown]
# ### `forward(n)` — alias `fd`
#
# Move turtle forward `n` units, leaving a trail if the pen is down. If n < 0, the turtle moves backward.

# %%
make_turtle()
fd(50)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# <g transform="rotate(-90.0,200.0,75.0) translate(200.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### `left(n)`; `right(n)` — aliases `lt`; `rt`
#
# Turn turtle left or right `n` degrees, remaining in place.

# %%
make_turtle()
lt(45)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <g transform="rotate(225.0,150,75) translate(150, 75)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### `penup()`; `pendown()`
#
# Raise or lower the turtle's pen. The turtle leaves a trail only when the pen is down (the default).

# %%
make_turtle()

for _ in range(3):
    fd(15)
    penup()
    fd(25)
    pendown()
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="165.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="190.0" y1="75.0" x2="205.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="230.0" y1="75.0" x2="245.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# <g transform="rotate(-90.0,270.0,75.0) translate(270.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### `hide()`; `show()`

# %% [markdown]
# Make the turtle invisible or visible. The turtle is visible by default. Making it invisible speeds up drawing.

# %%
make_turtle()
hide()
forward(100)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="250.0" y2="75.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
#
# </svg>

# %% [markdown]
# ### `make_turtle(auto_render=True, delay=0.2, width=300, height=150)`
#
# Create a new turtle and canvas. Assign new turtle to `_main_turtle`. Further commands are sent to `_main_turtle`.
#
# Optional arguments:
#
# `auto_render=True` updates the drawing with each turtle command. This is slow for complex drawings with many lines. Set to `False` for much faster processing, then use `render()` to render the drawing.
#
# `delay=0` sets a delay in seconds after each turtle command. For debugging, setting `delay=.5` makes the turtle pause for ½ second so it's easy to observe each step.
#
# `width/height` define the size of the drawing area.
#
# Using `auto_render=False` and `render()` the circles are drawn almost instantly. When `auto_render` is `False`, the `delay` is ignored, because there's no point in waiting when nothing visible is happening.

# %%
make_turtle(delay=5, auto_render=False, height=240, width=240)

def circle():
    for _ in range(180):
        fd(2)
        lt(2)

for _ in range(24):
    circle()
    lt(15)

render()
# Out:
# Warning: delay is ignored when auto_render=False
# <svg width="240" height="240">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="120" y1="120" x2="122.0" y2="120.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="122.0" y1="120.0" x2="124.0" y2="119.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="124.0" y1="119.9" x2="126.0" y2="119.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="126.0" y1="119.8" x2="128.0" y2="119.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="128.0" y1="119.6" x2="130.0" y2="119.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="130.0" y1="119.3" x2="131.9" y2="119.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="131.9" y1="119.0" x2="133.9" y2="118.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="133.9" y1="118.5" x2="135.8" y2="118.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="135.8" y1="118.1" x2="137.8" y2="117.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="137.8" y1="117.5" x2="139.7" y2="116.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="139.7" y1="116.9" x2="141.5" y2="116.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="141.5" y1="116.2" x2="143.4" y2="115.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="143.4" y1="115.5" x2="145.2" y2="114.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="145.2" y1="114.6" x2="147.0" y2="113.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="147.0" y1="113.8" x2="148.8" y2="112.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="148.8" y1="112.8" x2="150.5" y2="111.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.5" y1="111.8" x2="152.2" y2="110.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="152.2" y1="110.8" x2="153.9" y2="109.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="153.9" y1="109.6" x2="155.5" y2="108.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="155.5" y1="108.5" x2="157.1" y2="107.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="157.1" y1="107.2" x2="158.6" y2="106.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="158.6" y1="106.0" x2="160.1" y2="104.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="160.1" y1="104.6" x2="161.5" y2="103.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="161.5" y1="103.2" x2="162.9" y2="101.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="162.9" y1="101.8" x2="164.2" y2="100.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="164.2" y1="100.3" x2="165.5" y2="98.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="165.5" y1="98.8" x2="166.8" y2="97.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="166.8" y1="97.2" x2="167.9" y2="95.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="167.9" y1="95.6" x2="169.1" y2="93.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="169.1" y1="93.9" x2="170.1" y2="92.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="170.1" y1="92.2" x2="171.1" y2="90.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="171.1" y1="90.5" x2="172.1" y2="88.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="172.1" y1="88.7" x2="172.9" y2="86.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="172.9" y1="86.9" x2="173.7" y2="85.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="173.7" y1="85.1" x2="174.5" y2="83.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="174.5" y1="83.2" x2="175.2" y2="81.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="175.2" y1="81.4" x2="175.8" y2="79.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="175.8" y1="79.5" x2="176.3" y2="77.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="176.3" y1="77.5" x2="176.8" y2="75.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="176.8" y1="75.6" x2="177.2" y2="73.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.2" y1="73.6" x2="177.6" y2="71.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.6" y1="71.7" x2="177.9" y2="69.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.9" y1="69.7" x2="178.1" y2="67.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.1" y1="67.7" x2="178.2" y2="65.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.2" y1="65.7" x2="178.3" y2="63.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.3" y1="63.7" x2="178.3" y2="61.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.3" y1="61.7" x2="178.2" y2="59.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.2" y1="59.7" x2="178.1" y2="57.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.1" y1="57.7" x2="177.9" y2="55.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.9" y1="55.7" x2="177.6" y2="53.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.6" y1="53.7" x2="177.2" y2="51.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.2" y1="51.8" x2="176.8" y2="49.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="176.8" y1="49.8" x2="176.3" y2="47.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="176.3" y1="47.9" x2="175.8" y2="46.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="175.8" y1="46.0" x2="175.2" y2="44.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="175.2" y1="44.1" x2="174.5" y2="42.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="174.5" y1="42.2" x2="173.7" y2="40.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="173.7" y1="40.3" x2="172.9" y2="38.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="172.9" y1="38.5" x2="172.1" y2="36.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="172.1" y1="36.7" x2="171.1" y2="34.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="171.1" y1="34.9" x2="170.1" y2="33.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="170.1" y1="33.2" x2="169.1" y2="31.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="169.1" y1="31.5" x2="167.9" y2="29.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="167.9" y1="29.8" x2="166.8" y2="28.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="166.8" y1="28.2" x2="165.5" y2="26.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="165.5" y1="26.7" x2="164.2" y2="25.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="164.2" y1="25.1" x2="162.9" y2="23.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="162.9" y1="23.6" x2="161.5" y2="22.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="161.5" y1="22.2" x2="160.1" y2="20.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />

# %% [markdown]
# With `auto_render=True` (the default value), we can see the drawing as it happens.
# The drawing below will be updated at 361 times: 180 updates per circle, plus the update of `lt(15)`.
#
# > **Note**: The `jupyturtle` Python code generates the drawing as SVG code, which is then rendered by the browser's graphic engine. For each update, automatic or not, a complete new drawing is generated and rendered.

# %%
make_turtle(delay=0, height=240, width=240)

def circle():
    for _ in range(180):
        fd(2)
        lt(2)
        
circle()
lt(15)
circle()
# Out:
# <svg width="240" height="240">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="120" y1="120" x2="122.0" y2="120.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="122.0" y1="120.0" x2="124.0" y2="119.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="124.0" y1="119.9" x2="126.0" y2="119.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="126.0" y1="119.8" x2="128.0" y2="119.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="128.0" y1="119.6" x2="130.0" y2="119.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="130.0" y1="119.3" x2="131.9" y2="119.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="131.9" y1="119.0" x2="133.9" y2="118.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="133.9" y1="118.5" x2="135.8" y2="118.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="135.8" y1="118.1" x2="137.8" y2="117.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="137.8" y1="117.5" x2="139.7" y2="116.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="139.7" y1="116.9" x2="141.5" y2="116.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="141.5" y1="116.2" x2="143.4" y2="115.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="143.4" y1="115.5" x2="145.2" y2="114.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="145.2" y1="114.6" x2="147.0" y2="113.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="147.0" y1="113.8" x2="148.8" y2="112.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="148.8" y1="112.8" x2="150.5" y2="111.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.5" y1="111.8" x2="152.2" y2="110.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="152.2" y1="110.8" x2="153.9" y2="109.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="153.9" y1="109.6" x2="155.5" y2="108.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="155.5" y1="108.5" x2="157.1" y2="107.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="157.1" y1="107.2" x2="158.6" y2="106.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="158.6" y1="106.0" x2="160.1" y2="104.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="160.1" y1="104.6" x2="161.5" y2="103.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="161.5" y1="103.2" x2="162.9" y2="101.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="162.9" y1="101.8" x2="164.2" y2="100.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="164.2" y1="100.3" x2="165.5" y2="98.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="165.5" y1="98.8" x2="166.8" y2="97.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="166.8" y1="97.2" x2="167.9" y2="95.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="167.9" y1="95.6" x2="169.1" y2="93.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="169.1" y1="93.9" x2="170.1" y2="92.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="170.1" y1="92.2" x2="171.1" y2="90.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="171.1" y1="90.5" x2="172.1" y2="88.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="172.1" y1="88.7" x2="172.9" y2="86.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="172.9" y1="86.9" x2="173.7" y2="85.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="173.7" y1="85.1" x2="174.5" y2="83.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="174.5" y1="83.2" x2="175.2" y2="81.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="175.2" y1="81.4" x2="175.8" y2="79.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="175.8" y1="79.5" x2="176.3" y2="77.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="176.3" y1="77.5" x2="176.8" y2="75.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="176.8" y1="75.6" x2="177.2" y2="73.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.2" y1="73.6" x2="177.6" y2="71.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.6" y1="71.7" x2="177.9" y2="69.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.9" y1="69.7" x2="178.1" y2="67.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.1" y1="67.7" x2="178.2" y2="65.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.2" y1="65.7" x2="178.3" y2="63.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.3" y1="63.7" x2="178.3" y2="61.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.3" y1="61.7" x2="178.2" y2="59.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.2" y1="59.7" x2="178.1" y2="57.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.1" y1="57.7" x2="177.9" y2="55.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.9" y1="55.7" x2="177.6" y2="53.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.6" y1="53.7" x2="177.2" y2="51.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.2" y1="51.8" x2="176.8" y2="49.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="176.8" y1="49.8" x2="176.3" y2="47.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="176.3" y1="47.9" x2="175.8" y2="46.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="175.8" y1="46.0" x2="175.2" y2="44.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="175.2" y1="44.1" x2="174.5" y2="42.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="174.5" y1="42.2" x2="173.7" y2="40.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="173.7" y1="40.3" x2="172.9" y2="38.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="172.9" y1="38.5" x2="172.1" y2="36.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="172.1" y1="36.7" x2="171.1" y2="34.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="171.1" y1="34.9" x2="170.1" y2="33.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="170.1" y1="33.2" x2="169.1" y2="31.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="169.1" y1="31.5" x2="167.9" y2="29.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="167.9" y1="29.8" x2="166.8" y2="28.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="166.8" y1="28.2" x2="165.5" y2="26.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="165.5" y1="26.7" x2="164.2" y2="25.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="164.2" y1="25.1" x2="162.9" y2="23.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="162.9" y1="23.6" x2="161.5" y2="22.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="161.5" y1="22.2" x2="160.1" y2="20.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />

# %% [markdown]
# ### `get_turtle()`
#
# Returns existing `_main_turtle`, or creates and sets it if it was `None`.
# Useful when you need to change some turtle attribute, like `auto_render` or `delay` after `make_turtle()`.
# See example in `render()`.

# %% [markdown]
# ### `render()`
#
# Update the drawing.
# Use `render()` to render the drawing after setting `auto_render=False` and
# issuing turtle commands like `fd()`, `lt()` etc.
#
# When `auto_render=True`, `render()` is automatically called after each turtle command.
#
# The next example draws two circles.
# We can see the turtle drawing the first circle because `auto_render=True`.
# We then set `auto_render=False`, and the second circle is rendered all at once
# when we call `render()`.

# %%
make_turtle(delay=0.005, height=240, width=240)

def circle():
    for _ in range(180):
        fd(2)
        lt(2)

# first circle, `auto_render` is on (the default)
circle()  # slow-ish
lt(15)
# second circle, turn off `auto_render`
get_turtle().auto_render=False
circle()  # almost instant, delay is ignored
render()  # all lines rendered at once
# Out:
# <svg width="240" height="240">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="120" y1="120" x2="122.0" y2="120.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="122.0" y1="120.0" x2="124.0" y2="119.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="124.0" y1="119.9" x2="126.0" y2="119.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="126.0" y1="119.8" x2="128.0" y2="119.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="128.0" y1="119.6" x2="130.0" y2="119.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="130.0" y1="119.3" x2="131.9" y2="119.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="131.9" y1="119.0" x2="133.9" y2="118.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="133.9" y1="118.5" x2="135.8" y2="118.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="135.8" y1="118.1" x2="137.8" y2="117.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="137.8" y1="117.5" x2="139.7" y2="116.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="139.7" y1="116.9" x2="141.5" y2="116.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="141.5" y1="116.2" x2="143.4" y2="115.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="143.4" y1="115.5" x2="145.2" y2="114.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="145.2" y1="114.6" x2="147.0" y2="113.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="147.0" y1="113.8" x2="148.8" y2="112.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="148.8" y1="112.8" x2="150.5" y2="111.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="150.5" y1="111.8" x2="152.2" y2="110.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="152.2" y1="110.8" x2="153.9" y2="109.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="153.9" y1="109.6" x2="155.5" y2="108.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="155.5" y1="108.5" x2="157.1" y2="107.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="157.1" y1="107.2" x2="158.6" y2="106.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="158.6" y1="106.0" x2="160.1" y2="104.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="160.1" y1="104.6" x2="161.5" y2="103.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="161.5" y1="103.2" x2="162.9" y2="101.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="162.9" y1="101.8" x2="164.2" y2="100.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="164.2" y1="100.3" x2="165.5" y2="98.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="165.5" y1="98.8" x2="166.8" y2="97.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="166.8" y1="97.2" x2="167.9" y2="95.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="167.9" y1="95.6" x2="169.1" y2="93.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="169.1" y1="93.9" x2="170.1" y2="92.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="170.1" y1="92.2" x2="171.1" y2="90.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="171.1" y1="90.5" x2="172.1" y2="88.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="172.1" y1="88.7" x2="172.9" y2="86.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="172.9" y1="86.9" x2="173.7" y2="85.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="173.7" y1="85.1" x2="174.5" y2="83.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="174.5" y1="83.2" x2="175.2" y2="81.4" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="175.2" y1="81.4" x2="175.8" y2="79.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="175.8" y1="79.5" x2="176.3" y2="77.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="176.3" y1="77.5" x2="176.8" y2="75.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="176.8" y1="75.6" x2="177.2" y2="73.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.2" y1="73.6" x2="177.6" y2="71.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.6" y1="71.7" x2="177.9" y2="69.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.9" y1="69.7" x2="178.1" y2="67.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.1" y1="67.7" x2="178.2" y2="65.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.2" y1="65.7" x2="178.3" y2="63.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.3" y1="63.7" x2="178.3" y2="61.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.3" y1="61.7" x2="178.2" y2="59.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.2" y1="59.7" x2="178.1" y2="57.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="178.1" y1="57.7" x2="177.9" y2="55.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.9" y1="55.7" x2="177.6" y2="53.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.6" y1="53.7" x2="177.2" y2="51.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="177.2" y1="51.8" x2="176.8" y2="49.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="176.8" y1="49.8" x2="176.3" y2="47.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="176.3" y1="47.9" x2="175.8" y2="46.0" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="175.8" y1="46.0" x2="175.2" y2="44.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="175.2" y1="44.1" x2="174.5" y2="42.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="174.5" y1="42.2" x2="173.7" y2="40.3" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="173.7" y1="40.3" x2="172.9" y2="38.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="172.9" y1="38.5" x2="172.1" y2="36.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="172.1" y1="36.7" x2="171.1" y2="34.9" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="171.1" y1="34.9" x2="170.1" y2="33.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="170.1" y1="33.2" x2="169.1" y2="31.5" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="169.1" y1="31.5" x2="167.9" y2="29.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="167.9" y1="29.8" x2="166.8" y2="28.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="166.8" y1="28.2" x2="165.5" y2="26.7" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="165.5" y1="26.7" x2="164.2" y2="25.1" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="164.2" y1="25.1" x2="162.9" y2="23.6" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="162.9" y1="23.6" x2="161.5" y2="22.2" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
# <line x1="161.5" y1="22.2" x2="160.1" y2="20.8" stroke-linecap="round"
#   style="stroke:#663399;stroke-width:2" />
