# %%
from jupyturtle import *
fd(100)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 250,75 250,35" />'
#
# <g transform="rotate(180.0,250.0,35.0) translate(250.0, 35.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
lt(90)
fd(40)

# %%
# %%turtle
# lt(90)
# fd(10)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 150,65" />'
#
# <g transform="rotate(180.0,150.0,65.0) translate(150.0, 65.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
# %%turtle fast 130
#
# def circle():
#     for _ in range(90):
#         fd(2)
#         lt(4)
#
# for _ in range(18):
#     circle()
#     lt(20)
# Out:
# <svg width="130" height="130" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# ...

# %%
# %%turtle 220
#
# def triangle():
#     for _ in range(3):
#         fd(100)
#         lt(120)
#
# triangle()
# Out:
# <svg width="220" height="220" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 110,110 210,110 160,23.4 110,110" />'
#
# <g transform="rotate(-90.0,110.0,110.0) translate(110.0, 110.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
# %%turtle 220
#
# for _ in range(6):
#     lt(60)
#     triangle()
# Out:
# <svg width="220" height="220" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 110,110 160,23.4 60,23.4 110,110 60,23.4 10,110 110,110 10,110 60,196.6 110,110 60,196.6 160,196.6 110,110 160,196.6 210,110 110,110 210,110 160,23.4 110,110" />'
#
# <g transform="rotate(-90.0,110.0,110.0) translate(110.0, 110.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
# %%turtle 100 200 banana fast 300
# pass
# Out:
# UsageError: %%turtle cannot handle ['banana', '300']
